# %% [markdown]
# <a href="https://colab.research.google.com/github/Alamsyah-WM/Predict-DNA-binding-protein-with-ML-and-DL/blob/main/Bioinformatic_G1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup
#
#
# ---
#
#
# Installing packages pandas, numpy, tqdm, sckit-learn, and pretrain model

# %%
# !pip install fair-esm -q
# !pip install torch torchvision torchaudio
# !pip install fair-esm scikit-learn pandas numpy tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: fair-esm in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# #Import Library
#
#
# ---
#
#
# Importing Library from installed setup

# %%
import torch
import pandas as pd
import numpy as np
import esm
import os
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
import time
import itertools
from tqdm import tqdm
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.svm import SVC
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score,
    accuracy_score, precision_score, recall_score, f1_score, classification_report,
    matthews_corrcoef
)
import matplotlib.pyplot as plt

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# #Load Dataset
# ---
# Load both PDB1063 and UniSwiss dataset.
#
# > df_pdb = pd.read_csv(pdb_dataset_path) <p> df_uni = pd.read_csv(uni_dataset_path) </p>

# %%
df_pdb = pd.read_csv('/content/PDB1063-186.csv')
df_uni = pd.read_csv('/content/UniSwiss.csv')


print(f'Total sequence PDB: {len(df_pdb)}')
print(f'Total sequence UniSwiss: {len(df_uni)}')
# Out:
# Total sequence PDB: 1249
# Total sequence UniSwiss: 9762

# %% [markdown]
# #Preprocess Dataset
# ---
# Cleaning duplicate sequence (cleaning_dataset)
#
# > df_clean = df.drop_duplicates(subset='sequence')
#
# Split test and train dataset (split_dataset)
#
#
# > train_df = df[df['set'] == 'train'] <p>
#         test_df = df[df['set'] == 'test']

# %%
def cleaning_dataset (df, dataset_name= None):
    if df is None or df.empty:
        print(f'Dataset {dataset_name} is empty. No clean required')
        return df

    # Check if 'set' column exists
    if 'set' in df.columns:
        # Sort so that 'test' comes before 'train' - this ensures test set is kept
        df_sorted = df.sort_values(by='set', ascending=True)  # 'test' > 'train' alphabetically

        # Now drop duplicates - will keep first occurrence (which will be 'test' if duplicates exist across sets)
        df_clean = df_sorted.drop_duplicates(subset='sequence', keep='first')

        # Reset index
        df_clean = df_clean.reset_index(drop=True)

        # Show statistics
        train_before = len(df[df['set'] == 'train'])
        test_before = len(df[df['set'] == 'test'])
        train_after = len(df_clean[df_clean['set'] == 'train'])
        test_after = len(df_clean[df_clean['set'] == 'test'])

        print(f'Dataset {dataset_name}:')
        print(f'  Train: {train_before} -> {train_after} (removed {train_before - train_after})')
        print(f'  Test: {test_before} -> {test_after} (removed {test_before - test_after})')
        print(f'  Total: {len(df)} -> {len(df_clean)} (removed {len(df) - len(df_clean)})')
    else:
        # If no 'set' column, just remove duplicates normally
        df_clean = df.drop_duplicates(subset='sequence', keep='first')
        print(f'Total protein dataset {dataset_name} after cleaning: {len(df_clean)}')

    return df_clean

df_pdb = cleaning_dataset(df_pdb, "PDB")
df_uni = cleaning_dataset(df_uni, "UniSwiss")


def split_dataset (df, dataset_name= None):
    if 'set' in df.columns:
        train_df = df[df['set'] == 'train']
        test_df = df[df['set'] == 'test']
    else:
        return df

    # Extract seq and labels for both dataset
    x_train = train_df['sequence'].tolist()
    y_train = train_df['label'].values

    x_test = test_df['sequence'].tolist()
    y_test = test_df['label'].values

    print(f"\nTraining sequence {dataset_name}: {len(x_train)}")
    print(f"Training label {dataset_name}: {len(y_train)}")

    print(f"Test sequence {dataset_name}: {len(x_test)}")
    print(f"Test label {dataset_name}: {len(y_test)}")

    return train_df, test_df, x_train, y_train, x_test, y_test

df_pdb_train, df_pdb_test, x_pdb_train, y_pdb_train, x_pdb_test, y_pdb_test = split_dataset(df_pdb, 'PDB')
df_uni_train, df_uni_test, x_uni_train, y_uni_train, x_uni_test, y_uni_test = split_dataset(df_uni, 'UniSwiss')
# Out:
# Dataset PDB:
#   Train: 1063 -> 985 (removed 78)
#   Test: 186 -> 186 (removed 0)
#   Total: 1249 -> 1171 (removed 78)
# Dataset UniSwiss:
#   Train: 9000 -> 8937 (removed 63)
#   Test: 762 -> 759 (removed 3)
#   Total: 9762 -> 9696 (removed 66)
#
# Training sequence PDB: 985
# Training label PDB: 985
# Test sequence PDB: 186
# Test label PDB: 186
#
# Training sequence UniSwiss: 8937
# Training label UniSwiss: 8937
# Test sequence UniSwiss: 759
# Test label UniSwiss: 759

# %% [markdown]
# #Load pretrain model
#
# ---
#
#
# Check device processor for running
# >device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# Load model ESM-1b
# > model, alphabet = esm.pretrained.esm1b_t33_650M_UR50S()
#
# call converter/formatter for raw protein sequence into format can be processed by model
# > batch_converter = alphabet.get_batch_converter()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model, alphabet = esm.pretrained.esm1b_t33_650M_UR50S()
batch_converter = alphabet.get_batch_converter()
model = model.eval().to(device)
# Out:
# Using device: cuda
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm1b_t33_650M_UR50S.pt" to /root/.cache/torch/hub/checkpoints/esm1b_t33_650M_UR50S.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm1b_t33_650M_UR50S-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm1b_t33_650M_UR50S-contact-regression.pt

# %% [markdown]
# #Sequence Handling
#
# ---
#
#
# Add window sliding for split long protein sequence into overlapping windows. (window_sliding)
#
# If protein sequence length > 1022, split into overlap window (chunks)

# %%
def window_sliding(seq, max_len=1022, stride=512):
    if len(seq) <= max_len:
        return [seq]
    chunks = []
    for i in range(0, len(seq), stride):
        chunk = seq[i:i + max_len]
        if len(chunk) < 50:   # skip fragments too short to be meaningful
            continue
        chunks.append(chunk)
    return chunks

# %% [markdown]
# #Embeddings
#
# ---
# Extract mean ESM-1b embeddings for a list of protein sequences (extract_esm_embeddings).

# %%
def extract_esm_embeddings(sequences, batch_size=8):
    """Extract mean ESM-1b embeddings with automatic windowing for long proteins."""
    all_embeddings = []
    truncated_count = 0

    for seq in tqdm(sequences, desc="Extracting ESM embeddings"):
        subseqs = window_sliding(seq)
        if len(seq) > 1022 :
            truncated_count += 1

        subseq_embeddings = []
        for i in range(0, len(subseqs), batch_size):
            batch = subseqs[i:i + batch_size]
            batch_data = [("", s) for s in batch]
            batch_labels, batch_strs, batch_tokens = batch_converter(batch_data)
            batch_tokens = batch_tokens.to(device)

            with torch.no_grad():
                results = model(batch_tokens, repr_layers=[33])
                reps = results["representations"][33]

            for j, s in enumerate(batch):
                emb = reps[j, 1:len(s)+1].mean(0).cpu().numpy()
                subseq_embeddings.append(emb)

            del batch_tokens, results, reps
            torch.cuda.empty_cache()

        # Average all windows for this protein
        mean_embedding = np.mean(subseq_embeddings, axis=0)
        all_embeddings.append(mean_embedding)

    print(f"Total sequences processed: {len(sequences)}")
    print(f"Sequences truncated (>1022 aa): {truncated_count} ({truncated_count/len(sequences)*100:.2f}%)")

    return np.vstack(all_embeddings)

x_pdb_train_emb = extract_esm_embeddings(x_pdb_train, batch_size=8)
x_pdb_test_emb  = extract_esm_embeddings(x_pdb_test, batch_size=8)

x_uni_train_emb = extract_esm_embeddings(x_uni_train, batch_size=8)
x_uni_test_emb  = extract_esm_embeddings(x_uni_test, batch_size=8)
# Out:
# Extracting ESM embeddings: 100%|██████████| 985/985 [01:59<00:00,  8.27it/s]
# Total sequences processed: 985
# Sequences truncated (>1022 aa): 5 (0.51%)
# Extracting ESM embeddings: 100%|██████████| 186/186 [00:27<00:00,  6.88it/s]
# Total sequences processed: 186
# Sequences truncated (>1022 aa): 4 (2.15%)
# Extracting ESM embeddings: 100%|██████████| 8937/8937 [46:31<00:00,  3.20it/s]
# Total sequences processed: 8937
# Sequences truncated (>1022 aa): 735 (8.22%)
# Extracting ESM embeddings: 100%|██████████| 759/759 [03:54<00:00,  3.24it/s]
# Total sequences processed: 759
# Sequences truncated (>1022 aa): 64 (8.43%)

# %% [markdown]
# #Checkpoints DL
#
#
# ---
#
#
# Saving embedding output from pretrained model. <P>
# Create directory for Deep Learning model
# > os.makedirs("esm_embed/DL", exist_ok=True)
#
# Save sequence train and test (PDB)
# >torch.save(torch.tensor(x_pdb_train_emb), "esm_embed/DL/PDB/x_pdb_train.pt")<p>torch.save(torch.tensor(x_pdb_test_emb),  "esm_embed/DL/PDB/x__pdb_test.pt")
#
# Save label train and test (PDB)
# > np.save("esm_embed/DL/PDB/y_pdb_train.npy", y_pdb_train) <p>
# np.save("esm_embed/DL/PDB/y_pdb_test.npy",  y_pdb_test)

# %%
os.makedirs("esm_embed_2/DL", exist_ok=True)

torch.save(torch.tensor(x_pdb_train_emb), "esm_embed_2/DL/PDB/x_pdb_train.pt")
torch.save(torch.tensor(x_pdb_test_emb),  "esm_embed_2/DL/PDB/x_pdb_test.pt")

np.save("esm_embed_2/DL/PDB/y_pdb_train.npy", y_pdb_train)
np.save("esm_embed_2/DL/PDB/y_pdb_test.npy",  y_pdb_test)

torch.save(torch.tensor(x_uni_train_emb), "esm_embed_2/DL/UNI/x_uni_train.pt")
torch.save(torch.tensor(x_uni_test_emb),  "esm_embed_2/DL/UNI/x_uni_test.pt")

np.save("esm_embed_2/DL/UNI/y_uni_train.npy", y_uni_train)
np.save("esm_embed_2/DL/UNI/y_uni_test.npy",  y_uni_test)

print("Save success")
# Out:
# Save success

# %% [markdown]
# #Load Checkpoints
# Load embedding process for Deep learning and Machine learning

# %%
# Deep learning
x_pdb_train_emb = torch.load("/content/drive/MyDrive/esm_embed_2/DL/PDB/x_pdb_train.pt").numpy()
y_pdb_train = np.load("/content/drive/MyDrive/esm_embed_2/DL/PDB/y_pdb_train.npy")

x_pdb_test_emb = torch.load("/content/drive/MyDrive/esm_embed_2/DL/PDB/x_pdb_test.pt").numpy()
y_pdb_test = np.load("/content/drive/MyDrive/esm_embed_2/DL/PDB/y_pdb_test.npy")

x_uni_train_emb = torch.load("/content/drive/MyDrive/esm_embed_2/DL/UNI/x_uni_train.pt").numpy()
y_uni_train = np.load("/content/drive/MyDrive/esm_embed_2/DL/UNI/y_uni_train.npy")

x_uni_test_emb = torch.load("/content/drive/MyDrive/esm_embed_2/DL/UNI/x_uni_test.pt").numpy()
y_uni_test = np.load("/content/drive/MyDrive/esm_embed_2/DL/UNI/y_uni_test.npy")

print (x_pdb_train_emb.shape, y_pdb_train.shape)
print (x_uni_train_emb.shape, y_uni_train.shape)
# Out:
# (985, 1280) (985,)
# (8937, 1280) (8937,)

# %% [markdown]
# #Split Dataset

# %%
val_size_pdb = 111 / 1060  # ~10% validation (same size as test set, which is 111 out of 1060)
x_pdb_train, x_pdb_val, y_pdb_train, y_pdb_val = train_test_split(
    x_pdb_train_emb, y_pdb_train,
    test_size=val_size_pdb,
    stratify=y_pdb_train,
    random_state=42
)

# For UniSwiss dataset (use similar logic)
val_size_uni = 756 / 8940  # test set is 756 out of 8940 (about 8%)
x_uni_train, x_uni_val, y_uni_train, y_uni_val = train_test_split(
    x_uni_train_emb, y_uni_train,
    test_size=val_size_uni,
    stratify=y_uni_train,
    random_state=42
)

# %%
print(f"PDB New Training set size: {x_pdb_train.shape[0]}")
print(f"PDB Validation set size: {x_pdb_val.shape[0]}")
print(f"PDB Test set size: {x_pdb_test_emb.shape[0]}")

print(f"\nUniSwiss New Training set size: {x_uni_train.shape[0]}")
print(f"UniSwiss Validation set size: {x_uni_val.shape[0]}")
print(f"UniSwiss Test set size: {x_uni_test_emb.shape[0]}")
# Out:
# PDB New Training set size: 881
# PDB Validation set size: 104
# PDB Test set size: 186
#
# UniSwiss New Training set size: 8181
# UniSwiss Validation set size: 756
# UniSwiss Test set size: 759

# %%
# PDB
print("PDB - Training Set Class Balance:")
unique, counts = np.unique(y_pdb_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_pdb_train)*100:.2f}%")

print("\nPDB - Validation Set Class Balance:")
unique, counts = np.unique(y_pdb_val, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_pdb_val)*100:.2f}%")

print("\nPDB - Test Set Class Balance:")
unique, counts = np.unique(y_pdb_test, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_pdb_test)*100:.2f}%")

# UniSwiss
print("\nUniSwiss - Training Set Class Balance:")
unique, counts = np.unique(y_uni_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_uni_train)*100:.2f}%")

print("\nUniSwiss - Validation Set Class Balance:")
unique, counts = np.unique(y_uni_val, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_uni_val)*100:.2f}%")

print("\nUniSwiss - Test Set Class Balance:")
unique, counts = np.unique(y_uni_test, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}, Percent: {c/len(y_uni_test)*100:.2f}%")
# Out:
# PDB - Training Set Class Balance:
# Class 0: 487, Percent: 55.28%
# Class 1: 394, Percent: 44.72%
#
# PDB - Validation Set Class Balance:
# Class 0: 58, Percent: 55.77%
# Class 1: 46, Percent: 44.23%
#
# PDB - Test Set Class Balance:
# Class 0: 93, Percent: 50.00%
# Class 1: 93, Percent: 50.00%
#
# UniSwiss - Training Set Class Balance:
# Class 0: 4118, Percent: 50.34%
# Class 1: 4063, Percent: 49.66%
#
# UniSwiss - Validation Set Class Balance:
# Class 0: 380, Percent: 50.26%
# Class 1: 376, Percent: 49.74%
#
# UniSwiss - Test Set Class Balance:
# Class 0: 381, Percent: 50.20%
# Class 1: 378, Percent: 49.80%

# %% [markdown]
# #Define Models
# Define Bi-LSTM Model
#
#
# ```
# class BiLSTMModel(torch.nn.Module):
#     def __init__(self, input_dim, hidden_dim, dropout, output_dim):
#         super().__init__()
#         self.lstm = torch.nn.LSTM(
#             input_dim, hidden_dim, batch_first=True, bidirectional=True
#         )
#         self.dropout = torch.nn.Dropout(dropout)
#         self.fc = torch.nn.Linear(hidden_dim * 2, output_dim)  # times 2 for bidirectional
#
# ```
#
#
#
#     def forward(self, x):
#         # Reshape x: [batch_size, input_dim] -> [batch_size, seq_len=1, input_dim]
#         x = x.unsqueeze(1)
#         lstm_out, _ = self.lstm(x)  # [batch_size, 1, hidden_dim*2]
#         x = self.dropout(lstm_out[:, -1, :])   # last output
#         return self.fc(x)  # [batch_size, output_dim]
#
#
# Set manual hyperparameter loop for find the best Hyperparameter
#
#
# ```
# configs = [
#     {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005},
#     {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005},
#     {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005},
#     {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001},
#     {'hidden_dim': 192, 'dropout': 0.4, 'lr': 0.0007}
# ]
# ```

# %%
# Example model class - adjust only if your actual class has different arguments!
class BiLSTMModel(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, dropout, output_dim):
        super().__init__()
        self.lstm = torch.nn.LSTM(
            input_dim, hidden_dim, batch_first=True, bidirectional=True
        )
        self.dropout = torch.nn.Dropout(dropout)
        self.fc = torch.nn.Linear(hidden_dim * 2, output_dim)  # times 2 for bidirectional

    def forward(self, x):
        # Reshape x: [batch_size, input_dim] -> [batch_size, seq_len=1, input_dim]
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)  # [batch_size, 1, hidden_dim*2]
        x = self.dropout(lstm_out[:, -1, :])   # last output
        return self.fc(x)  # [batch_size, output_dim]

# %% [markdown]
# ##PDB Hyperparameter grid

# %%
# -- PDB Hyperparameter grid --
hidden_dims_pdb = [128, 256, 512]
dropouts_pdb = [0.1, 0.3, 0.5]
lrs_pdb = [0.0005, 0.001, 0.002]
batch_sizes_pdb = [16, 32, 64]

grid_pdb = list(itertools.product(hidden_dims_pdb, dropouts_pdb, lrs_pdb, batch_sizes_pdb))

configs_pdb = [
    {'hidden_dim': h, 'dropout': d, 'lr': lr, 'batch_size': bs}
    for h, d, lr, bs in grid_pdb
]
results_pdb = []

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# PDB dataset loaders (set these up before this block!)
pdb_train_dataset = TensorDataset(torch.tensor(x_pdb_train, dtype=torch.float32), torch.tensor(y_pdb_train, dtype=torch.long))
pdb_val_dataset = TensorDataset(torch.tensor(x_pdb_val, dtype=torch.float32), torch.tensor(y_pdb_val, dtype=torch.long))

# Make sure you use configs_pdb and results_pdb for this block!
for i, config in enumerate(configs_pdb):
    print(f"\nConfig {i+1}/{len(configs_pdb)}: {config}")

    train_loader = DataLoader(pdb_train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(pdb_val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = BiLSTMModel(input_dim=1280, hidden_dim=config['hidden_dim'],
                        dropout=config['dropout'], output_dim=2).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'])
    criterion = torch.nn.CrossEntropyLoss()
    patience = 5
    best_val_f1 = 0
    best_state = None
    bad_epochs = 0

    # ---- TRACK LOSS ARRAYS HERE ----
    train_losses = []
    val_losses = []

    for epoch in range(1, 31):
        # --- Training ---
        model.train()
        train_loss_epoch = 0.0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss_epoch += loss.item() * xb.size(0)
        train_loss_epoch = train_loss_epoch / len(train_loader.dataset)
        train_losses.append(train_loss_epoch)

        # --- Validation ---
        model.eval()
        val_loss_epoch = 0.0
        all_preds, all_targets = [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                outputs = model(xb)
                loss = criterion(outputs, yb)
                val_loss_epoch += loss.item() * xb.size(0)
                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                all_preds.extend(preds)
                all_targets.extend(yb.cpu().numpy())
        val_loss_epoch = val_loss_epoch / len(val_loader.dataset)
        val_losses.append(val_loss_epoch)

        val_f1 = f1_score(all_targets, all_preds, average='binary')
        val_acc = accuracy_score(all_targets, all_preds)
        print(f"Epoch {epoch}: TrainLoss = {train_loss_epoch:.4f}, ValLoss = {val_loss_epoch:.4f}, Val Acc = {val_acc:.4f}, Val F1 = {val_f1:.4f}")

        # --- Early Stopping ---
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_state = model.state_dict()
            bad_epochs = 0
        else:
            bad_epochs += 1
        if bad_epochs >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

    # --- Log best for summary ---
    results_pdb.append({
        **config,
        'best_val_f1': best_val_f1,
        'train_losses': train_losses,
        'val_losses': val_losses
    })

# --- Find best configuration ---
best_pdb_config = max(results_pdb, key=lambda x: x['best_val_f1'])
print(f"\nBest PDB Config: {best_pdb_config}")
# Out:
# Config 1/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6275, ValLoss = 0.5505, Val Acc = 0.7885, Val F1 = 0.7843
# Epoch 2: TrainLoss = 0.4223, ValLoss = 0.4570, Val Acc = 0.7404, Val F1 = 0.6582
# Epoch 3: TrainLoss = 0.3314, ValLoss = 0.4314, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 4: TrainLoss = 0.2859, ValLoss = 0.4021, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 5: TrainLoss = 0.2480, ValLoss = 0.4147, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 6: TrainLoss = 0.2324, ValLoss = 0.3891, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 7: TrainLoss = 0.1982, ValLoss = 0.3991, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 8: TrainLoss = 0.2150, ValLoss = 0.4344, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.1795, ValLoss = 0.4391, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 10: TrainLoss = 0.1618, ValLoss = 0.4280, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 11: TrainLoss = 0.1460, ValLoss = 0.4164, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 12: TrainLoss = 0.1264, ValLoss = 0.4473, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 13: TrainLoss = 0.1176, ValLoss = 0.4390, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 14: TrainLoss = 0.0999, ValLoss = 0.5619, Val Acc = 0.7500, Val F1 = 0.6667
# Early stopping at epoch 14
#
# Config 2/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6522, ValLoss = 0.6028, Val Acc = 0.7212, Val F1 = 0.5797
# Epoch 2: TrainLoss = 0.5161, ValLoss = 0.4732, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 3: TrainLoss = 0.3731, ValLoss = 0.4020, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 4: TrainLoss = 0.3118, ValLoss = 0.4270, Val Acc = 0.7692, Val F1 = 0.7000
# Epoch 5: TrainLoss = 0.2831, ValLoss = 0.4071, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 6: TrainLoss = 0.2588, ValLoss = 0.3916, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 7: TrainLoss = 0.2306, ValLoss = 0.3912, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 8: TrainLoss = 0.2140, ValLoss = 0.3897, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 9: TrainLoss = 0.2012, ValLoss = 0.4061, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 10: TrainLoss = 0.1781, ValLoss = 0.3902, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 11: TrainLoss = 0.1714, ValLoss = 0.3960, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 12: TrainLoss = 0.1602, ValLoss = 0.3998, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 13: TrainLoss = 0.1335, ValLoss = 0.4113, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 14: TrainLoss = 0.1261, ValLoss = 0.4184, Val Acc = 0.7981, Val F1 = 0.7692
# Early stopping at epoch 14
#
# Config 3/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6673, ValLoss = 0.6398, Val Acc = 0.6635, Val F1 = 0.4444
# Epoch 2: TrainLoss = 0.6018, ValLoss = 0.5789, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 3: TrainLoss = 0.5096, ValLoss = 0.4999, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 4: TrainLoss = 0.4151, ValLoss = 0.4398, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 5: TrainLoss = 0.3493, ValLoss = 0.4169, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 6: TrainLoss = 0.3085, ValLoss = 0.3973, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 7: TrainLoss = 0.2854, ValLoss = 0.4031, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 8: TrainLoss = 0.2643, ValLoss = 0.3862, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 9: TrainLoss = 0.2416, ValLoss = 0.3933, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 10: TrainLoss = 0.2288, ValLoss = 0.4144, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 11: TrainLoss = 0.2255, ValLoss = 0.3936, Val Acc = 0.8077, Val F1 = 0.7959
# Early stopping at epoch 11
#
# Config 4/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5933, ValLoss = 0.4654, Val Acc = 0.7788, Val F1 = 0.7579
# Epoch 2: TrainLoss = 0.3723, ValLoss = 0.4879, Val Acc = 0.7404, Val F1 = 0.6494
# Epoch 3: TrainLoss = 0.3045, ValLoss = 0.4015, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 4: TrainLoss = 0.2561, ValLoss = 0.4231, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 5: TrainLoss = 0.2318, ValLoss = 0.4629, Val Acc = 0.7500, Val F1 = 0.6667
# Epoch 6: TrainLoss = 0.2183, ValLoss = 0.4955, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 7: TrainLoss = 0.2436, ValLoss = 0.4036, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 8: TrainLoss = 0.1576, ValLoss = 0.5193, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 9: TrainLoss = 0.1429, ValLoss = 0.4673, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 10: TrainLoss = 0.1002, ValLoss = 0.4510, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 11: TrainLoss = 0.0816, ValLoss = 0.4661, Val Acc = 0.7788, Val F1 = 0.7527
# Early stopping at epoch 11
#
# Config 5/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6161, ValLoss = 0.5140, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 2: TrainLoss = 0.3876, ValLoss = 0.3994, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 3: TrainLoss = 0.3082, ValLoss = 0.3898, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 4: TrainLoss = 0.2622, ValLoss = 0.3939, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2272, ValLoss = 0.4023, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 6: TrainLoss = 0.1908, ValLoss = 0.3871, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 7: TrainLoss = 0.1643, ValLoss = 0.4165, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 8: TrainLoss = 0.1418, ValLoss = 0.4395, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.1465, ValLoss = 0.4146, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 10: TrainLoss = 0.1129, ValLoss = 0.4219, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 11: TrainLoss = 0.0928, ValLoss = 0.5621, Val Acc = 0.7596, Val F1 = 0.6914
# Epoch 12: TrainLoss = 0.0771, ValLoss = 0.4850, Val Acc = 0.7981, Val F1 = 0.7789
# Early stopping at epoch 12
#
# Config 6/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6519, ValLoss = 0.6017, Val Acc = 0.7500, Val F1 = 0.6829
# Epoch 2: TrainLoss = 0.5177, ValLoss = 0.4835, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 3: TrainLoss = 0.3776, ValLoss = 0.4087, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 4: TrainLoss = 0.3182, ValLoss = 0.4018, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 5: TrainLoss = 0.2812, ValLoss = 0.4024, Val Acc = 0.8269, Val F1 = 0.8000
# Epoch 6: TrainLoss = 0.2536, ValLoss = 0.3989, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 7: TrainLoss = 0.2201, ValLoss = 0.4120, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 8: TrainLoss = 0.2096, ValLoss = 0.4005, Val Acc = 0.7981, Val F1 = 0.7879
# Early stopping at epoch 8
#
# Config 7/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5460, ValLoss = 0.4360, Val Acc = 0.7885, Val F1 = 0.7843
# Epoch 2: TrainLoss = 0.3298, ValLoss = 0.3992, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 3: TrainLoss = 0.2827, ValLoss = 0.4240, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 4: TrainLoss = 0.2529, ValLoss = 0.5686, Val Acc = 0.7115, Val F1 = 0.5588
# Epoch 5: TrainLoss = 0.2066, ValLoss = 0.3946, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 6: TrainLoss = 0.1436, ValLoss = 0.6000, Val Acc = 0.8173, Val F1 = 0.8288
# Epoch 7: TrainLoss = 0.1583, ValLoss = 0.6131, Val Acc = 0.7115, Val F1 = 0.5588
# Epoch 8: TrainLoss = 0.1023, ValLoss = 0.4421, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.0652, ValLoss = 0.5751, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 10: TrainLoss = 0.0543, ValLoss = 0.6688, Val Acc = 0.7308, Val F1 = 0.6410
# Epoch 11: TrainLoss = 0.0371, ValLoss = 0.7917, Val Acc = 0.7115, Val F1 = 0.6250
# Early stopping at epoch 11
#
# Config 8/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5297, ValLoss = 0.4205, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 2: TrainLoss = 0.3237, ValLoss = 0.4287, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 3: TrainLoss = 0.2717, ValLoss = 0.4856, Val Acc = 0.7500, Val F1 = 0.6579
# Epoch 4: TrainLoss = 0.2363, ValLoss = 0.3901, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 5: TrainLoss = 0.2344, ValLoss = 0.3679, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 6: TrainLoss = 0.2131, ValLoss = 0.4339, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 7: TrainLoss = 0.1432, ValLoss = 0.4127, Val Acc = 0.8462, Val F1 = 0.8431
# Epoch 8: TrainLoss = 0.1066, ValLoss = 0.4661, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 9: TrainLoss = 0.1068, ValLoss = 0.4626, Val Acc = 0.8365, Val F1 = 0.8317
# Epoch 10: TrainLoss = 0.0802, ValLoss = 0.5538, Val Acc = 0.7596, Val F1 = 0.7126
# Epoch 11: TrainLoss = 0.0569, ValLoss = 0.5444, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 12: TrainLoss = 0.0590, ValLoss = 0.6337, Val Acc = 0.7692, Val F1 = 0.7073
# Early stopping at epoch 12
#
# Config 9/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6128, ValLoss = 0.5150, Val Acc = 0.7212, Val F1 = 0.6420
# Epoch 2: TrainLoss = 0.3967, ValLoss = 0.4183, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 3: TrainLoss = 0.3342, ValLoss = 0.4488, Val Acc = 0.8173, Val F1 = 0.8190
# Epoch 4: TrainLoss = 0.2850, ValLoss = 0.3952, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 5: TrainLoss = 0.2477, ValLoss = 0.4007, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 6: TrainLoss = 0.2112, ValLoss = 0.4257, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 7: TrainLoss = 0.2206, ValLoss = 0.4395, Val Acc = 0.8365, Val F1 = 0.8350
# Epoch 8: TrainLoss = 0.1584, ValLoss = 0.4078, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 9: TrainLoss = 0.1322, ValLoss = 0.4563, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 10: TrainLoss = 0.1373, ValLoss = 0.4482, Val Acc = 0.8365, Val F1 = 0.8283
# Epoch 11: TrainLoss = 0.1077, ValLoss = 0.5113, Val Acc = 0.7404, Val F1 = 0.6582
# Epoch 12: TrainLoss = 0.0905, ValLoss = 0.4873, Val Acc = 0.8173, Val F1 = 0.8119
# Early stopping at epoch 12
#
# Config 10/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6327, ValLoss = 0.5546, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 2: TrainLoss = 0.4486, ValLoss = 0.4368, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 3: TrainLoss = 0.3414, ValLoss = 0.4007, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 4: TrainLoss = 0.2959, ValLoss = 0.4010, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 5: TrainLoss = 0.2733, ValLoss = 0.3854, Val Acc = 0.8269, Val F1 = 0.8043
# Epoch 6: TrainLoss = 0.2559, ValLoss = 0.3882, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 7: TrainLoss = 0.2415, ValLoss = 0.4031, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 8: TrainLoss = 0.2129, ValLoss = 0.4050, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 9: TrainLoss = 0.1941, ValLoss = 0.3906, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 10: TrainLoss = 0.1745, ValLoss = 0.4195, Val Acc = 0.7596, Val F1 = 0.7126
# Epoch 11: TrainLoss = 0.1734, ValLoss = 0.3990, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 12: TrainLoss = 0.1972, ValLoss = 0.3930, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 13: TrainLoss = 0.1493, ValLoss = 0.4054, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 14: TrainLoss = 0.1312, ValLoss = 0.3984, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 15: TrainLoss = 0.1169, ValLoss = 0.4063, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 16: TrainLoss = 0.1030, ValLoss = 0.4288, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 17: TrainLoss = 0.0944, ValLoss = 0.4341, Val Acc = 0.7981, Val F1 = 0.7742
# Early stopping at epoch 17
#
# Config 11/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6536, ValLoss = 0.6148, Val Acc = 0.6442, Val F1 = 0.3509
# Epoch 2: TrainLoss = 0.5522, ValLoss = 0.5133, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 3: TrainLoss = 0.4189, ValLoss = 0.4400, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 4: TrainLoss = 0.3379, ValLoss = 0.3964, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 5: TrainLoss = 0.3016, ValLoss = 0.4208, Val Acc = 0.7981, Val F1 = 0.7529
# Epoch 6: TrainLoss = 0.2808, ValLoss = 0.3926, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 7: TrainLoss = 0.2548, ValLoss = 0.3856, Val Acc = 0.8173, Val F1 = 0.7912
# Early stopping at epoch 7
#
# Config 12/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6762, ValLoss = 0.6514, Val Acc = 0.5673, Val F1 = 0.0816
# Epoch 2: TrainLoss = 0.6156, ValLoss = 0.6017, Val Acc = 0.7404, Val F1 = 0.6667
# Epoch 3: TrainLoss = 0.5408, ValLoss = 0.5286, Val Acc = 0.7596, Val F1 = 0.7126
# Epoch 4: TrainLoss = 0.4431, ValLoss = 0.4586, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 5: TrainLoss = 0.3708, ValLoss = 0.4176, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 6: TrainLoss = 0.3241, ValLoss = 0.3971, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 7: TrainLoss = 0.3080, ValLoss = 0.3957, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 8: TrainLoss = 0.2806, ValLoss = 0.4025, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 9: TrainLoss = 0.2664, ValLoss = 0.3834, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 10: TrainLoss = 0.2452, ValLoss = 0.3929, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 11: TrainLoss = 0.2330, ValLoss = 0.3899, Val Acc = 0.7885, Val F1 = 0.7660
# Early stopping at epoch 11
#
# Config 13/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5874, ValLoss = 0.4659, Val Acc = 0.7692, Val F1 = 0.7333
# Epoch 2: TrainLoss = 0.3660, ValLoss = 0.5147, Val Acc = 0.7692, Val F1 = 0.7857
# Epoch 3: TrainLoss = 0.2999, ValLoss = 0.4987, Val Acc = 0.7308, Val F1 = 0.6111
# Epoch 4: TrainLoss = 0.2788, ValLoss = 0.4104, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 5: TrainLoss = 0.2513, ValLoss = 0.4070, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 6: TrainLoss = 0.2289, ValLoss = 0.4221, Val Acc = 0.8269, Val F1 = 0.8302
# Epoch 7: TrainLoss = 0.2017, ValLoss = 0.3800, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 8: TrainLoss = 0.1716, ValLoss = 0.3731, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 9: TrainLoss = 0.1607, ValLoss = 0.3875, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 10: TrainLoss = 0.1257, ValLoss = 0.4581, Val Acc = 0.8462, Val F1 = 0.8431
# Epoch 11: TrainLoss = 0.0981, ValLoss = 0.4652, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 12: TrainLoss = 0.0888, ValLoss = 0.4461, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 13: TrainLoss = 0.0731, ValLoss = 0.5702, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 14: TrainLoss = 0.0614, ValLoss = 0.5125, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 15: TrainLoss = 0.0680, ValLoss = 0.5101, Val Acc = 0.7981, Val F1 = 0.7742
# Early stopping at epoch 15
#
# Config 14/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6254, ValLoss = 0.5448, Val Acc = 0.7404, Val F1 = 0.6667
# Epoch 2: TrainLoss = 0.4274, ValLoss = 0.4487, Val Acc = 0.8077, Val F1 = 0.8077
# Epoch 3: TrainLoss = 0.3435, ValLoss = 0.4271, Val Acc = 0.8077, Val F1 = 0.8077
# Epoch 4: TrainLoss = 0.3132, ValLoss = 0.4066, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 5: TrainLoss = 0.2635, ValLoss = 0.3891, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 6: TrainLoss = 0.2404, ValLoss = 0.4154, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 7: TrainLoss = 0.2123, ValLoss = 0.3916, Val Acc = 0.7981, Val F1 = 0.7742
# Early stopping at epoch 7
#
# Config 15/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6583, ValLoss = 0.6071, Val Acc = 0.7500, Val F1 = 0.6829
# Epoch 2: TrainLoss = 0.5339, ValLoss = 0.4898, Val Acc = 0.7692, Val F1 = 0.7333
# Epoch 3: TrainLoss = 0.3875, ValLoss = 0.4182, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 4: TrainLoss = 0.3195, ValLoss = 0.3951, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 5: TrainLoss = 0.2871, ValLoss = 0.4054, Val Acc = 0.8173, Val F1 = 0.7765
# Epoch 6: TrainLoss = 0.2526, ValLoss = 0.4178, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 7: TrainLoss = 0.2349, ValLoss = 0.3889, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 8: TrainLoss = 0.2193, ValLoss = 0.3775, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 9: TrainLoss = 0.1879, ValLoss = 0.3967, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 10: TrainLoss = 0.1892, ValLoss = 0.3822, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 11: TrainLoss = 0.1532, ValLoss = 0.3901, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 12: TrainLoss = 0.1384, ValLoss = 0.3965, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 13: TrainLoss = 0.1238, ValLoss = 0.4112, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 14: TrainLoss = 0.1149, ValLoss = 0.4228, Val Acc = 0.7788, Val F1 = 0.7416
# Early stopping at epoch 14
#
# Config 16/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5303, ValLoss = 0.5342, Val Acc = 0.7500, Val F1 = 0.7719
# Epoch 2: TrainLoss = 0.3556, ValLoss = 0.4083, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 3: TrainLoss = 0.2898, ValLoss = 0.4020, Val Acc = 0.7788, Val F1 = 0.7160
# Epoch 4: TrainLoss = 0.2661, ValLoss = 0.4523, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 5: TrainLoss = 0.2600, ValLoss = 0.3635, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 6: TrainLoss = 0.2251, ValLoss = 0.4779, Val Acc = 0.8173, Val F1 = 0.8224
# Epoch 7: TrainLoss = 0.1880, ValLoss = 0.4074, Val Acc = 0.7692, Val F1 = 0.7391
# Epoch 8: TrainLoss = 0.1471, ValLoss = 0.5487, Val Acc = 0.7212, Val F1 = 0.6234
# Epoch 9: TrainLoss = 0.1244, ValLoss = 0.4540, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 10: TrainLoss = 0.0875, ValLoss = 0.4434, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 11: TrainLoss = 0.0732, ValLoss = 0.5087, Val Acc = 0.8077, Val F1 = 0.7826
# Early stopping at epoch 11
#
# Config 17/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6016, ValLoss = 0.4669, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 2: TrainLoss = 0.3624, ValLoss = 0.4125, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 3: TrainLoss = 0.2809, ValLoss = 0.4893, Val Acc = 0.7404, Val F1 = 0.6582
# Epoch 4: TrainLoss = 0.2808, ValLoss = 0.5981, Val Acc = 0.7981, Val F1 = 0.8142
# Epoch 5: TrainLoss = 0.2314, ValLoss = 0.3860, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 6: TrainLoss = 0.1924, ValLoss = 0.3951, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 7: TrainLoss = 0.1454, ValLoss = 0.4296, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 8: TrainLoss = 0.1377, ValLoss = 0.4852, Val Acc = 0.8173, Val F1 = 0.8190
# Epoch 9: TrainLoss = 0.1430, ValLoss = 0.5836, Val Acc = 0.7404, Val F1 = 0.6494
# Epoch 10: TrainLoss = 0.1107, ValLoss = 0.4727, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 11: TrainLoss = 0.0724, ValLoss = 0.5756, Val Acc = 0.7500, Val F1 = 0.6829
# Epoch 12: TrainLoss = 0.0796, ValLoss = 0.6173, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 13: TrainLoss = 0.0699, ValLoss = 0.5881, Val Acc = 0.7981, Val F1 = 0.7742
# Early stopping at epoch 13
#
# Config 18/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6415, ValLoss = 0.5452, Val Acc = 0.7212, Val F1 = 0.5915
# Epoch 2: TrainLoss = 0.4221, ValLoss = 0.4113, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 3: TrainLoss = 0.3261, ValLoss = 0.4399, Val Acc = 0.7885, Val F1 = 0.7317
# Epoch 4: TrainLoss = 0.2905, ValLoss = 0.3979, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 5: TrainLoss = 0.2429, ValLoss = 0.4117, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 6: TrainLoss = 0.2002, ValLoss = 0.3666, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 7: TrainLoss = 0.1825, ValLoss = 0.3855, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 8: TrainLoss = 0.1520, ValLoss = 0.4391, Val Acc = 0.7596, Val F1 = 0.7126
# Epoch 9: TrainLoss = 0.1282, ValLoss = 0.5210, Val Acc = 0.7500, Val F1 = 0.6486
# Epoch 10: TrainLoss = 0.1188, ValLoss = 0.5028, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 11: TrainLoss = 0.1065, ValLoss = 0.4179, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 12: TrainLoss = 0.0812, ValLoss = 0.4474, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 13: TrainLoss = 0.0609, ValLoss = 0.4698, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 14: TrainLoss = 0.0526, ValLoss = 0.5088, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 15: TrainLoss = 0.0349, ValLoss = 0.5565, Val Acc = 0.7788, Val F1 = 0.7416
# Early stopping at epoch 15
#
# Config 19/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6516, ValLoss = 0.5897, Val Acc = 0.6923, Val F1 = 0.5152
# Epoch 2: TrainLoss = 0.4863, ValLoss = 0.4490, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 3: TrainLoss = 0.3634, ValLoss = 0.4052, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 4: TrainLoss = 0.3286, ValLoss = 0.3939, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2905, ValLoss = 0.3817, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 6: TrainLoss = 0.2707, ValLoss = 0.3938, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 7: TrainLoss = 0.2446, ValLoss = 0.3723, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.2288, ValLoss = 0.3764, Val Acc = 0.8173, Val F1 = 0.8000
# Early stopping at epoch 8
#
# Config 20/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6613, ValLoss = 0.6256, Val Acc = 0.6827, Val F1 = 0.4590
# Epoch 2: TrainLoss = 0.5693, ValLoss = 0.5321, Val Acc = 0.7596, Val F1 = 0.6753
# Epoch 3: TrainLoss = 0.4370, ValLoss = 0.4406, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 4: TrainLoss = 0.3552, ValLoss = 0.4317, Val Acc = 0.8077, Val F1 = 0.8039
# Epoch 5: TrainLoss = 0.3346, ValLoss = 0.3968, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 6: TrainLoss = 0.3083, ValLoss = 0.4067, Val Acc = 0.7981, Val F1 = 0.7586
# Epoch 7: TrainLoss = 0.2772, ValLoss = 0.3850, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 8: TrainLoss = 0.2575, ValLoss = 0.3889, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 9: TrainLoss = 0.2397, ValLoss = 0.3858, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 10: TrainLoss = 0.2243, ValLoss = 0.3830, Val Acc = 0.7981, Val F1 = 0.7835
# Early stopping at epoch 10
#
# Config 21/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6702, ValLoss = 0.6437, Val Acc = 0.6058, Val F1 = 0.2264
# Epoch 2: TrainLoss = 0.6144, ValLoss = 0.5946, Val Acc = 0.7019, Val F1 = 0.5974
# Epoch 3: TrainLoss = 0.5430, ValLoss = 0.5315, Val Acc = 0.7404, Val F1 = 0.6667
# Epoch 4: TrainLoss = 0.4582, ValLoss = 0.4667, Val Acc = 0.7596, Val F1 = 0.7126
# Epoch 5: TrainLoss = 0.3783, ValLoss = 0.4308, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 6: TrainLoss = 0.3377, ValLoss = 0.4099, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 7: TrainLoss = 0.3092, ValLoss = 0.3983, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.2918, ValLoss = 0.3950, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 9: TrainLoss = 0.2777, ValLoss = 0.4131, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 10: TrainLoss = 0.2679, ValLoss = 0.3849, Val Acc = 0.8077, Val F1 = 0.7872
# Early stopping at epoch 10
#
# Config 22/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6043, ValLoss = 0.4827, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 2: TrainLoss = 0.3942, ValLoss = 0.3953, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 3: TrainLoss = 0.3203, ValLoss = 0.3830, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 4: TrainLoss = 0.2953, ValLoss = 0.3981, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 5: TrainLoss = 0.2707, ValLoss = 0.3942, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 6: TrainLoss = 0.2302, ValLoss = 0.3789, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 7: TrainLoss = 0.2194, ValLoss = 0.4217, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 8: TrainLoss = 0.1955, ValLoss = 0.3833, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 9: TrainLoss = 0.1811, ValLoss = 0.4354, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 10: TrainLoss = 0.1610, ValLoss = 0.4747, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 11: TrainLoss = 0.1536, ValLoss = 0.4039, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 12: TrainLoss = 0.1310, ValLoss = 0.4253, Val Acc = 0.8077, Val F1 = 0.7826
# Early stopping at epoch 12
#
# Config 23/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6367, ValLoss = 0.5644, Val Acc = 0.7692, Val F1 = 0.7447
# Epoch 2: TrainLoss = 0.4512, ValLoss = 0.4365, Val Acc = 0.7981, Val F1 = 0.7470
# Epoch 3: TrainLoss = 0.3383, ValLoss = 0.4229, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 4: TrainLoss = 0.3218, ValLoss = 0.4174, Val Acc = 0.7885, Val F1 = 0.7317
# Epoch 5: TrainLoss = 0.2719, ValLoss = 0.3850, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 6: TrainLoss = 0.2462, ValLoss = 0.3965, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 7: TrainLoss = 0.2092, ValLoss = 0.3916, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 8: TrainLoss = 0.2085, ValLoss = 0.3947, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 9: TrainLoss = 0.1935, ValLoss = 0.3922, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 10: TrainLoss = 0.2070, ValLoss = 0.3857, Val Acc = 0.8462, Val F1 = 0.8431
# Epoch 11: TrainLoss = 0.1682, ValLoss = 0.3920, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 12: TrainLoss = 0.1514, ValLoss = 0.4432, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 13: TrainLoss = 0.1574, ValLoss = 0.3949, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 14: TrainLoss = 0.1310, ValLoss = 0.4150, Val Acc = 0.8365, Val F1 = 0.8317
# Epoch 15: TrainLoss = 0.1049, ValLoss = 0.4367, Val Acc = 0.7788, Val F1 = 0.7356
# Early stopping at epoch 15
#
# Config 24/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6553, ValLoss = 0.6110, Val Acc = 0.6538, Val F1 = 0.4000
# Epoch 2: TrainLoss = 0.5317, ValLoss = 0.4937, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 3: TrainLoss = 0.4032, ValLoss = 0.4253, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 4: TrainLoss = 0.3327, ValLoss = 0.4056, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2957, ValLoss = 0.4064, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 6: TrainLoss = 0.2684, ValLoss = 0.3982, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 7: TrainLoss = 0.2531, ValLoss = 0.4108, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 8: TrainLoss = 0.2403, ValLoss = 0.4541, Val Acc = 0.7788, Val F1 = 0.7089
# Epoch 9: TrainLoss = 0.2202, ValLoss = 0.3976, Val Acc = 0.8173, Val F1 = 0.7957
# Early stopping at epoch 9
#
# Config 25/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5561, ValLoss = 0.4262, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 2: TrainLoss = 0.3689, ValLoss = 0.4715, Val Acc = 0.7500, Val F1 = 0.6667
# Epoch 3: TrainLoss = 0.3182, ValLoss = 0.3862, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 4: TrainLoss = 0.2821, ValLoss = 0.4139, Val Acc = 0.7981, Val F1 = 0.7921
# Epoch 5: TrainLoss = 0.3021, ValLoss = 0.3704, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 6: TrainLoss = 0.2127, ValLoss = 0.4084, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 7: TrainLoss = 0.2258, ValLoss = 0.4168, Val Acc = 0.7885, Val F1 = 0.7442
# Epoch 8: TrainLoss = 0.1934, ValLoss = 0.4163, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 9: TrainLoss = 0.2196, ValLoss = 0.3994, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 10: TrainLoss = 0.1490, ValLoss = 0.4355, Val Acc = 0.8077, Val F1 = 0.8077
# Epoch 11: TrainLoss = 0.1311, ValLoss = 0.4640, Val Acc = 0.8173, Val F1 = 0.7654
# Epoch 12: TrainLoss = 0.1018, ValLoss = 0.4745, Val Acc = 0.7981, Val F1 = 0.7921
# Epoch 13: TrainLoss = 0.1343, ValLoss = 0.5105, Val Acc = 0.7692, Val F1 = 0.7073
# Epoch 14: TrainLoss = 0.1041, ValLoss = 0.4573, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 15: TrainLoss = 0.0676, ValLoss = 0.5233, Val Acc = 0.8077, Val F1 = 0.7917
# Early stopping at epoch 15
#
# Config 26/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5836, ValLoss = 0.4606, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 2: TrainLoss = 0.3661, ValLoss = 0.3967, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 3: TrainLoss = 0.3395, ValLoss = 0.4551, Val Acc = 0.7692, Val F1 = 0.7000
# Epoch 4: TrainLoss = 0.2847, ValLoss = 0.3767, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 5: TrainLoss = 0.2431, ValLoss = 0.3880, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 6: TrainLoss = 0.2178, ValLoss = 0.3987, Val Acc = 0.7885, Val F1 = 0.7442
# Epoch 7: TrainLoss = 0.2021, ValLoss = 0.4017, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 8: TrainLoss = 0.1647, ValLoss = 0.3762, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 9: TrainLoss = 0.1455, ValLoss = 0.4390, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 10: TrainLoss = 0.1679, ValLoss = 0.4779, Val Acc = 0.7596, Val F1 = 0.6988
# Epoch 11: TrainLoss = 0.1291, ValLoss = 0.4314, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 12: TrainLoss = 0.0932, ValLoss = 0.4539, Val Acc = 0.8173, Val F1 = 0.7765
# Epoch 13: TrainLoss = 0.0949, ValLoss = 0.4193, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 14: TrainLoss = 0.0776, ValLoss = 0.4809, Val Acc = 0.7981, Val F1 = 0.7835
# Early stopping at epoch 14
#
# Config 27/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6179, ValLoss = 0.5221, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 2: TrainLoss = 0.4061, ValLoss = 0.4344, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 3: TrainLoss = 0.3267, ValLoss = 0.4100, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 4: TrainLoss = 0.2865, ValLoss = 0.3923, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 5: TrainLoss = 0.2452, ValLoss = 0.3886, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 6: TrainLoss = 0.2095, ValLoss = 0.4028, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 7: TrainLoss = 0.2029, ValLoss = 0.3846, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 8: TrainLoss = 0.1775, ValLoss = 0.4105, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 9: TrainLoss = 0.1692, ValLoss = 0.4206, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 10: TrainLoss = 0.1525, ValLoss = 0.4309, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 11: TrainLoss = 0.1287, ValLoss = 0.4230, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 12: TrainLoss = 0.1362, ValLoss = 0.4665, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 13: TrainLoss = 0.1152, ValLoss = 0.4415, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 14: TrainLoss = 0.0871, ValLoss = 0.4478, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 15: TrainLoss = 0.0815, ValLoss = 0.4880, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 16: TrainLoss = 0.0840, ValLoss = 0.4960, Val Acc = 0.7885, Val F1 = 0.7660
# Early stopping at epoch 16
#
# Config 28/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5943, ValLoss = 0.5634, Val Acc = 0.7019, Val F1 = 0.7395
# Epoch 2: TrainLoss = 0.3882, ValLoss = 0.4126, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 3: TrainLoss = 0.3062, ValLoss = 0.4178, Val Acc = 0.7981, Val F1 = 0.7586
# Epoch 4: TrainLoss = 0.2776, ValLoss = 0.3841, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2510, ValLoss = 0.4292, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 6: TrainLoss = 0.2134, ValLoss = 0.3965, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 7: TrainLoss = 0.1973, ValLoss = 0.3927, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.1845, ValLoss = 0.4166, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 9: TrainLoss = 0.1494, ValLoss = 0.3986, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 10: TrainLoss = 0.1266, ValLoss = 0.4277, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 11: TrainLoss = 0.1150, ValLoss = 0.4727, Val Acc = 0.7885, Val F1 = 0.7317
# Early stopping at epoch 11
#
# Config 29/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6256, ValLoss = 0.5462, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 2: TrainLoss = 0.4668, ValLoss = 0.4489, Val Acc = 0.7596, Val F1 = 0.7059
# Epoch 3: TrainLoss = 0.3504, ValLoss = 0.4271, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 4: TrainLoss = 0.2989, ValLoss = 0.3939, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 5: TrainLoss = 0.2711, ValLoss = 0.3956, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 6: TrainLoss = 0.2444, ValLoss = 0.3997, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 7: TrainLoss = 0.2172, ValLoss = 0.4074, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 8: TrainLoss = 0.1951, ValLoss = 0.3783, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 9: TrainLoss = 0.1787, ValLoss = 0.3945, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 10: TrainLoss = 0.1583, ValLoss = 0.3976, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 11: TrainLoss = 0.1414, ValLoss = 0.4094, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 12: TrainLoss = 0.1292, ValLoss = 0.4078, Val Acc = 0.8077, Val F1 = 0.7917
# Early stopping at epoch 12
#
# Config 30/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6701, ValLoss = 0.6386, Val Acc = 0.5577, Val F1 = 0.0000
# Epoch 2: TrainLoss = 0.5993, ValLoss = 0.5633, Val Acc = 0.7212, Val F1 = 0.6329
# Epoch 3: TrainLoss = 0.4859, ValLoss = 0.4805, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 4: TrainLoss = 0.3935, ValLoss = 0.4354, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 5: TrainLoss = 0.3269, ValLoss = 0.4071, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 6: TrainLoss = 0.2965, ValLoss = 0.3997, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 7: TrainLoss = 0.2745, ValLoss = 0.4035, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 8: TrainLoss = 0.2513, ValLoss = 0.3911, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 9: TrainLoss = 0.2310, ValLoss = 0.4014, Val Acc = 0.8077, Val F1 = 0.7959
# Early stopping at epoch 9
#
# Config 31/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5227, ValLoss = 0.4084, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 2: TrainLoss = 0.3512, ValLoss = 0.4024, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 3: TrainLoss = 0.3001, ValLoss = 0.3891, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 4: TrainLoss = 0.2687, ValLoss = 0.5197, Val Acc = 0.7788, Val F1 = 0.7890
# Epoch 5: TrainLoss = 0.2393, ValLoss = 0.4572, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 6: TrainLoss = 0.2111, ValLoss = 0.4013, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 7: TrainLoss = 0.1816, ValLoss = 0.4456, Val Acc = 0.7500, Val F1 = 0.6977
# Epoch 8: TrainLoss = 0.1777, ValLoss = 0.4611, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 9: TrainLoss = 0.1214, ValLoss = 0.4484, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 10: TrainLoss = 0.0931, ValLoss = 0.5448, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 11: TrainLoss = 0.0835, ValLoss = 0.5091, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 12: TrainLoss = 0.0592, ValLoss = 0.5384, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 13: TrainLoss = 0.0669, ValLoss = 0.9639, Val Acc = 0.7212, Val F1 = 0.5797
# Early stopping at epoch 13
#
# Config 32/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6213, ValLoss = 0.5159, Val Acc = 0.7500, Val F1 = 0.6750
# Epoch 2: TrainLoss = 0.3879, ValLoss = 0.4163, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 3: TrainLoss = 0.3222, ValLoss = 0.4366, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 4: TrainLoss = 0.2672, ValLoss = 0.4042, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 5: TrainLoss = 0.2489, ValLoss = 0.3956, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 6: TrainLoss = 0.2013, ValLoss = 0.4259, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 7: TrainLoss = 0.1753, ValLoss = 0.4850, Val Acc = 0.7596, Val F1 = 0.6835
# Epoch 8: TrainLoss = 0.1748, ValLoss = 0.4613, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 9: TrainLoss = 0.1294, ValLoss = 0.4647, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 10: TrainLoss = 0.1263, ValLoss = 0.4599, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 11: TrainLoss = 0.0837, ValLoss = 0.4813, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 12: TrainLoss = 0.0698, ValLoss = 0.5391, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 13: TrainLoss = 0.0713, ValLoss = 0.5405, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 14: TrainLoss = 0.0868, ValLoss = 0.5479, Val Acc = 0.7885, Val F1 = 0.7442
# Early stopping at epoch 14
#
# Config 33/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6271, ValLoss = 0.5582, Val Acc = 0.7019, Val F1 = 0.5373
# Epoch 2: TrainLoss = 0.4415, ValLoss = 0.4308, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 3: TrainLoss = 0.3300, ValLoss = 0.4073, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 4: TrainLoss = 0.2916, ValLoss = 0.4171, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 5: TrainLoss = 0.2570, ValLoss = 0.3902, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 6: TrainLoss = 0.2171, ValLoss = 0.3858, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 7: TrainLoss = 0.1951, ValLoss = 0.3980, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.1704, ValLoss = 0.4037, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.1451, ValLoss = 0.4209, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 10: TrainLoss = 0.1388, ValLoss = 0.4213, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 11: TrainLoss = 0.1143, ValLoss = 0.4468, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 12: TrainLoss = 0.0926, ValLoss = 0.4569, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 13: TrainLoss = 0.1006, ValLoss = 0.5265, Val Acc = 0.7692, Val F1 = 0.6923
# Epoch 14: TrainLoss = 0.0878, ValLoss = 0.5359, Val Acc = 0.8365, Val F1 = 0.8350
# Epoch 15: TrainLoss = 0.0882, ValLoss = 0.5189, Val Acc = 0.7885, Val F1 = 0.7317
# Epoch 16: TrainLoss = 0.0626, ValLoss = 0.5355, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 17: TrainLoss = 0.0493, ValLoss = 0.5456, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 18: TrainLoss = 0.0411, ValLoss = 0.5896, Val Acc = 0.7885, Val F1 = 0.7381
# Epoch 19: TrainLoss = 0.0315, ValLoss = 0.5969, Val Acc = 0.8077, Val F1 = 0.7826
# Early stopping at epoch 19
#
# Config 34/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5726, ValLoss = 0.4554, Val Acc = 0.8077, Val F1 = 0.8077
# Epoch 2: TrainLoss = 0.3410, ValLoss = 0.3782, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 3: TrainLoss = 0.2901, ValLoss = 0.4052, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 4: TrainLoss = 0.2412, ValLoss = 0.3933, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 5: TrainLoss = 0.1852, ValLoss = 0.4212, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 6: TrainLoss = 0.1544, ValLoss = 0.4936, Val Acc = 0.7596, Val F1 = 0.6753
# Epoch 7: TrainLoss = 0.1287, ValLoss = 0.5470, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 8: TrainLoss = 0.1200, ValLoss = 0.5305, Val Acc = 0.8077, Val F1 = 0.7872
# Early stopping at epoch 8
#
# Config 35/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5294, ValLoss = 0.4575, Val Acc = 0.8077, Val F1 = 0.8039
# Epoch 2: TrainLoss = 0.3133, ValLoss = 0.4030, Val Acc = 0.8173, Val F1 = 0.7816
# Epoch 3: TrainLoss = 0.2716, ValLoss = 0.3527, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 4: TrainLoss = 0.2116, ValLoss = 0.4036, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 5: TrainLoss = 0.1894, ValLoss = 0.4820, Val Acc = 0.7404, Val F1 = 0.6582
# Epoch 6: TrainLoss = 0.1520, ValLoss = 0.4821, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 7: TrainLoss = 0.1593, ValLoss = 0.4772, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 8: TrainLoss = 0.0903, ValLoss = 0.5077, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 9: TrainLoss = 0.0639, ValLoss = 0.6053, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 10: TrainLoss = 0.0475, ValLoss = 0.7666, Val Acc = 0.7692, Val F1 = 0.7000
# Epoch 11: TrainLoss = 0.0342, ValLoss = 0.7467, Val Acc = 0.7885, Val F1 = 0.7755
# Epoch 12: TrainLoss = 0.0333, ValLoss = 0.7491, Val Acc = 0.7692, Val F1 = 0.7391
# Epoch 13: TrainLoss = 0.0469, ValLoss = 0.9404, Val Acc = 0.7500, Val F1 = 0.6829
# Early stopping at epoch 13
#
# Config 36/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6222, ValLoss = 0.5165, Val Acc = 0.7596, Val F1 = 0.7573
# Epoch 2: TrainLoss = 0.3837, ValLoss = 0.4113, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 3: TrainLoss = 0.3156, ValLoss = 0.3727, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 4: TrainLoss = 0.2496, ValLoss = 0.3867, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 5: TrainLoss = 0.2204, ValLoss = 0.4019, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 6: TrainLoss = 0.1958, ValLoss = 0.3759, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 7: TrainLoss = 0.1795, ValLoss = 0.4089, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 8: TrainLoss = 0.1637, ValLoss = 0.4037, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.1381, ValLoss = 0.4766, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 10: TrainLoss = 0.0946, ValLoss = 0.4794, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 11: TrainLoss = 0.0712, ValLoss = 0.5465, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 12: TrainLoss = 0.0605, ValLoss = 0.6334, Val Acc = 0.7788, Val F1 = 0.7416
# Early stopping at epoch 12
#
# Config 37/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6071, ValLoss = 0.5124, Val Acc = 0.7692, Val F1 = 0.7391
# Epoch 2: TrainLoss = 0.4115, ValLoss = 0.4204, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 3: TrainLoss = 0.3184, ValLoss = 0.4129, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 4: TrainLoss = 0.2906, ValLoss = 0.3955, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 5: TrainLoss = 0.2727, ValLoss = 0.4057, Val Acc = 0.7981, Val F1 = 0.7586
# Epoch 6: TrainLoss = 0.2540, ValLoss = 0.3952, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 7: TrainLoss = 0.2256, ValLoss = 0.3806, Val Acc = 0.8077, Val F1 = 0.7917
# Early stopping at epoch 7
#
# Config 38/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6337, ValLoss = 0.5715, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 2: TrainLoss = 0.4724, ValLoss = 0.4445, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 3: TrainLoss = 0.3464, ValLoss = 0.3991, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 4: TrainLoss = 0.2975, ValLoss = 0.3885, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 5: TrainLoss = 0.2729, ValLoss = 0.3864, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 6: TrainLoss = 0.2461, ValLoss = 0.3830, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 7: TrainLoss = 0.2337, ValLoss = 0.3811, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 8: TrainLoss = 0.2111, ValLoss = 0.3911, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 9: TrainLoss = 0.1883, ValLoss = 0.3824, Val Acc = 0.8077, Val F1 = 0.7872
# Early stopping at epoch 9
#
# Config 39/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6604, ValLoss = 0.6192, Val Acc = 0.6827, Val F1 = 0.4762
# Epoch 2: TrainLoss = 0.5650, ValLoss = 0.5405, Val Acc = 0.7115, Val F1 = 0.6053
# Epoch 3: TrainLoss = 0.4500, ValLoss = 0.4583, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 4: TrainLoss = 0.3698, ValLoss = 0.4267, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 5: TrainLoss = 0.3212, ValLoss = 0.4015, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 6: TrainLoss = 0.2925, ValLoss = 0.3931, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 7: TrainLoss = 0.2685, ValLoss = 0.3983, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 8: TrainLoss = 0.2504, ValLoss = 0.3929, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 9: TrainLoss = 0.2298, ValLoss = 0.3855, Val Acc = 0.8077, Val F1 = 0.7727
# Early stopping at epoch 9
#
# Config 40/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5500, ValLoss = 0.4213, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 2: TrainLoss = 0.3577, ValLoss = 0.3846, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 3: TrainLoss = 0.2982, ValLoss = 0.4081, Val Acc = 0.7981, Val F1 = 0.7921
# Epoch 4: TrainLoss = 0.2737, ValLoss = 0.4175, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 5: TrainLoss = 0.2408, ValLoss = 0.3922, Val Acc = 0.8077, Val F1 = 0.7561
# Epoch 6: TrainLoss = 0.2276, ValLoss = 0.3645, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 7: TrainLoss = 0.1791, ValLoss = 0.4035, Val Acc = 0.8077, Val F1 = 0.7826
# Early stopping at epoch 7
#
# Config 41/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5992, ValLoss = 0.4987, Val Acc = 0.7981, Val F1 = 0.7921
# Epoch 2: TrainLoss = 0.3875, ValLoss = 0.4184, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 3: TrainLoss = 0.3068, ValLoss = 0.4615, Val Acc = 0.8077, Val F1 = 0.8113
# Epoch 4: TrainLoss = 0.2966, ValLoss = 0.4045, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 5: TrainLoss = 0.2422, ValLoss = 0.4286, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 6: TrainLoss = 0.2442, ValLoss = 0.4133, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 7: TrainLoss = 0.2137, ValLoss = 0.4044, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 8: TrainLoss = 0.1798, ValLoss = 0.4112, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 9: TrainLoss = 0.1512, ValLoss = 0.4250, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 10: TrainLoss = 0.1369, ValLoss = 0.4290, Val Acc = 0.8173, Val F1 = 0.8000
# Early stopping at epoch 10
#
# Config 42/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6471, ValLoss = 0.5781, Val Acc = 0.7500, Val F1 = 0.6829
# Epoch 2: TrainLoss = 0.4989, ValLoss = 0.4569, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 3: TrainLoss = 0.3579, ValLoss = 0.4052, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 4: TrainLoss = 0.3037, ValLoss = 0.3977, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 5: TrainLoss = 0.2640, ValLoss = 0.4084, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 6: TrainLoss = 0.2392, ValLoss = 0.4009, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 7: TrainLoss = 0.2126, ValLoss = 0.4122, Val Acc = 0.8269, Val F1 = 0.8235
# Epoch 8: TrainLoss = 0.1985, ValLoss = 0.4007, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 9: TrainLoss = 0.1667, ValLoss = 0.3926, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 10: TrainLoss = 0.1493, ValLoss = 0.4085, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 11: TrainLoss = 0.1306, ValLoss = 0.4094, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 12: TrainLoss = 0.1159, ValLoss = 0.4338, Val Acc = 0.8173, Val F1 = 0.8081
# Early stopping at epoch 12
#
# Config 43/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5080, ValLoss = 0.4362, Val Acc = 0.8077, Val F1 = 0.8039
# Epoch 2: TrainLoss = 0.3487, ValLoss = 0.5185, Val Acc = 0.7308, Val F1 = 0.6111
# Epoch 3: TrainLoss = 0.3243, ValLoss = 0.6614, Val Acc = 0.6923, Val F1 = 0.5152
# Epoch 4: TrainLoss = 0.2748, ValLoss = 0.3610, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 5: TrainLoss = 0.2210, ValLoss = 0.4004, Val Acc = 0.8173, Val F1 = 0.7865
# Epoch 6: TrainLoss = 0.2151, ValLoss = 0.4170, Val Acc = 0.8173, Val F1 = 0.8155
# Epoch 7: TrainLoss = 0.1593, ValLoss = 0.4396, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.1351, ValLoss = 0.4808, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 9: TrainLoss = 0.1188, ValLoss = 0.4661, Val Acc = 0.8077, Val F1 = 0.7500
# Epoch 10: TrainLoss = 0.0925, ValLoss = 0.5725, Val Acc = 0.7885, Val F1 = 0.7442
# Epoch 11: TrainLoss = 0.0812, ValLoss = 0.5464, Val Acc = 0.7885, Val F1 = 0.7442
# Early stopping at epoch 11
#
# Config 44/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5821, ValLoss = 0.4337, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 2: TrainLoss = 0.3483, ValLoss = 0.3852, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 3: TrainLoss = 0.2862, ValLoss = 0.4133, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 4: TrainLoss = 0.2582, ValLoss = 0.4433, Val Acc = 0.7788, Val F1 = 0.7473
# Epoch 5: TrainLoss = 0.2154, ValLoss = 0.3989, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 6: TrainLoss = 0.1715, ValLoss = 0.3855, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 7: TrainLoss = 0.1431, ValLoss = 0.4857, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 8: TrainLoss = 0.1341, ValLoss = 0.5354, Val Acc = 0.7885, Val F1 = 0.7755
# Epoch 9: TrainLoss = 0.1117, ValLoss = 0.4896, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 10: TrainLoss = 0.0976, ValLoss = 0.5782, Val Acc = 0.7788, Val F1 = 0.7416
# Early stopping at epoch 10
#
# Config 45/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.5753, ValLoss = 0.5714, Val Acc = 0.6827, Val F1 = 0.4590
# Epoch 2: TrainLoss = 0.3840, ValLoss = 0.4916, Val Acc = 0.7788, Val F1 = 0.7890
# Epoch 3: TrainLoss = 0.3472, ValLoss = 0.3881, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 4: TrainLoss = 0.2656, ValLoss = 0.3930, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 5: TrainLoss = 0.2363, ValLoss = 0.3828, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 6: TrainLoss = 0.2229, ValLoss = 0.3837, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 7: TrainLoss = 0.1784, ValLoss = 0.4005, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 8: TrainLoss = 0.1525, ValLoss = 0.4469, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 9: TrainLoss = 0.1296, ValLoss = 0.4310, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 10: TrainLoss = 0.1149, ValLoss = 0.4251, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 11: TrainLoss = 0.0854, ValLoss = 0.4991, Val Acc = 0.7596, Val F1 = 0.7191
# Early stopping at epoch 11
#
# Config 46/81: {'hidden_dim': 256, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.6299, ValLoss = 0.5522, Val Acc = 0.7115, Val F1 = 0.5714
# Epoch 2: TrainLoss = 0.4350, ValLoss = 0.4456, Val Acc = 0.7885, Val F1 = 0.7179
# Epoch 3: TrainLoss = 0.3503, ValLoss = 0.3888, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 4: TrainLoss = 0.3047, ValLoss = 0.3895, Val Acc = 0.8269, Val F1 = 0.8085
# Epoch 5: TrainLoss = 0.2912, ValLoss = 0.4010, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 6: TrainLoss = 0.2501, ValLoss = 0.4186, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 7: TrainLoss = 0.2433, ValLoss = 0.3932, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 8: TrainLoss = 0.2518, ValLoss = 0.4109, Val Acc = 0.8269, Val F1 = 0.8163
# ...
# Epoch 3: TrainLoss = 0.3057, ValLoss = 0.5041, Val Acc = 0.8077, Val F1 = 0.8214
# Epoch 4: TrainLoss = 0.2688, ValLoss = 0.3802, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 5: TrainLoss = 0.2384, ValLoss = 0.3980, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 6: TrainLoss = 0.2013, ValLoss = 0.4106, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 7: TrainLoss = 0.2051, ValLoss = 0.4914, Val Acc = 0.7500, Val F1 = 0.6750
# Epoch 8: TrainLoss = 0.1555, ValLoss = 0.4327, Val Acc = 0.8077, Val F1 = 0.8000
# Epoch 9: TrainLoss = 0.1234, ValLoss = 0.4502, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 10: TrainLoss = 0.1044, ValLoss = 0.4824, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 11: TrainLoss = 0.0851, ValLoss = 0.4757, Val Acc = 0.8077, Val F1 = 0.7872
# Early stopping at epoch 11
#
# Config 69/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6396, ValLoss = 0.5688, Val Acc = 0.6827, Val F1 = 0.4590
# Epoch 2: TrainLoss = 0.4491, ValLoss = 0.4737, Val Acc = 0.7981, Val F1 = 0.7961
# Epoch 3: TrainLoss = 0.3490, ValLoss = 0.4131, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 4: TrainLoss = 0.2999, ValLoss = 0.3891, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 5: TrainLoss = 0.2731, ValLoss = 0.4497, Val Acc = 0.7596, Val F1 = 0.6835
# Epoch 6: TrainLoss = 0.2434, ValLoss = 0.3918, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 7: TrainLoss = 0.2200, ValLoss = 0.4248, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 8: TrainLoss = 0.2014, ValLoss = 0.4026, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 9: TrainLoss = 0.1696, ValLoss = 0.4674, Val Acc = 0.7596, Val F1 = 0.7059
# Epoch 10: TrainLoss = 0.1807, ValLoss = 0.4351, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 11: TrainLoss = 0.2035, ValLoss = 0.4076, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 12: TrainLoss = 0.1467, ValLoss = 0.4477, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 13: TrainLoss = 0.1128, ValLoss = 0.4770, Val Acc = 0.7500, Val F1 = 0.6977
# Epoch 14: TrainLoss = 0.1046, ValLoss = 0.4524, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 15: TrainLoss = 0.0846, ValLoss = 0.4598, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 16: TrainLoss = 0.0823, ValLoss = 0.6023, Val Acc = 0.7500, Val F1 = 0.6486
# Early stopping at epoch 16
#
# Config 70/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5178, ValLoss = 0.3894, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 2: TrainLoss = 0.3401, ValLoss = 0.4012, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 3: TrainLoss = 0.2798, ValLoss = 0.4243, Val Acc = 0.8269, Val F1 = 0.8043
# Epoch 4: TrainLoss = 0.2507, ValLoss = 0.4391, Val Acc = 0.8269, Val F1 = 0.8302
# Epoch 5: TrainLoss = 0.2630, ValLoss = 0.5415, Val Acc = 0.7115, Val F1 = 0.5946
# Epoch 6: TrainLoss = 0.1992, ValLoss = 0.4195, Val Acc = 0.7596, Val F1 = 0.6914
# Epoch 7: TrainLoss = 0.2314, ValLoss = 0.3712, Val Acc = 0.8558, Val F1 = 0.8454
# Epoch 8: TrainLoss = 0.1306, ValLoss = 0.3820, Val Acc = 0.8365, Val F1 = 0.8211
# Epoch 9: TrainLoss = 0.1115, ValLoss = 0.4598, Val Acc = 0.8269, Val F1 = 0.8125
# Epoch 10: TrainLoss = 0.0733, ValLoss = 0.5718, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 11: TrainLoss = 0.0748, ValLoss = 0.5311, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 12: TrainLoss = 0.0563, ValLoss = 0.7800, Val Acc = 0.7500, Val F1 = 0.6579
# Early stopping at epoch 12
#
# Config 71/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5430, ValLoss = 0.4336, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 2: TrainLoss = 0.3269, ValLoss = 0.4301, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 3: TrainLoss = 0.3545, ValLoss = 0.4798, Val Acc = 0.7500, Val F1 = 0.6286
# Epoch 4: TrainLoss = 0.2603, ValLoss = 0.3993, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 5: TrainLoss = 0.2329, ValLoss = 0.3842, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 6: TrainLoss = 0.1783, ValLoss = 0.4390, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 7: TrainLoss = 0.1542, ValLoss = 0.4785, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 8: TrainLoss = 0.1338, ValLoss = 0.4725, Val Acc = 0.7692, Val F1 = 0.7000
# Epoch 9: TrainLoss = 0.1077, ValLoss = 0.5181, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 10: TrainLoss = 0.0860, ValLoss = 0.5520, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 11: TrainLoss = 0.1268, ValLoss = 0.5540, Val Acc = 0.7981, Val F1 = 0.7789
# Epoch 12: TrainLoss = 0.0417, ValLoss = 0.6428, Val Acc = 0.7692, Val F1 = 0.7209
# Epoch 13: TrainLoss = 0.0408, ValLoss = 0.6296, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 14: TrainLoss = 0.0697, ValLoss = 0.6054, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 15: TrainLoss = 0.0500, ValLoss = 0.7127, Val Acc = 0.7885, Val F1 = 0.7442
# Early stopping at epoch 15
#
# Config 72/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.5158, ValLoss = 0.4525, Val Acc = 0.7692, Val F1 = 0.7073
# Epoch 2: TrainLoss = 0.3262, ValLoss = 0.4059, Val Acc = 0.7981, Val F1 = 0.7879
# Epoch 3: TrainLoss = 0.2784, ValLoss = 0.3838, Val Acc = 0.7981, Val F1 = 0.7835
# Epoch 4: TrainLoss = 0.2203, ValLoss = 0.3868, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 5: TrainLoss = 0.2208, ValLoss = 0.3850, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 6: TrainLoss = 0.1735, ValLoss = 0.4950, Val Acc = 0.7692, Val F1 = 0.7143
# Epoch 7: TrainLoss = 0.1489, ValLoss = 0.4177, Val Acc = 0.7885, Val F1 = 0.7500
# Epoch 8: TrainLoss = 0.1264, ValLoss = 0.5524, Val Acc = 0.7500, Val F1 = 0.6667
# Epoch 9: TrainLoss = 0.0996, ValLoss = 0.4727, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 10: TrainLoss = 0.0844, ValLoss = 0.5133, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 11: TrainLoss = 0.1059, ValLoss = 0.6037, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 12: TrainLoss = 0.0879, ValLoss = 0.6002, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 13: TrainLoss = 0.0446, ValLoss = 0.6311, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 14: TrainLoss = 0.0411, ValLoss = 0.6195, Val Acc = 0.7981, Val F1 = 0.7692
# Early stopping at epoch 14
#
# Config 73/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5847, ValLoss = 0.5554, Val Acc = 0.6827, Val F1 = 0.4590
# Epoch 2: TrainLoss = 0.3968, ValLoss = 0.4386, Val Acc = 0.7885, Val F1 = 0.7317
# Epoch 3: TrainLoss = 0.3320, ValLoss = 0.4253, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 4: TrainLoss = 0.2871, ValLoss = 0.4008, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2824, ValLoss = 0.3990, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 6: TrainLoss = 0.2319, ValLoss = 0.3935, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 7: TrainLoss = 0.2270, ValLoss = 0.4158, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 8: TrainLoss = 0.2183, ValLoss = 0.4002, Val Acc = 0.7788, Val F1 = 0.7473
# Epoch 9: TrainLoss = 0.1769, ValLoss = 0.4333, Val Acc = 0.8173, Val F1 = 0.8190
# Epoch 10: TrainLoss = 0.1674, ValLoss = 0.4014, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 11: TrainLoss = 0.1411, ValLoss = 0.4247, Val Acc = 0.8173, Val F1 = 0.8119
# Epoch 12: TrainLoss = 0.1853, ValLoss = 0.4225, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 13: TrainLoss = 0.1296, ValLoss = 0.4257, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 14: TrainLoss = 0.1336, ValLoss = 0.4745, Val Acc = 0.7692, Val F1 = 0.7209
# Early stopping at epoch 14
#
# Config 74/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6336, ValLoss = 0.5660, Val Acc = 0.7212, Val F1 = 0.6329
# Epoch 2: TrainLoss = 0.4655, ValLoss = 0.4315, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 3: TrainLoss = 0.3766, ValLoss = 0.4472, Val Acc = 0.7981, Val F1 = 0.8037
# Epoch 4: TrainLoss = 0.3141, ValLoss = 0.4022, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 5: TrainLoss = 0.2904, ValLoss = 0.3774, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 6: TrainLoss = 0.2558, ValLoss = 0.3955, Val Acc = 0.8077, Val F1 = 0.7778
# Epoch 7: TrainLoss = 0.2299, ValLoss = 0.3969, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 8: TrainLoss = 0.2132, ValLoss = 0.3982, Val Acc = 0.7981, Val F1 = 0.7640
# Epoch 9: TrainLoss = 0.2135, ValLoss = 0.4092, Val Acc = 0.7981, Val F1 = 0.7470
# Early stopping at epoch 9
#
# Config 75/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6538, ValLoss = 0.6107, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 2: TrainLoss = 0.5497, ValLoss = 0.5168, Val Acc = 0.7885, Val F1 = 0.7609
# Epoch 3: TrainLoss = 0.4263, ValLoss = 0.4474, Val Acc = 0.7500, Val F1 = 0.6977
# Epoch 4: TrainLoss = 0.3618, ValLoss = 0.4483, Val Acc = 0.7596, Val F1 = 0.6667
# Epoch 5: TrainLoss = 0.3253, ValLoss = 0.4140, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 6: TrainLoss = 0.2946, ValLoss = 0.3958, Val Acc = 0.8173, Val F1 = 0.7865
# Early stopping at epoch 6
#
# Config 76/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5966, ValLoss = 0.4761, Val Acc = 0.7981, Val F1 = 0.8000
# Epoch 2: TrainLoss = 0.3586, ValLoss = 0.4292, Val Acc = 0.7981, Val F1 = 0.7342
# Epoch 3: TrainLoss = 0.3158, ValLoss = 0.5772, Val Acc = 0.7692, Val F1 = 0.7931
# Epoch 4: TrainLoss = 0.3188, ValLoss = 0.3705, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 5: TrainLoss = 0.2487, ValLoss = 0.3948, Val Acc = 0.8365, Val F1 = 0.8247
# Epoch 6: TrainLoss = 0.2150, ValLoss = 0.4197, Val Acc = 0.7596, Val F1 = 0.7059
# Epoch 7: TrainLoss = 0.1933, ValLoss = 0.4844, Val Acc = 0.8462, Val F1 = 0.8491
# Epoch 8: TrainLoss = 0.2027, ValLoss = 0.3854, Val Acc = 0.8173, Val F1 = 0.8081
# Epoch 9: TrainLoss = 0.1573, ValLoss = 0.4274, Val Acc = 0.8365, Val F1 = 0.8172
# Epoch 10: TrainLoss = 0.1299, ValLoss = 0.4589, Val Acc = 0.7885, Val F1 = 0.7317
# Epoch 11: TrainLoss = 0.1460, ValLoss = 0.5238, Val Acc = 0.7404, Val F1 = 0.6494
# Epoch 12: TrainLoss = 0.1120, ValLoss = 0.5939, Val Acc = 0.7308, Val F1 = 0.6111
# Early stopping at epoch 12
#
# Config 77/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.6194, ValLoss = 0.5154, Val Acc = 0.7885, Val F1 = 0.7755
# Epoch 2: TrainLoss = 0.3926, ValLoss = 0.3997, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 3: TrainLoss = 0.3188, ValLoss = 0.4268, Val Acc = 0.7788, Val F1 = 0.7229
# Epoch 4: TrainLoss = 0.2779, ValLoss = 0.3848, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 5: TrainLoss = 0.2766, ValLoss = 0.3799, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 6: TrainLoss = 0.2123, ValLoss = 0.3776, Val Acc = 0.8269, Val F1 = 0.8200
# Epoch 7: TrainLoss = 0.2085, ValLoss = 0.3829, Val Acc = 0.8077, Val F1 = 0.7727
# Epoch 8: TrainLoss = 0.2230, ValLoss = 0.4585, Val Acc = 0.7500, Val F1 = 0.6667
# Epoch 9: TrainLoss = 0.2042, ValLoss = 0.3961, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 10: TrainLoss = 0.1493, ValLoss = 0.4113, Val Acc = 0.7885, Val F1 = 0.7660
# Epoch 11: TrainLoss = 0.1410, ValLoss = 0.4105, Val Acc = 0.8365, Val F1 = 0.8317
# Epoch 12: TrainLoss = 0.1067, ValLoss = 0.4589, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 13: TrainLoss = 0.0981, ValLoss = 0.4176, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 14: TrainLoss = 0.0810, ValLoss = 0.5085, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 15: TrainLoss = 0.0777, ValLoss = 0.5346, Val Acc = 0.7981, Val F1 = 0.7470
# Epoch 16: TrainLoss = 0.0734, ValLoss = 0.5728, Val Acc = 0.8365, Val F1 = 0.8247
# Early stopping at epoch 16
#
# Config 78/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.6179, ValLoss = 0.5286, Val Acc = 0.7788, Val F1 = 0.7294
# Epoch 2: TrainLoss = 0.4153, ValLoss = 0.4214, Val Acc = 0.7885, Val F1 = 0.7556
# Epoch 3: TrainLoss = 0.3249, ValLoss = 0.4395, Val Acc = 0.8077, Val F1 = 0.8077
# Epoch 4: TrainLoss = 0.2969, ValLoss = 0.4027, Val Acc = 0.8173, Val F1 = 0.7912
# Epoch 5: TrainLoss = 0.2663, ValLoss = 0.3909, Val Acc = 0.8077, Val F1 = 0.7959
# Epoch 6: TrainLoss = 0.2289, ValLoss = 0.3890, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 7: TrainLoss = 0.2184, ValLoss = 0.3919, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 8: TrainLoss = 0.2270, ValLoss = 0.4335, Val Acc = 0.8269, Val F1 = 0.8302
# Epoch 9: TrainLoss = 0.1876, ValLoss = 0.4124, Val Acc = 0.7692, Val F1 = 0.7273
# Epoch 10: TrainLoss = 0.1646, ValLoss = 0.3987, Val Acc = 0.8077, Val F1 = 0.7872
# Epoch 11: TrainLoss = 0.1520, ValLoss = 0.3989, Val Acc = 0.8173, Val F1 = 0.8000
# Epoch 12: TrainLoss = 0.1224, ValLoss = 0.4155, Val Acc = 0.8269, Val F1 = 0.8163
# Epoch 13: TrainLoss = 0.1219, ValLoss = 0.4476, Val Acc = 0.7788, Val F1 = 0.7356
# Early stopping at epoch 13
#
# Config 79/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.5190, ValLoss = 0.4061, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 2: TrainLoss = 0.3886, ValLoss = 0.4302, Val Acc = 0.7788, Val F1 = 0.7767
# Epoch 3: TrainLoss = 0.3194, ValLoss = 0.5145, Val Acc = 0.7404, Val F1 = 0.6197
# Epoch 4: TrainLoss = 0.2809, ValLoss = 0.3488, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2366, ValLoss = 0.5171, Val Acc = 0.8269, Val F1 = 0.8302
# Epoch 6: TrainLoss = 0.2241, ValLoss = 0.4386, Val Acc = 0.7788, Val F1 = 0.7416
# Epoch 7: TrainLoss = 0.1853, ValLoss = 0.5549, Val Acc = 0.7404, Val F1 = 0.6197
# Epoch 8: TrainLoss = 0.2138, ValLoss = 0.5051, Val Acc = 0.7500, Val F1 = 0.6579
# Epoch 9: TrainLoss = 0.1811, ValLoss = 0.6758, Val Acc = 0.7596, Val F1 = 0.6479
# Epoch 10: TrainLoss = 0.1697, ValLoss = 0.4295, Val Acc = 0.8077, Val F1 = 0.7727
# Early stopping at epoch 10
#
# Config 80/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.5553, ValLoss = 0.4353, Val Acc = 0.7500, Val F1 = 0.6829
# Epoch 2: TrainLoss = 0.3516, ValLoss = 0.3849, Val Acc = 0.8077, Val F1 = 0.7917
# Epoch 3: TrainLoss = 0.3021, ValLoss = 0.4001, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 4: TrainLoss = 0.2568, ValLoss = 0.3899, Val Acc = 0.8173, Val F1 = 0.7957
# Epoch 5: TrainLoss = 0.2284, ValLoss = 0.4019, Val Acc = 0.8173, Val F1 = 0.8041
# Epoch 6: TrainLoss = 0.2373, ValLoss = 0.4612, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 7: TrainLoss = 0.1857, ValLoss = 0.4337, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 8: TrainLoss = 0.1757, ValLoss = 0.4688, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 9: TrainLoss = 0.1449, ValLoss = 0.4350, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 10: TrainLoss = 0.1366, ValLoss = 0.5280, Val Acc = 0.7981, Val F1 = 0.7742
# Epoch 11: TrainLoss = 0.1444, ValLoss = 0.6322, Val Acc = 0.8365, Val F1 = 0.8440
# Epoch 12: TrainLoss = 0.1282, ValLoss = 0.4106, Val Acc = 0.8558, Val F1 = 0.8387
# Epoch 13: TrainLoss = 0.0914, ValLoss = 0.6278, Val Acc = 0.7308, Val F1 = 0.6500
# Epoch 14: TrainLoss = 0.0731, ValLoss = 0.7548, Val Acc = 0.7308, Val F1 = 0.6000
# Epoch 15: TrainLoss = 0.0551, ValLoss = 0.7491, Val Acc = 0.7404, Val F1 = 0.6400
# Epoch 16: TrainLoss = 0.0448, ValLoss = 0.7495, Val Acc = 0.7981, Val F1 = 0.7692
# Early stopping at epoch 16
#
# Config 81/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.5664, ValLoss = 0.4543, Val Acc = 0.7981, Val F1 = 0.7921
# Epoch 2: TrainLoss = 0.3638, ValLoss = 0.4242, Val Acc = 0.7788, Val F1 = 0.7356
# Epoch 3: TrainLoss = 0.3017, ValLoss = 0.3806, Val Acc = 0.8077, Val F1 = 0.7826
# Epoch 4: TrainLoss = 0.2651, ValLoss = 0.4099, Val Acc = 0.8365, Val F1 = 0.8381
# Epoch 5: TrainLoss = 0.2417, ValLoss = 0.3766, Val Acc = 0.7981, Val F1 = 0.7692
# Epoch 6: TrainLoss = 0.2214, ValLoss = 0.4394, Val Acc = 0.8269, Val F1 = 0.8269
# Epoch 7: TrainLoss = 0.2002, ValLoss = 0.4845, Val Acc = 0.7596, Val F1 = 0.6753
# Epoch 8: TrainLoss = 0.2080, ValLoss = 0.4395, Val Acc = 0.8365, Val F1 = 0.8350
# Epoch 9: TrainLoss = 0.1565, ValLoss = 0.4253, Val Acc = 0.8269, Val F1 = 0.8043
# Early stopping at epoch 9
#
# Best PDB Config: {'hidden_dim': 256, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 16, 'best_val_f1': 0.8543689320388349, 'train_losses': [0.5996379166266433, 0.3874104127000328, 0.31514877413698683, 0.27394721172031156, 0.2575330014396607, 0.25814160885591647, 0.21211520944818194, 0.20865407729231744, 0.1710027768852762, 0.17180027909911602, 0.1358306696083477], 'val_losses': [0.4673807621002197, 0.40033567410248977, 0.40092830474560076, 0.40752061284505403, 0.43888671352313113, 0.38977979925962597, 0.4113784913833325, 0.380504500407439, 0.40985438571526456, 0.3877477405162958, 0.42685744166374207]}

# %% [markdown]
# ##UniSwiss hyperparameter Grid

# %%
# -- UniSwiss Hyperparameter grid --
hidden_dims_uni = [128, 256, 512]
dropouts_uni = [0.1, 0.3, 0.5]
lrs_uni = [0.0005, 0.001, 0.002]
batch_sizes_uni = [16, 32, 64]

grid_uni = list(itertools.product(hidden_dims_uni, dropouts_uni, lrs_uni, batch_sizes_uni))

configs_uni = [
    {'hidden_dim': h, 'dropout': d, 'lr': lr, 'batch_size': bs}
    for h, d, lr, bs in grid_uni
]
results_uni = []

# Uniswiss dataset loaders (set these up before this block!)
uni_train_dataset = TensorDataset(torch.tensor(x_uni_train, dtype=torch.float32), torch.tensor(y_uni_train, dtype=torch.long))
uni_val_dataset = TensorDataset(torch.tensor(x_uni_val, dtype=torch.float32), torch.tensor(y_uni_val, dtype=torch.long))

# Make sure you use configs_uni and results_uni for this block!
for i, config in enumerate(configs_uni):
    print(f"\nConfig {i+1}/{len(configs_uni)}: {config}")

    train_loader = DataLoader(uni_train_dataset, batch_size=config['batch_size'], shuffle=True)
    val_loader = DataLoader(uni_val_dataset, batch_size=config['batch_size'], shuffle=False)

    model = BiLSTMModel(input_dim=1280, hidden_dim=config['hidden_dim'],
                        dropout=config['dropout'], output_dim=2).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'])
    criterion = torch.nn.CrossEntropyLoss()
    patience = 5
    best_val_f1 = 0
    best_state = None
    bad_epochs = 0

    # ---- TRACK LOSS ARRAYS HERE ----
    train_losses = []
    val_losses = []

    for epoch in range(1, 31):
        # --- Training ---
        model.train()
        train_loss_epoch = 0.0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss_epoch += loss.item() * xb.size(0)
        train_loss_epoch = train_loss_epoch / len(train_loader.dataset)
        train_losses.append(train_loss_epoch)

        # --- Validation ---
        model.eval()
        val_loss_epoch = 0.0
        all_preds, all_targets = [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                outputs = model(xb)
                loss = criterion(outputs, yb)
                val_loss_epoch += loss.item() * xb.size(0)
                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                all_preds.extend(preds)
                all_targets.extend(yb.cpu().numpy())
        val_loss_epoch = val_loss_epoch / len(val_loader.dataset)
        val_losses.append(val_loss_epoch)

        val_f1 = f1_score(all_targets, all_preds, average='binary')
        val_acc = accuracy_score(all_targets, all_preds)
        print(f"Epoch {epoch}: TrainLoss = {train_loss_epoch:.4f}, ValLoss = {val_loss_epoch:.4f}, Val Acc = {val_acc:.4f}, Val F1 = {val_f1:.4f}")

        # --- Early Stopping ---
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_state = model.state_dict()
            bad_epochs = 0
        else:
            bad_epochs += 1
        if bad_epochs >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

    # --- Log best for summary ---
    results_uni.append({
        **config,
        'best_val_f1': best_val_f1,
        'train_losses': train_losses,
        'val_losses': val_losses
    })

# --- Find best configuration ---
best_uni_config = max(results_uni, key=lambda x: x['best_val_f1'])
print(f"\nBest uni Config: {best_uni_config}")
# Out:
# Config 1/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3684, ValLoss = 0.2662, Val Acc = 0.8849, Val F1 = 0.8820
# Epoch 2: TrainLoss = 0.2657, ValLoss = 0.2465, Val Acc = 0.8862, Val F1 = 0.8847
# Epoch 3: TrainLoss = 0.2412, ValLoss = 0.2365, Val Acc = 0.9061, Val F1 = 0.9039
# Epoch 4: TrainLoss = 0.2315, ValLoss = 0.2473, Val Acc = 0.8902, Val F1 = 0.8926
# Epoch 5: TrainLoss = 0.2166, ValLoss = 0.2338, Val Acc = 0.9034, Val F1 = 0.9023
# Epoch 6: TrainLoss = 0.2047, ValLoss = 0.2321, Val Acc = 0.9101, Val F1 = 0.9084
# Epoch 7: TrainLoss = 0.1934, ValLoss = 0.2498, Val Acc = 0.8995, Val F1 = 0.9018
# Epoch 8: TrainLoss = 0.1838, ValLoss = 0.2417, Val Acc = 0.9034, Val F1 = 0.9048
# Epoch 9: TrainLoss = 0.1703, ValLoss = 0.2544, Val Acc = 0.8929, Val F1 = 0.8886
# Epoch 10: TrainLoss = 0.1606, ValLoss = 0.2597, Val Acc = 0.9034, Val F1 = 0.9056
# Epoch 11: TrainLoss = 0.1527, ValLoss = 0.2432, Val Acc = 0.8981, Val F1 = 0.8958
# Early stopping at epoch 11
#
# Config 2/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3854, ValLoss = 0.2696, Val Acc = 0.8915, Val F1 = 0.8889
# Epoch 2: TrainLoss = 0.2707, ValLoss = 0.2431, Val Acc = 0.9021, Val F1 = 0.9013
# Epoch 3: TrainLoss = 0.2468, ValLoss = 0.2659, Val Acc = 0.8849, Val F1 = 0.8908
# Epoch 4: TrainLoss = 0.2409, ValLoss = 0.2582, Val Acc = 0.8876, Val F1 = 0.8920
# Epoch 5: TrainLoss = 0.2243, ValLoss = 0.2519, Val Acc = 0.9008, Val F1 = 0.9037
# Epoch 6: TrainLoss = 0.2156, ValLoss = 0.2304, Val Acc = 0.9074, Val F1 = 0.9069
# Epoch 7: TrainLoss = 0.2049, ValLoss = 0.2490, Val Acc = 0.8968, Val F1 = 0.8908
# Epoch 8: TrainLoss = 0.1937, ValLoss = 0.2316, Val Acc = 0.9074, Val F1 = 0.9062
# Epoch 9: TrainLoss = 0.1908, ValLoss = 0.2294, Val Acc = 0.9021, Val F1 = 0.9026
# Epoch 10: TrainLoss = 0.1788, ValLoss = 0.2366, Val Acc = 0.9087, Val F1 = 0.9089
# Epoch 11: TrainLoss = 0.1749, ValLoss = 0.2748, Val Acc = 0.8823, Val F1 = 0.8892
# Epoch 12: TrainLoss = 0.1641, ValLoss = 0.2503, Val Acc = 0.8955, Val F1 = 0.8970
# Epoch 13: TrainLoss = 0.1591, ValLoss = 0.2462, Val Acc = 0.9008, Val F1 = 0.8988
# Epoch 14: TrainLoss = 0.1498, ValLoss = 0.2481, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 15: TrainLoss = 0.1365, ValLoss = 0.3034, Val Acc = 0.8915, Val F1 = 0.8972
# Early stopping at epoch 15
#
# Config 3/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4392, ValLoss = 0.2878, Val Acc = 0.8810, Val F1 = 0.8794
# Epoch 2: TrainLoss = 0.2781, ValLoss = 0.2755, Val Acc = 0.8915, Val F1 = 0.8957
# Epoch 3: TrainLoss = 0.2562, ValLoss = 0.2475, Val Acc = 0.8968, Val F1 = 0.8949
# Epoch 4: TrainLoss = 0.2403, ValLoss = 0.2377, Val Acc = 0.9021, Val F1 = 0.8989
# Epoch 5: TrainLoss = 0.2342, ValLoss = 0.2422, Val Acc = 0.8955, Val F1 = 0.8898
# Epoch 6: TrainLoss = 0.2231, ValLoss = 0.2360, Val Acc = 0.9087, Val F1 = 0.9059
# Epoch 7: TrainLoss = 0.2121, ValLoss = 0.2725, Val Acc = 0.8862, Val F1 = 0.8764
# Epoch 8: TrainLoss = 0.2115, ValLoss = 0.2281, Val Acc = 0.9061, Val F1 = 0.9055
# Epoch 9: TrainLoss = 0.2012, ValLoss = 0.3184, Val Acc = 0.8664, Val F1 = 0.8779
# Epoch 10: TrainLoss = 0.1966, ValLoss = 0.2332, Val Acc = 0.8995, Val F1 = 0.8997
# Epoch 11: TrainLoss = 0.1877, ValLoss = 0.2345, Val Acc = 0.9021, Val F1 = 0.9019
# Early stopping at epoch 11
#
# Config 4/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3375, ValLoss = 0.2565, Val Acc = 0.8942, Val F1 = 0.8953
# Epoch 2: TrainLoss = 0.2560, ValLoss = 0.2559, Val Acc = 0.8929, Val F1 = 0.8930
# Epoch 3: TrainLoss = 0.2366, ValLoss = 0.2298, Val Acc = 0.9034, Val F1 = 0.9033
# Epoch 4: TrainLoss = 0.2158, ValLoss = 0.2368, Val Acc = 0.8955, Val F1 = 0.8959
# Epoch 5: TrainLoss = 0.2049, ValLoss = 0.2341, Val Acc = 0.9074, Val F1 = 0.9084
# Epoch 6: TrainLoss = 0.1888, ValLoss = 0.2601, Val Acc = 0.9034, Val F1 = 0.8979
# Epoch 7: TrainLoss = 0.1713, ValLoss = 0.2331, Val Acc = 0.9140, Val F1 = 0.9123
# Epoch 8: TrainLoss = 0.1568, ValLoss = 0.2790, Val Acc = 0.8889, Val F1 = 0.8926
# Epoch 9: TrainLoss = 0.1384, ValLoss = 0.2541, Val Acc = 0.8995, Val F1 = 0.8992
# Epoch 10: TrainLoss = 0.1253, ValLoss = 0.2754, Val Acc = 0.8995, Val F1 = 0.8939
# Epoch 11: TrainLoss = 0.1139, ValLoss = 0.2775, Val Acc = 0.8955, Val F1 = 0.8925
# Epoch 12: TrainLoss = 0.0985, ValLoss = 0.3010, Val Acc = 0.9021, Val F1 = 0.9008
# Early stopping at epoch 12
#
# Config 5/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3564, ValLoss = 0.2740, Val Acc = 0.8876, Val F1 = 0.8920
# Epoch 2: TrainLoss = 0.2646, ValLoss = 0.2579, Val Acc = 0.8915, Val F1 = 0.8943
# Epoch 3: TrainLoss = 0.2392, ValLoss = 0.2631, Val Acc = 0.8915, Val F1 = 0.8965
# Epoch 4: TrainLoss = 0.2217, ValLoss = 0.2427, Val Acc = 0.8995, Val F1 = 0.8939
# Epoch 5: TrainLoss = 0.2113, ValLoss = 0.2254, Val Acc = 0.9127, Val F1 = 0.9096
# Epoch 6: TrainLoss = 0.1937, ValLoss = 0.2272, Val Acc = 0.9101, Val F1 = 0.9071
# Epoch 7: TrainLoss = 0.1819, ValLoss = 0.2356, Val Acc = 0.9048, Val F1 = 0.9062
# Epoch 8: TrainLoss = 0.1712, ValLoss = 0.2562, Val Acc = 0.9008, Val F1 = 0.8968
# Epoch 9: TrainLoss = 0.1540, ValLoss = 0.2615, Val Acc = 0.8929, Val F1 = 0.8955
# Epoch 10: TrainLoss = 0.1408, ValLoss = 0.2691, Val Acc = 0.8955, Val F1 = 0.8975
# Early stopping at epoch 10
#
# Config 6/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3843, ValLoss = 0.2869, Val Acc = 0.8810, Val F1 = 0.8843
# Epoch 2: TrainLoss = 0.2644, ValLoss = 0.2522, Val Acc = 0.9048, Val F1 = 0.9022
# Epoch 3: TrainLoss = 0.2451, ValLoss = 0.2552, Val Acc = 0.8889, Val F1 = 0.8817
# Epoch 4: TrainLoss = 0.2299, ValLoss = 0.2479, Val Acc = 0.8968, Val F1 = 0.8990
# Epoch 5: TrainLoss = 0.2239, ValLoss = 0.2395, Val Acc = 0.8995, Val F1 = 0.8984
# Epoch 6: TrainLoss = 0.2048, ValLoss = 0.2351, Val Acc = 0.9048, Val F1 = 0.9011
# Epoch 7: TrainLoss = 0.1982, ValLoss = 0.2535, Val Acc = 0.8968, Val F1 = 0.8898
# Early stopping at epoch 7
#
# Config 7/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3288, ValLoss = 0.2551, Val Acc = 0.8968, Val F1 = 0.8923
# Epoch 2: TrainLoss = 0.2601, ValLoss = 0.2701, Val Acc = 0.8915, Val F1 = 0.8959
# Epoch 3: TrainLoss = 0.2311, ValLoss = 0.2479, Val Acc = 0.8902, Val F1 = 0.8826
# Epoch 4: TrainLoss = 0.2111, ValLoss = 0.2395, Val Acc = 0.9034, Val F1 = 0.9028
# Epoch 5: TrainLoss = 0.2025, ValLoss = 0.2408, Val Acc = 0.9034, Val F1 = 0.9025
# Epoch 6: TrainLoss = 0.1819, ValLoss = 0.2563, Val Acc = 0.8981, Val F1 = 0.9001
# Epoch 7: TrainLoss = 0.1651, ValLoss = 0.2753, Val Acc = 0.9021, Val F1 = 0.9054
# Epoch 8: TrainLoss = 0.1505, ValLoss = 0.2619, Val Acc = 0.8942, Val F1 = 0.8953
# Epoch 9: TrainLoss = 0.1327, ValLoss = 0.3403, Val Acc = 0.8915, Val F1 = 0.8975
# Epoch 10: TrainLoss = 0.1234, ValLoss = 0.3092, Val Acc = 0.8915, Val F1 = 0.8912
# Epoch 11: TrainLoss = 0.1090, ValLoss = 0.3530, Val Acc = 0.8862, Val F1 = 0.8897
# Epoch 12: TrainLoss = 0.1014, ValLoss = 0.3142, Val Acc = 0.8889, Val F1 = 0.8903
# Early stopping at epoch 12
#
# Config 8/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3312, ValLoss = 0.2527, Val Acc = 0.8981, Val F1 = 0.8975
# Epoch 2: TrainLoss = 0.2549, ValLoss = 0.2391, Val Acc = 0.8968, Val F1 = 0.8932
# Epoch 3: TrainLoss = 0.2380, ValLoss = 0.2336, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 4: TrainLoss = 0.2209, ValLoss = 0.2227, Val Acc = 0.9101, Val F1 = 0.9084
# Epoch 5: TrainLoss = 0.2069, ValLoss = 0.2503, Val Acc = 0.8955, Val F1 = 0.8981
# Epoch 6: TrainLoss = 0.1769, ValLoss = 0.2670, Val Acc = 0.8902, Val F1 = 0.8816
# Epoch 7: TrainLoss = 0.1622, ValLoss = 0.2553, Val Acc = 0.9034, Val F1 = 0.9004
# Epoch 8: TrainLoss = 0.1462, ValLoss = 0.2641, Val Acc = 0.8968, Val F1 = 0.8992
# Epoch 9: TrainLoss = 0.1377, ValLoss = 0.2780, Val Acc = 0.8929, Val F1 = 0.8886
# Early stopping at epoch 9
#
# Config 9/81: {'hidden_dim': 128, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3454, ValLoss = 0.3328, Val Acc = 0.8492, Val F1 = 0.8636
# Epoch 2: TrainLoss = 0.2622, ValLoss = 0.2409, Val Acc = 0.9034, Val F1 = 0.9023
# Epoch 3: TrainLoss = 0.2339, ValLoss = 0.2521, Val Acc = 0.9008, Val F1 = 0.8942
# Epoch 4: TrainLoss = 0.2226, ValLoss = 0.2252, Val Acc = 0.9008, Val F1 = 0.8999
# Epoch 5: TrainLoss = 0.2068, ValLoss = 0.2268, Val Acc = 0.8995, Val F1 = 0.9016
# Epoch 6: TrainLoss = 0.1875, ValLoss = 0.2577, Val Acc = 0.8955, Val F1 = 0.8994
# Epoch 7: TrainLoss = 0.1762, ValLoss = 0.2283, Val Acc = 0.9114, Val F1 = 0.9108
# Epoch 8: TrainLoss = 0.1635, ValLoss = 0.2416, Val Acc = 0.9048, Val F1 = 0.9053
# Epoch 9: TrainLoss = 0.1471, ValLoss = 0.2697, Val Acc = 0.8955, Val F1 = 0.8978
# Epoch 10: TrainLoss = 0.1326, ValLoss = 0.2938, Val Acc = 0.8915, Val F1 = 0.8962
# Epoch 11: TrainLoss = 0.1162, ValLoss = 0.2652, Val Acc = 0.8995, Val F1 = 0.9005
# Epoch 12: TrainLoss = 0.1095, ValLoss = 0.3001, Val Acc = 0.8968, Val F1 = 0.9005
# Early stopping at epoch 12
#
# Config 10/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3645, ValLoss = 0.2644, Val Acc = 0.8902, Val F1 = 0.8915
# Epoch 2: TrainLoss = 0.2720, ValLoss = 0.2422, Val Acc = 0.9021, Val F1 = 0.9024
# Epoch 3: TrainLoss = 0.2508, ValLoss = 0.2357, Val Acc = 0.9008, Val F1 = 0.9009
# Epoch 4: TrainLoss = 0.2350, ValLoss = 0.2389, Val Acc = 0.8968, Val F1 = 0.8992
# Epoch 5: TrainLoss = 0.2227, ValLoss = 0.2567, Val Acc = 0.8889, Val F1 = 0.8934
# Epoch 6: TrainLoss = 0.2146, ValLoss = 0.2365, Val Acc = 0.9034, Val F1 = 0.9046
# Epoch 7: TrainLoss = 0.2058, ValLoss = 0.2773, Val Acc = 0.8836, Val F1 = 0.8911
# Epoch 8: TrainLoss = 0.1976, ValLoss = 0.2178, Val Acc = 0.9101, Val F1 = 0.9086
# Epoch 9: TrainLoss = 0.1867, ValLoss = 0.2663, Val Acc = 0.8796, Val F1 = 0.8829
# Epoch 10: TrainLoss = 0.1763, ValLoss = 0.2348, Val Acc = 0.9034, Val F1 = 0.9015
# Epoch 11: TrainLoss = 0.1738, ValLoss = 0.2344, Val Acc = 0.9087, Val F1 = 0.9053
# Epoch 12: TrainLoss = 0.1631, ValLoss = 0.2352, Val Acc = 0.9021, Val F1 = 0.9019
# Epoch 13: TrainLoss = 0.1540, ValLoss = 0.2432, Val Acc = 0.8995, Val F1 = 0.9008
# Early stopping at epoch 13
#
# Config 11/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3905, ValLoss = 0.2906, Val Acc = 0.8810, Val F1 = 0.8843
# Epoch 2: TrainLoss = 0.2726, ValLoss = 0.2563, Val Acc = 0.8942, Val F1 = 0.8913
# Epoch 3: TrainLoss = 0.2514, ValLoss = 0.2490, Val Acc = 0.8942, Val F1 = 0.8925
# Epoch 4: TrainLoss = 0.2406, ValLoss = 0.2368, Val Acc = 0.9061, Val F1 = 0.9034
# Epoch 5: TrainLoss = 0.2285, ValLoss = 0.2362, Val Acc = 0.8968, Val F1 = 0.8974
# Epoch 6: TrainLoss = 0.2237, ValLoss = 0.2447, Val Acc = 0.8955, Val F1 = 0.8986
# Epoch 7: TrainLoss = 0.2126, ValLoss = 0.2402, Val Acc = 0.9034, Val F1 = 0.8985
# Epoch 8: TrainLoss = 0.2060, ValLoss = 0.2298, Val Acc = 0.9048, Val F1 = 0.9019
# Epoch 9: TrainLoss = 0.2021, ValLoss = 0.2363, Val Acc = 0.8968, Val F1 = 0.8992
# Early stopping at epoch 9
#
# Config 12/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4481, ValLoss = 0.3017, Val Acc = 0.8717, Val F1 = 0.8739
# Epoch 2: TrainLoss = 0.2927, ValLoss = 0.2629, Val Acc = 0.8862, Val F1 = 0.8868
# Epoch 3: TrainLoss = 0.2617, ValLoss = 0.2697, Val Acc = 0.8862, Val F1 = 0.8914
# Epoch 4: TrainLoss = 0.2472, ValLoss = 0.2387, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 5: TrainLoss = 0.2380, ValLoss = 0.2355, Val Acc = 0.8995, Val F1 = 0.8965
# Epoch 6: TrainLoss = 0.2270, ValLoss = 0.2409, Val Acc = 0.8981, Val F1 = 0.8993
# Epoch 7: TrainLoss = 0.2235, ValLoss = 0.2292, Val Acc = 0.9021, Val F1 = 0.9011
# Epoch 8: TrainLoss = 0.2138, ValLoss = 0.2307, Val Acc = 0.9048, Val F1 = 0.9032
# Epoch 9: TrainLoss = 0.2068, ValLoss = 0.2371, Val Acc = 0.8955, Val F1 = 0.8967
# Epoch 10: TrainLoss = 0.2023, ValLoss = 0.2289, Val Acc = 0.9074, Val F1 = 0.9064
# Epoch 11: TrainLoss = 0.1943, ValLoss = 0.2379, Val Acc = 0.8929, Val F1 = 0.8947
# Epoch 12: TrainLoss = 0.1916, ValLoss = 0.2374, Val Acc = 0.9048, Val F1 = 0.9014
# Epoch 13: TrainLoss = 0.1871, ValLoss = 0.2598, Val Acc = 0.8862, Val F1 = 0.8909
# Epoch 14: TrainLoss = 0.1803, ValLoss = 0.2401, Val Acc = 0.8942, Val F1 = 0.8961
# Epoch 15: TrainLoss = 0.1781, ValLoss = 0.2454, Val Acc = 0.8942, Val F1 = 0.8966
# Early stopping at epoch 15
#
# Config 13/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3443, ValLoss = 0.2670, Val Acc = 0.8981, Val F1 = 0.9006
# Epoch 2: TrainLoss = 0.2675, ValLoss = 0.2606, Val Acc = 0.8929, Val F1 = 0.8966
# Epoch 3: TrainLoss = 0.2457, ValLoss = 0.2361, Val Acc = 0.9021, Val F1 = 0.8992
# Epoch 4: TrainLoss = 0.2335, ValLoss = 0.2313, Val Acc = 0.9127, Val F1 = 0.9111
# Epoch 5: TrainLoss = 0.2175, ValLoss = 0.2232, Val Acc = 0.9114, Val F1 = 0.9098
# Epoch 6: TrainLoss = 0.2059, ValLoss = 0.2288, Val Acc = 0.9087, Val F1 = 0.9059
# Epoch 7: TrainLoss = 0.1957, ValLoss = 0.2389, Val Acc = 0.8968, Val F1 = 0.8987
# Epoch 8: TrainLoss = 0.1820, ValLoss = 0.2337, Val Acc = 0.9008, Val F1 = 0.9020
# Epoch 9: TrainLoss = 0.1732, ValLoss = 0.3351, Val Acc = 0.8677, Val F1 = 0.8786
# Early stopping at epoch 9
#
# Config 14/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3629, ValLoss = 0.2709, Val Acc = 0.8862, Val F1 = 0.8880
# Epoch 2: TrainLoss = 0.2631, ValLoss = 0.2537, Val Acc = 0.8915, Val F1 = 0.8861
# Epoch 3: TrainLoss = 0.2458, ValLoss = 0.2343, Val Acc = 0.8995, Val F1 = 0.8992
# Epoch 4: TrainLoss = 0.2341, ValLoss = 0.2370, Val Acc = 0.9008, Val F1 = 0.9030
# Epoch 5: TrainLoss = 0.2173, ValLoss = 0.2449, Val Acc = 0.8981, Val F1 = 0.8923
# Epoch 6: TrainLoss = 0.2104, ValLoss = 0.2369, Val Acc = 0.8995, Val F1 = 0.8992
# Epoch 7: TrainLoss = 0.1998, ValLoss = 0.2338, Val Acc = 0.9048, Val F1 = 0.9053
# Epoch 8: TrainLoss = 0.1902, ValLoss = 0.2472, Val Acc = 0.9008, Val F1 = 0.9035
# Epoch 9: TrainLoss = 0.1800, ValLoss = 0.2400, Val Acc = 0.9048, Val F1 = 0.9053
# Epoch 10: TrainLoss = 0.1700, ValLoss = 0.2354, Val Acc = 0.9034, Val F1 = 0.9033
# Epoch 11: TrainLoss = 0.1635, ValLoss = 0.2430, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 12: TrainLoss = 0.1499, ValLoss = 0.2919, Val Acc = 0.8889, Val F1 = 0.8950
# Early stopping at epoch 12
#
# Config 15/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3845, ValLoss = 0.2662, Val Acc = 0.8836, Val F1 = 0.8817
# Epoch 2: TrainLoss = 0.2709, ValLoss = 0.2489, Val Acc = 0.8955, Val F1 = 0.8928
# Epoch 3: TrainLoss = 0.2470, ValLoss = 0.2314, Val Acc = 0.9034, Val F1 = 0.9017
# Epoch 4: TrainLoss = 0.2354, ValLoss = 0.2335, Val Acc = 0.9034, Val F1 = 0.9033
# Epoch 5: TrainLoss = 0.2272, ValLoss = 0.2275, Val Acc = 0.9087, Val F1 = 0.9069
# Epoch 6: TrainLoss = 0.2121, ValLoss = 0.2398, Val Acc = 0.9034, Val F1 = 0.9043
# Epoch 7: TrainLoss = 0.2061, ValLoss = 0.2499, Val Acc = 0.9008, Val F1 = 0.8985
# Epoch 8: TrainLoss = 0.1981, ValLoss = 0.2358, Val Acc = 0.9021, Val F1 = 0.9036
# Epoch 9: TrainLoss = 0.1964, ValLoss = 0.2497, Val Acc = 0.8929, Val F1 = 0.8966
# Epoch 10: TrainLoss = 0.1870, ValLoss = 0.2351, Val Acc = 0.9048, Val F1 = 0.9035
# Early stopping at epoch 10
#
# Config 16/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3461, ValLoss = 0.2685, Val Acc = 0.8902, Val F1 = 0.8855
# Epoch 2: TrainLoss = 0.2682, ValLoss = 0.2393, Val Acc = 0.9074, Val F1 = 0.9072
# Epoch 3: TrainLoss = 0.2563, ValLoss = 0.2476, Val Acc = 0.9008, Val F1 = 0.9037
# Epoch 4: TrainLoss = 0.2353, ValLoss = 0.2393, Val Acc = 0.8968, Val F1 = 0.8932
# Epoch 5: TrainLoss = 0.2235, ValLoss = 0.2344, Val Acc = 0.9114, Val F1 = 0.9083
# Epoch 6: TrainLoss = 0.2105, ValLoss = 0.2698, Val Acc = 0.8929, Val F1 = 0.8979
# Epoch 7: TrainLoss = 0.1983, ValLoss = 0.2402, Val Acc = 0.9061, Val F1 = 0.9079
# Epoch 8: TrainLoss = 0.1893, ValLoss = 0.2312, Val Acc = 0.9008, Val F1 = 0.8971
# Epoch 9: TrainLoss = 0.1795, ValLoss = 0.2307, Val Acc = 0.9114, Val F1 = 0.9103
# Epoch 10: TrainLoss = 0.1705, ValLoss = 0.2610, Val Acc = 0.8942, Val F1 = 0.8977
# Epoch 11: TrainLoss = 0.1600, ValLoss = 0.2365, Val Acc = 0.9074, Val F1 = 0.9038
# Epoch 12: TrainLoss = 0.1474, ValLoss = 0.2451, Val Acc = 0.9061, Val F1 = 0.9021
# Epoch 13: TrainLoss = 0.1423, ValLoss = 0.2606, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 14: TrainLoss = 0.1323, ValLoss = 0.2545, Val Acc = 0.9048, Val F1 = 0.9053
# Early stopping at epoch 14
#
# Config 17/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3439, ValLoss = 0.2672, Val Acc = 0.8876, Val F1 = 0.8880
# Epoch 2: TrainLoss = 0.2634, ValLoss = 0.2702, Val Acc = 0.8876, Val F1 = 0.8917
# Epoch 3: TrainLoss = 0.2529, ValLoss = 0.2336, Val Acc = 0.8968, Val F1 = 0.8943
# Epoch 4: TrainLoss = 0.2296, ValLoss = 0.2310, Val Acc = 0.9008, Val F1 = 0.8971
# Epoch 5: TrainLoss = 0.2189, ValLoss = 0.2501, Val Acc = 0.8929, Val F1 = 0.8883
# Epoch 6: TrainLoss = 0.2095, ValLoss = 0.2369, Val Acc = 0.8929, Val F1 = 0.8877
# Epoch 7: TrainLoss = 0.1981, ValLoss = 0.2288, Val Acc = 0.9140, Val F1 = 0.9123
# Epoch 8: TrainLoss = 0.1822, ValLoss = 0.2395, Val Acc = 0.9061, Val F1 = 0.9037
# Epoch 9: TrainLoss = 0.1785, ValLoss = 0.2537, Val Acc = 0.9008, Val F1 = 0.8985
# Epoch 10: TrainLoss = 0.1683, ValLoss = 0.2480, Val Acc = 0.9021, Val F1 = 0.9024
# Epoch 11: TrainLoss = 0.1487, ValLoss = 0.2519, Val Acc = 0.9074, Val F1 = 0.9093
# Epoch 12: TrainLoss = 0.1383, ValLoss = 0.2774, Val Acc = 0.9061, Val F1 = 0.9060
# Early stopping at epoch 12
#
# Config 18/81: {'hidden_dim': 128, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3587, ValLoss = 0.2570, Val Acc = 0.8981, Val F1 = 0.8955
# Epoch 2: TrainLoss = 0.2723, ValLoss = 0.2807, Val Acc = 0.8836, Val F1 = 0.8908
# Epoch 3: TrainLoss = 0.2459, ValLoss = 0.2385, Val Acc = 0.9061, Val F1 = 0.9079
# Epoch 4: TrainLoss = 0.2260, ValLoss = 0.2392, Val Acc = 0.9048, Val F1 = 0.9065
# Epoch 5: TrainLoss = 0.2272, ValLoss = 0.2507, Val Acc = 0.8929, Val F1 = 0.8966
# Epoch 6: TrainLoss = 0.2115, ValLoss = 0.2330, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 7: TrainLoss = 0.1923, ValLoss = 0.2678, Val Acc = 0.8889, Val F1 = 0.8947
# Epoch 8: TrainLoss = 0.1840, ValLoss = 0.2548, Val Acc = 0.8929, Val F1 = 0.8864
# Early stopping at epoch 8
#
# Config 19/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3737, ValLoss = 0.2782, Val Acc = 0.8836, Val F1 = 0.8872
# Epoch 2: TrainLoss = 0.2801, ValLoss = 0.2502, Val Acc = 0.8955, Val F1 = 0.8962
# Epoch 3: TrainLoss = 0.2587, ValLoss = 0.2608, Val Acc = 0.8889, Val F1 = 0.8814
# Epoch 4: TrainLoss = 0.2507, ValLoss = 0.2357, Val Acc = 0.8968, Val F1 = 0.8940
# Epoch 5: TrainLoss = 0.2356, ValLoss = 0.2313, Val Acc = 0.8995, Val F1 = 0.8978
# Epoch 6: TrainLoss = 0.2243, ValLoss = 0.2279, Val Acc = 0.9087, Val F1 = 0.9091
# Epoch 7: TrainLoss = 0.2224, ValLoss = 0.2611, Val Acc = 0.8981, Val F1 = 0.8905
# Epoch 8: TrainLoss = 0.2122, ValLoss = 0.2308, Val Acc = 0.9034, Val F1 = 0.9001
# Epoch 9: TrainLoss = 0.2029, ValLoss = 0.2302, Val Acc = 0.9087, Val F1 = 0.9091
# Epoch 10: TrainLoss = 0.1965, ValLoss = 0.2519, Val Acc = 0.8981, Val F1 = 0.9019
# Epoch 11: TrainLoss = 0.1907, ValLoss = 0.2355, Val Acc = 0.9008, Val F1 = 0.8982
# Early stopping at epoch 11
#
# Config 20/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.4125, ValLoss = 0.2817, Val Acc = 0.8796, Val F1 = 0.8801
# Epoch 2: TrainLoss = 0.2801, ValLoss = 0.2543, Val Acc = 0.8915, Val F1 = 0.8910
# Epoch 3: TrainLoss = 0.2627, ValLoss = 0.2524, Val Acc = 0.8942, Val F1 = 0.8950
# Epoch 4: TrainLoss = 0.2453, ValLoss = 0.2428, Val Acc = 0.9008, Val F1 = 0.9012
# Epoch 5: TrainLoss = 0.2395, ValLoss = 0.2315, Val Acc = 0.9034, Val F1 = 0.9020
# Epoch 6: TrainLoss = 0.2352, ValLoss = 0.2311, Val Acc = 0.9034, Val F1 = 0.9031
# Epoch 7: TrainLoss = 0.2233, ValLoss = 0.2382, Val Acc = 0.9008, Val F1 = 0.9020
# Epoch 8: TrainLoss = 0.2174, ValLoss = 0.2257, Val Acc = 0.9087, Val F1 = 0.9071
# Epoch 9: TrainLoss = 0.2115, ValLoss = 0.2387, Val Acc = 0.8995, Val F1 = 0.8959
# Epoch 10: TrainLoss = 0.2045, ValLoss = 0.2282, Val Acc = 0.9101, Val F1 = 0.9074
# Epoch 11: TrainLoss = 0.2020, ValLoss = 0.2266, Val Acc = 0.9061, Val F1 = 0.9052
# Epoch 12: TrainLoss = 0.1957, ValLoss = 0.2426, Val Acc = 0.8968, Val F1 = 0.8982
# Epoch 13: TrainLoss = 0.1918, ValLoss = 0.2304, Val Acc = 0.9074, Val F1 = 0.9072
# Epoch 14: TrainLoss = 0.1833, ValLoss = 0.2299, Val Acc = 0.9048, Val F1 = 0.9045
# Epoch 15: TrainLoss = 0.1850, ValLoss = 0.2574, Val Acc = 0.8981, Val F1 = 0.9022
# Early stopping at epoch 15
#
# Config 21/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4635, ValLoss = 0.3051, Val Acc = 0.8730, Val F1 = 0.8727
# Epoch 2: TrainLoss = 0.2940, ValLoss = 0.2628, Val Acc = 0.8876, Val F1 = 0.8874
# Epoch 3: TrainLoss = 0.2676, ValLoss = 0.2573, Val Acc = 0.8968, Val F1 = 0.8976
# Epoch 4: TrainLoss = 0.2556, ValLoss = 0.2455, Val Acc = 0.8915, Val F1 = 0.8886
# Epoch 5: TrainLoss = 0.2452, ValLoss = 0.2356, Val Acc = 0.9048, Val F1 = 0.9027
# Epoch 6: TrainLoss = 0.2409, ValLoss = 0.2437, Val Acc = 0.9008, Val F1 = 0.9032
# Epoch 7: TrainLoss = 0.2332, ValLoss = 0.2343, Val Acc = 0.8995, Val F1 = 0.8976
# Epoch 8: TrainLoss = 0.2235, ValLoss = 0.2380, Val Acc = 0.9008, Val F1 = 0.9017
# Epoch 9: TrainLoss = 0.2208, ValLoss = 0.2277, Val Acc = 0.9034, Val F1 = 0.9015
# Epoch 10: TrainLoss = 0.2148, ValLoss = 0.2269, Val Acc = 0.9008, Val F1 = 0.8991
# Epoch 11: TrainLoss = 0.2101, ValLoss = 0.2384, Val Acc = 0.9034, Val F1 = 0.8988
# Early stopping at epoch 11
#
# Config 22/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3582, ValLoss = 0.2901, Val Acc = 0.8677, Val F1 = 0.8559
# Epoch 2: TrainLoss = 0.2802, ValLoss = 0.2589, Val Acc = 0.8942, Val F1 = 0.8953
# Epoch 3: TrainLoss = 0.2546, ValLoss = 0.2552, Val Acc = 0.8942, Val F1 = 0.8880
# Epoch 4: TrainLoss = 0.2482, ValLoss = 0.2395, Val Acc = 0.8929, Val F1 = 0.8913
# Epoch 5: TrainLoss = 0.2361, ValLoss = 0.2394, Val Acc = 0.8942, Val F1 = 0.8972
# Epoch 6: TrainLoss = 0.2257, ValLoss = 0.2366, Val Acc = 0.9034, Val F1 = 0.9001
# Epoch 7: TrainLoss = 0.2167, ValLoss = 0.2298, Val Acc = 0.9021, Val F1 = 0.9019
# Epoch 8: TrainLoss = 0.2140, ValLoss = 0.2319, Val Acc = 0.9021, Val F1 = 0.9029
# Epoch 9: TrainLoss = 0.1985, ValLoss = 0.2402, Val Acc = 0.8995, Val F1 = 0.9013
# Epoch 10: TrainLoss = 0.1921, ValLoss = 0.2334, Val Acc = 0.9021, Val F1 = 0.8997
# Epoch 11: TrainLoss = 0.1820, ValLoss = 0.2375, Val Acc = 0.9048, Val F1 = 0.9003
# Epoch 12: TrainLoss = 0.1760, ValLoss = 0.2417, Val Acc = 0.8995, Val F1 = 0.9028
# Epoch 13: TrainLoss = 0.1699, ValLoss = 0.2389, Val Acc = 0.8995, Val F1 = 0.8967
# Early stopping at epoch 13
#
# Config 23/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3801, ValLoss = 0.2630, Val Acc = 0.8889, Val F1 = 0.8883
# Epoch 2: TrainLoss = 0.2809, ValLoss = 0.2643, Val Acc = 0.8836, Val F1 = 0.8757
# Epoch 3: TrainLoss = 0.2580, ValLoss = 0.2535, Val Acc = 0.8955, Val F1 = 0.8916
# Epoch 4: TrainLoss = 0.2449, ValLoss = 0.2350, Val Acc = 0.8968, Val F1 = 0.8960
# Epoch 5: TrainLoss = 0.2336, ValLoss = 0.2423, Val Acc = 0.8981, Val F1 = 0.8986
# Epoch 6: TrainLoss = 0.2259, ValLoss = 0.2884, Val Acc = 0.8823, Val F1 = 0.8913
# Epoch 7: TrainLoss = 0.2132, ValLoss = 0.2306, Val Acc = 0.9021, Val F1 = 0.9013
# Epoch 8: TrainLoss = 0.2046, ValLoss = 0.2343, Val Acc = 0.9034, Val F1 = 0.9007
# Epoch 9: TrainLoss = 0.2007, ValLoss = 0.2459, Val Acc = 0.8929, Val F1 = 0.8858
# Epoch 10: TrainLoss = 0.1888, ValLoss = 0.2261, Val Acc = 0.9074, Val F1 = 0.9067
# Epoch 11: TrainLoss = 0.1904, ValLoss = 0.2288, Val Acc = 0.9074, Val F1 = 0.9054
# Epoch 12: TrainLoss = 0.1752, ValLoss = 0.2489, Val Acc = 0.8929, Val F1 = 0.8924
# Epoch 13: TrainLoss = 0.1735, ValLoss = 0.2538, Val Acc = 0.9021, Val F1 = 0.9044
# Epoch 14: TrainLoss = 0.1669, ValLoss = 0.2340, Val Acc = 0.9074, Val F1 = 0.9057
# Epoch 15: TrainLoss = 0.1526, ValLoss = 0.2305, Val Acc = 0.9061, Val F1 = 0.9055
# Early stopping at epoch 15
#
# Config 24/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3964, ValLoss = 0.2903, Val Acc = 0.8810, Val F1 = 0.8725
# Epoch 2: TrainLoss = 0.2824, ValLoss = 0.2514, Val Acc = 0.8915, Val F1 = 0.8904
# Epoch 3: TrainLoss = 0.2620, ValLoss = 0.2526, Val Acc = 0.8968, Val F1 = 0.8923
# Epoch 4: TrainLoss = 0.2510, ValLoss = 0.2448, Val Acc = 0.9021, Val F1 = 0.9044
# Epoch 5: TrainLoss = 0.2340, ValLoss = 0.2271, Val Acc = 0.9048, Val F1 = 0.9016
# Epoch 6: TrainLoss = 0.2257, ValLoss = 0.2405, Val Acc = 0.9048, Val F1 = 0.9062
# Epoch 7: TrainLoss = 0.2211, ValLoss = 0.2231, Val Acc = 0.9114, Val F1 = 0.9108
# Epoch 8: TrainLoss = 0.2140, ValLoss = 0.2279, Val Acc = 0.9087, Val F1 = 0.9069
# Epoch 9: TrainLoss = 0.2055, ValLoss = 0.2332, Val Acc = 0.9034, Val F1 = 0.8988
# Epoch 10: TrainLoss = 0.2025, ValLoss = 0.2336, Val Acc = 0.9008, Val F1 = 0.9022
# Epoch 11: TrainLoss = 0.1983, ValLoss = 0.2309, Val Acc = 0.9114, Val F1 = 0.9093
# Epoch 12: TrainLoss = 0.1859, ValLoss = 0.2353, Val Acc = 0.9140, Val F1 = 0.9148
# Epoch 13: TrainLoss = 0.1914, ValLoss = 0.2372, Val Acc = 0.9087, Val F1 = 0.9051
# Epoch 14: TrainLoss = 0.1805, ValLoss = 0.2335, Val Acc = 0.9061, Val F1 = 0.9065
# Epoch 15: TrainLoss = 0.1681, ValLoss = 0.2347, Val Acc = 0.9087, Val F1 = 0.9059
# Epoch 16: TrainLoss = 0.1624, ValLoss = 0.2355, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 17: TrainLoss = 0.1599, ValLoss = 0.2427, Val Acc = 0.9061, Val F1 = 0.9084
# Early stopping at epoch 17
#
# Config 25/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3525, ValLoss = 0.2848, Val Acc = 0.8810, Val F1 = 0.8840
# Epoch 2: TrainLoss = 0.2924, ValLoss = 0.2439, Val Acc = 0.9101, Val F1 = 0.9101
# Epoch 3: TrainLoss = 0.2734, ValLoss = 0.2440, Val Acc = 0.9021, Val F1 = 0.9031
# Epoch 4: TrainLoss = 0.2533, ValLoss = 0.2639, Val Acc = 0.8942, Val F1 = 0.8985
# Epoch 5: TrainLoss = 0.2480, ValLoss = 0.2347, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 6: TrainLoss = 0.2404, ValLoss = 0.2632, Val Acc = 0.8902, Val F1 = 0.8833
# Epoch 7: TrainLoss = 0.2335, ValLoss = 0.2246, Val Acc = 0.9074, Val F1 = 0.9069
# Early stopping at epoch 7
#
# Config 26/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3696, ValLoss = 0.2958, Val Acc = 0.8836, Val F1 = 0.8897
# Epoch 2: TrainLoss = 0.2788, ValLoss = 0.2809, Val Acc = 0.8849, Val F1 = 0.8917
# Epoch 3: TrainLoss = 0.2643, ValLoss = 0.2453, Val Acc = 0.9061, Val F1 = 0.9084
# Epoch 4: TrainLoss = 0.2467, ValLoss = 0.2313, Val Acc = 0.9048, Val F1 = 0.9032
# Epoch 5: TrainLoss = 0.2364, ValLoss = 0.2278, Val Acc = 0.9061, Val F1 = 0.9069
# Epoch 6: TrainLoss = 0.2298, ValLoss = 0.2287, Val Acc = 0.9008, Val F1 = 0.8991
# Epoch 7: TrainLoss = 0.2265, ValLoss = 0.2334, Val Acc = 0.9021, Val F1 = 0.9044
# Epoch 8: TrainLoss = 0.2118, ValLoss = 0.2313, Val Acc = 0.9087, Val F1 = 0.9089
# Epoch 9: TrainLoss = 0.2066, ValLoss = 0.2228, Val Acc = 0.9048, Val F1 = 0.9037
# Epoch 10: TrainLoss = 0.1994, ValLoss = 0.2261, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 11: TrainLoss = 0.1838, ValLoss = 0.2593, Val Acc = 0.8942, Val F1 = 0.8982
# Epoch 12: TrainLoss = 0.1814, ValLoss = 0.2384, Val Acc = 0.9048, Val F1 = 0.9048
# Epoch 13: TrainLoss = 0.1727, ValLoss = 0.2429, Val Acc = 0.9087, Val F1 = 0.9112
# Epoch 14: TrainLoss = 0.1669, ValLoss = 0.2368, Val Acc = 0.9087, Val F1 = 0.9076
# Epoch 15: TrainLoss = 0.1635, ValLoss = 0.2589, Val Acc = 0.8995, Val F1 = 0.9013
# Epoch 16: TrainLoss = 0.1527, ValLoss = 0.2421, Val Acc = 0.9061, Val F1 = 0.9069
# Epoch 17: TrainLoss = 0.1450, ValLoss = 0.2808, Val Acc = 0.8929, Val F1 = 0.8979
# Epoch 18: TrainLoss = 0.1374, ValLoss = 0.3137, Val Acc = 0.8955, Val F1 = 0.9014
# Early stopping at epoch 18
#
# Config 27/81: {'hidden_dim': 128, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3594, ValLoss = 0.2685, Val Acc = 0.8876, Val F1 = 0.8886
# Epoch 2: TrainLoss = 0.2794, ValLoss = 0.2476, Val Acc = 0.9021, Val F1 = 0.8989
# Epoch 3: TrainLoss = 0.2603, ValLoss = 0.2491, Val Acc = 0.9034, Val F1 = 0.9053
# Epoch 4: TrainLoss = 0.2453, ValLoss = 0.2309, Val Acc = 0.8968, Val F1 = 0.8957
# Epoch 5: TrainLoss = 0.2374, ValLoss = 0.2352, Val Acc = 0.8968, Val F1 = 0.8987
# Epoch 6: TrainLoss = 0.2277, ValLoss = 0.2285, Val Acc = 0.9008, Val F1 = 0.9004
# Epoch 7: TrainLoss = 0.2151, ValLoss = 0.2230, Val Acc = 0.9114, Val F1 = 0.9083
# Epoch 8: TrainLoss = 0.2127, ValLoss = 0.2226, Val Acc = 0.9074, Val F1 = 0.9069
# Epoch 9: TrainLoss = 0.2025, ValLoss = 0.2258, Val Acc = 0.9008, Val F1 = 0.9025
# Epoch 10: TrainLoss = 0.1904, ValLoss = 0.2573, Val Acc = 0.8955, Val F1 = 0.9001
# Epoch 11: TrainLoss = 0.1852, ValLoss = 0.2587, Val Acc = 0.9008, Val F1 = 0.8951
# Epoch 12: TrainLoss = 0.1823, ValLoss = 0.2534, Val Acc = 0.9008, Val F1 = 0.9045
# Early stopping at epoch 12
#
# Config 28/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3478, ValLoss = 0.2697, Val Acc = 0.8796, Val F1 = 0.8720
# Epoch 2: TrainLoss = 0.2635, ValLoss = 0.2409, Val Acc = 0.8968, Val F1 = 0.8968
# Epoch 3: TrainLoss = 0.2452, ValLoss = 0.2401, Val Acc = 0.9008, Val F1 = 0.8988
# Epoch 4: TrainLoss = 0.2317, ValLoss = 0.2368, Val Acc = 0.9021, Val F1 = 0.9046
# Epoch 5: TrainLoss = 0.2174, ValLoss = 0.2310, Val Acc = 0.9074, Val F1 = 0.9064
# Epoch 6: TrainLoss = 0.2042, ValLoss = 0.2777, Val Acc = 0.8889, Val F1 = 0.8942
# Epoch 7: TrainLoss = 0.2010, ValLoss = 0.2279, Val Acc = 0.9127, Val F1 = 0.9122
# Epoch 8: TrainLoss = 0.1855, ValLoss = 0.2426, Val Acc = 0.9127, Val F1 = 0.9098
# Epoch 9: TrainLoss = 0.1757, ValLoss = 0.2531, Val Acc = 0.9021, Val F1 = 0.9024
# Epoch 10: TrainLoss = 0.1585, ValLoss = 0.2680, Val Acc = 0.9008, Val F1 = 0.9037
# Epoch 11: TrainLoss = 0.1505, ValLoss = 0.2634, Val Acc = 0.8968, Val F1 = 0.8997
# Epoch 12: TrainLoss = 0.1391, ValLoss = 0.2804, Val Acc = 0.8942, Val F1 = 0.8972
# Early stopping at epoch 12
#
# Config 29/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3671, ValLoss = 0.2612, Val Acc = 0.8915, Val F1 = 0.8915
# Epoch 2: TrainLoss = 0.2638, ValLoss = 0.2707, Val Acc = 0.8862, Val F1 = 0.8778
# Epoch 3: TrainLoss = 0.2491, ValLoss = 0.2349, Val Acc = 0.9048, Val F1 = 0.9027
# Epoch 4: TrainLoss = 0.2359, ValLoss = 0.2444, Val Acc = 0.9008, Val F1 = 0.8960
# Epoch 5: TrainLoss = 0.2243, ValLoss = 0.2379, Val Acc = 0.8955, Val F1 = 0.8931
# Epoch 6: TrainLoss = 0.2140, ValLoss = 0.2403, Val Acc = 0.8929, Val F1 = 0.8952
# Epoch 7: TrainLoss = 0.2089, ValLoss = 0.2317, Val Acc = 0.9021, Val F1 = 0.9031
# Epoch 8: TrainLoss = 0.1949, ValLoss = 0.2469, Val Acc = 0.8968, Val F1 = 0.8984
# Epoch 9: TrainLoss = 0.1859, ValLoss = 0.2506, Val Acc = 0.8902, Val F1 = 0.8874
# Epoch 10: TrainLoss = 0.1775, ValLoss = 0.2473, Val Acc = 0.8981, Val F1 = 0.8961
# Epoch 11: TrainLoss = 0.1683, ValLoss = 0.2344, Val Acc = 0.9061, Val F1 = 0.9031
# Epoch 12: TrainLoss = 0.1604, ValLoss = 0.2650, Val Acc = 0.8929, Val F1 = 0.8971
# Early stopping at epoch 12
#
# Config 30/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4060, ValLoss = 0.2752, Val Acc = 0.8876, Val F1 = 0.8856
# Epoch 2: TrainLoss = 0.2727, ValLoss = 0.2575, Val Acc = 0.8876, Val F1 = 0.8892
# Epoch 3: TrainLoss = 0.2541, ValLoss = 0.2483, Val Acc = 0.8981, Val F1 = 0.8993
# Epoch 4: TrainLoss = 0.2376, ValLoss = 0.2476, Val Acc = 0.8995, Val F1 = 0.9018
# Epoch 5: TrainLoss = 0.2280, ValLoss = 0.2351, Val Acc = 0.9008, Val F1 = 0.8996
# Epoch 6: TrainLoss = 0.2212, ValLoss = 0.2357, Val Acc = 0.8968, Val F1 = 0.8960
# Epoch 7: TrainLoss = 0.2165, ValLoss = 0.2289, Val Acc = 0.9048, Val F1 = 0.9045
# Epoch 8: TrainLoss = 0.2066, ValLoss = 0.2414, Val Acc = 0.8942, Val F1 = 0.8961
# Epoch 9: TrainLoss = 0.2001, ValLoss = 0.2288, Val Acc = 0.9140, Val F1 = 0.9118
# Epoch 10: TrainLoss = 0.1946, ValLoss = 0.2523, Val Acc = 0.8849, Val F1 = 0.8886
# Epoch 11: TrainLoss = 0.1858, ValLoss = 0.2368, Val Acc = 0.9048, Val F1 = 0.9008
# Epoch 12: TrainLoss = 0.1837, ValLoss = 0.2300, Val Acc = 0.9114, Val F1 = 0.9093
# Epoch 13: TrainLoss = 0.1758, ValLoss = 0.2403, Val Acc = 0.9034, Val F1 = 0.9023
# Epoch 14: TrainLoss = 0.1728, ValLoss = 0.2434, Val Acc = 0.8955, Val F1 = 0.8931
# Early stopping at epoch 14
#
# Config 31/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3365, ValLoss = 0.2563, Val Acc = 0.8862, Val F1 = 0.8862
# Epoch 2: TrainLoss = 0.2621, ValLoss = 0.2424, Val Acc = 0.8968, Val F1 = 0.8960
# Epoch 3: TrainLoss = 0.2393, ValLoss = 0.2532, Val Acc = 0.8902, Val F1 = 0.8823
# Epoch 4: TrainLoss = 0.2178, ValLoss = 0.2316, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 5: TrainLoss = 0.2049, ValLoss = 0.2420, Val Acc = 0.8915, Val F1 = 0.8880
# Epoch 6: TrainLoss = 0.1872, ValLoss = 0.2291, Val Acc = 0.9087, Val F1 = 0.9089
# Epoch 7: TrainLoss = 0.1697, ValLoss = 0.2497, Val Acc = 0.8981, Val F1 = 0.8964
# Epoch 8: TrainLoss = 0.1525, ValLoss = 0.2787, Val Acc = 0.8915, Val F1 = 0.8930
# Epoch 9: TrainLoss = 0.1347, ValLoss = 0.2478, Val Acc = 0.9127, Val F1 = 0.9103
# Epoch 10: TrainLoss = 0.1180, ValLoss = 0.3450, Val Acc = 0.8783, Val F1 = 0.8844
# Epoch 11: TrainLoss = 0.1085, ValLoss = 0.2813, Val Acc = 0.8942, Val F1 = 0.8919
# Epoch 12: TrainLoss = 0.0973, ValLoss = 0.3224, Val Acc = 0.9008, Val F1 = 0.9037
# Epoch 13: TrainLoss = 0.0883, ValLoss = 0.3486, Val Acc = 0.8823, Val F1 = 0.8883
# Epoch 14: TrainLoss = 0.0763, ValLoss = 0.3107, Val Acc = 0.8995, Val F1 = 0.8973
# Early stopping at epoch 14
#
# Config 32/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3516, ValLoss = 0.2896, Val Acc = 0.8783, Val F1 = 0.8689
# Epoch 2: TrainLoss = 0.2627, ValLoss = 0.3170, Val Acc = 0.8638, Val F1 = 0.8752
# Epoch 3: TrainLoss = 0.2396, ValLoss = 0.2566, Val Acc = 0.8915, Val F1 = 0.8970
# Epoch 4: TrainLoss = 0.2243, ValLoss = 0.2293, Val Acc = 0.8981, Val F1 = 0.8961
# Epoch 5: TrainLoss = 0.2081, ValLoss = 0.2455, Val Acc = 0.8902, Val F1 = 0.8943
# Epoch 6: TrainLoss = 0.1955, ValLoss = 0.2572, Val Acc = 0.8968, Val F1 = 0.9008
# Epoch 7: TrainLoss = 0.1781, ValLoss = 0.2422, Val Acc = 0.9087, Val F1 = 0.9071
# Epoch 8: TrainLoss = 0.1623, ValLoss = 0.2444, Val Acc = 0.9074, Val F1 = 0.9081
# Epoch 9: TrainLoss = 0.1583, ValLoss = 0.2468, Val Acc = 0.9048, Val F1 = 0.9058
# Epoch 10: TrainLoss = 0.1356, ValLoss = 0.2738, Val Acc = 0.8915, Val F1 = 0.8892
# Epoch 11: TrainLoss = 0.1252, ValLoss = 0.2982, Val Acc = 0.8929, Val F1 = 0.8960
# Epoch 12: TrainLoss = 0.1105, ValLoss = 0.2680, Val Acc = 0.9087, Val F1 = 0.9059
# Epoch 13: TrainLoss = 0.1028, ValLoss = 0.2905, Val Acc = 0.9048, Val F1 = 0.9065
# Early stopping at epoch 13
#
# Config 33/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3586, ValLoss = 0.2748, Val Acc = 0.8849, Val F1 = 0.8854
# Epoch 2: TrainLoss = 0.2655, ValLoss = 0.2711, Val Acc = 0.8836, Val F1 = 0.8736
# Epoch 3: TrainLoss = 0.2430, ValLoss = 0.2524, Val Acc = 0.8942, Val F1 = 0.8966
# Epoch 4: TrainLoss = 0.2299, ValLoss = 0.2708, Val Acc = 0.8902, Val F1 = 0.8969
# Epoch 5: TrainLoss = 0.2237, ValLoss = 0.2231, Val Acc = 0.9087, Val F1 = 0.9089
# Epoch 6: TrainLoss = 0.2064, ValLoss = 0.2703, Val Acc = 0.8862, Val F1 = 0.8761
# Epoch 7: TrainLoss = 0.1978, ValLoss = 0.2425, Val Acc = 0.8995, Val F1 = 0.8967
# Epoch 8: TrainLoss = 0.1867, ValLoss = 0.2377, Val Acc = 0.9048, Val F1 = 0.9058
# Epoch 9: TrainLoss = 0.1746, ValLoss = 0.2535, Val Acc = 0.8915, Val F1 = 0.8932
# Epoch 10: TrainLoss = 0.1682, ValLoss = 0.2509, Val Acc = 0.8995, Val F1 = 0.9036
# Early stopping at epoch 10
#
# Config 34/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3260, ValLoss = 0.2667, Val Acc = 0.8876, Val F1 = 0.8895
# Epoch 2: TrainLoss = 0.2624, ValLoss = 0.2394, Val Acc = 0.9061, Val F1 = 0.9034
# Epoch 3: TrainLoss = 0.2389, ValLoss = 0.2545, Val Acc = 0.8955, Val F1 = 0.8886
# Epoch 4: TrainLoss = 0.2181, ValLoss = 0.2616, Val Acc = 0.8929, Val F1 = 0.8960
# Epoch 5: TrainLoss = 0.2042, ValLoss = 0.2490, Val Acc = 0.8942, Val F1 = 0.8904
# Epoch 6: TrainLoss = 0.1844, ValLoss = 0.2585, Val Acc = 0.8968, Val F1 = 0.8960
# Epoch 7: TrainLoss = 0.1720, ValLoss = 0.2544, Val Acc = 0.8981, Val F1 = 0.8983
# Early stopping at epoch 7
#
# Config 35/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3257, ValLoss = 0.2495, Val Acc = 0.9087, Val F1 = 0.9096
# Epoch 2: TrainLoss = 0.2530, ValLoss = 0.2553, Val Acc = 0.8955, Val F1 = 0.8991
# Epoch 3: TrainLoss = 0.2334, ValLoss = 0.2485, Val Acc = 0.8968, Val F1 = 0.8971
# Epoch 4: TrainLoss = 0.2137, ValLoss = 0.2370, Val Acc = 0.8981, Val F1 = 0.8969
# Epoch 5: TrainLoss = 0.2029, ValLoss = 0.2336, Val Acc = 0.9087, Val F1 = 0.9059
# Epoch 6: TrainLoss = 0.1783, ValLoss = 0.2552, Val Acc = 0.8968, Val F1 = 0.8990
# Early stopping at epoch 6
#
# Config 36/81: {'hidden_dim': 256, 'dropout': 0.1, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3481, ValLoss = 0.2756, Val Acc = 0.8889, Val F1 = 0.8934
# Epoch 2: TrainLoss = 0.2602, ValLoss = 0.2311, Val Acc = 0.9021, Val F1 = 0.9000
# Epoch 3: TrainLoss = 0.2430, ValLoss = 0.3048, Val Acc = 0.8638, Val F1 = 0.8755
# Epoch 4: TrainLoss = 0.2184, ValLoss = 0.2308, Val Acc = 0.9021, Val F1 = 0.9026
# Epoch 5: TrainLoss = 0.2087, ValLoss = 0.2228, Val Acc = 0.9127, Val F1 = 0.9106
# Epoch 6: TrainLoss = 0.1888, ValLoss = 0.2554, Val Acc = 0.8889, Val F1 = 0.8923
# Epoch 7: TrainLoss = 0.1790, ValLoss = 0.2357, Val Acc = 0.9074, Val F1 = 0.9049
# Epoch 8: TrainLoss = 0.1598, ValLoss = 0.2514, Val Acc = 0.9008, Val F1 = 0.9052
# Epoch 9: TrainLoss = 0.1458, ValLoss = 0.2878, Val Acc = 0.8902, Val F1 = 0.8940
# Epoch 10: TrainLoss = 0.1243, ValLoss = 0.2756, Val Acc = 0.9021, Val F1 = 0.9016
# Early stopping at epoch 10
#
# Config 37/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3503, ValLoss = 0.2657, Val Acc = 0.8849, Val F1 = 0.8807
# Epoch 2: TrainLoss = 0.2640, ValLoss = 0.2520, Val Acc = 0.8968, Val F1 = 0.8940
# Epoch 3: TrainLoss = 0.2490, ValLoss = 0.2378, Val Acc = 0.8968, Val F1 = 0.8937
# Epoch 4: TrainLoss = 0.2359, ValLoss = 0.2389, Val Acc = 0.9021, Val F1 = 0.8989
# Epoch 5: TrainLoss = 0.2233, ValLoss = 0.2569, Val Acc = 0.8981, Val F1 = 0.9012
# Epoch 6: TrainLoss = 0.2167, ValLoss = 0.2748, Val Acc = 0.8836, Val F1 = 0.8897
# Epoch 7: TrainLoss = 0.2072, ValLoss = 0.2234, Val Acc = 0.9034, Val F1 = 0.9038
# Epoch 8: TrainLoss = 0.1994, ValLoss = 0.2896, Val Acc = 0.8783, Val F1 = 0.8870
# Epoch 9: TrainLoss = 0.1884, ValLoss = 0.2390, Val Acc = 0.9008, Val F1 = 0.9014
# Epoch 10: TrainLoss = 0.1791, ValLoss = 0.2542, Val Acc = 0.8876, Val F1 = 0.8844
# Epoch 11: TrainLoss = 0.1718, ValLoss = 0.2381, Val Acc = 0.9101, Val F1 = 0.9108
# Epoch 12: TrainLoss = 0.1667, ValLoss = 0.2578, Val Acc = 0.8955, Val F1 = 0.8895
# Epoch 13: TrainLoss = 0.1540, ValLoss = 0.2490, Val Acc = 0.9008, Val F1 = 0.8985
# Epoch 14: TrainLoss = 0.1425, ValLoss = 0.2594, Val Acc = 0.9021, Val F1 = 0.9046
# Epoch 15: TrainLoss = 0.1376, ValLoss = 0.2593, Val Acc = 0.9061, Val F1 = 0.9060
# Epoch 16: TrainLoss = 0.1286, ValLoss = 0.2865, Val Acc = 0.8889, Val F1 = 0.8929
# Early stopping at epoch 16
#
# Config 38/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3790, ValLoss = 0.2674, Val Acc = 0.8902, Val F1 = 0.8898
# Epoch 2: TrainLoss = 0.2740, ValLoss = 0.2533, Val Acc = 0.8862, Val F1 = 0.8847
# Epoch 3: TrainLoss = 0.2531, ValLoss = 0.2622, Val Acc = 0.8810, Val F1 = 0.8858
# Epoch 4: TrainLoss = 0.2401, ValLoss = 0.2462, Val Acc = 0.8995, Val F1 = 0.9016
# Epoch 5: TrainLoss = 0.2282, ValLoss = 0.2310, Val Acc = 0.9074, Val F1 = 0.9077
# Epoch 6: TrainLoss = 0.2204, ValLoss = 0.2269, Val Acc = 0.9048, Val F1 = 0.9030
# Epoch 7: TrainLoss = 0.2135, ValLoss = 0.2331, Val Acc = 0.9008, Val F1 = 0.9004
# Epoch 8: TrainLoss = 0.2063, ValLoss = 0.2297, Val Acc = 0.9074, Val F1 = 0.9072
# Epoch 9: TrainLoss = 0.1951, ValLoss = 0.2498, Val Acc = 0.8995, Val F1 = 0.9005
# Epoch 10: TrainLoss = 0.1889, ValLoss = 0.2340, Val Acc = 0.9034, Val F1 = 0.9023
# Early stopping at epoch 10
#
# Config 39/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4135, ValLoss = 0.2839, Val Acc = 0.8810, Val F1 = 0.8822
# Epoch 2: TrainLoss = 0.2791, ValLoss = 0.2602, Val Acc = 0.8836, Val F1 = 0.8833
# Epoch 3: TrainLoss = 0.2563, ValLoss = 0.2504, Val Acc = 0.8915, Val F1 = 0.8892
# Epoch 4: TrainLoss = 0.2419, ValLoss = 0.2448, Val Acc = 0.8955, Val F1 = 0.8913
# Epoch 5: TrainLoss = 0.2343, ValLoss = 0.2342, Val Acc = 0.9034, Val F1 = 0.9036
# Epoch 6: TrainLoss = 0.2253, ValLoss = 0.2601, Val Acc = 0.8929, Val F1 = 0.8867
# Epoch 7: TrainLoss = 0.2264, ValLoss = 0.2361, Val Acc = 0.9034, Val F1 = 0.8993
# Epoch 8: TrainLoss = 0.2160, ValLoss = 0.2433, Val Acc = 0.8929, Val F1 = 0.8955
# Epoch 9: TrainLoss = 0.2127, ValLoss = 0.2391, Val Acc = 0.9008, Val F1 = 0.8980
# Epoch 10: TrainLoss = 0.2051, ValLoss = 0.2308, Val Acc = 0.9101, Val F1 = 0.9096
# Epoch 11: TrainLoss = 0.1953, ValLoss = 0.2307, Val Acc = 0.9087, Val F1 = 0.9066
# Epoch 12: TrainLoss = 0.1961, ValLoss = 0.2389, Val Acc = 0.9074, Val F1 = 0.9030
# Epoch 13: TrainLoss = 0.1854, ValLoss = 0.2385, Val Acc = 0.9008, Val F1 = 0.9014
# Epoch 14: TrainLoss = 0.1815, ValLoss = 0.2510, Val Acc = 0.8955, Val F1 = 0.8978
# Epoch 15: TrainLoss = 0.1764, ValLoss = 0.2388, Val Acc = 0.9008, Val F1 = 0.9017
# Early stopping at epoch 15
#
# Config 40/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3361, ValLoss = 0.2971, Val Acc = 0.8717, Val F1 = 0.8801
# Epoch 2: TrainLoss = 0.2704, ValLoss = 0.2402, Val Acc = 0.9021, Val F1 = 0.9039
# Epoch 3: TrainLoss = 0.2508, ValLoss = 0.2302, Val Acc = 0.9034, Val F1 = 0.9017
# Epoch 4: TrainLoss = 0.2318, ValLoss = 0.2309, Val Acc = 0.9061, Val F1 = 0.9037
# Epoch 5: TrainLoss = 0.2206, ValLoss = 0.2354, Val Acc = 0.9021, Val F1 = 0.9021
# Epoch 6: TrainLoss = 0.2087, ValLoss = 0.2317, Val Acc = 0.9087, Val F1 = 0.9103
# Epoch 7: TrainLoss = 0.1975, ValLoss = 0.2456, Val Acc = 0.9008, Val F1 = 0.9032
# Epoch 8: TrainLoss = 0.1855, ValLoss = 0.2436, Val Acc = 0.9034, Val F1 = 0.9025
# Epoch 9: TrainLoss = 0.1747, ValLoss = 0.2624, Val Acc = 0.9034, Val F1 = 0.9041
# Epoch 10: TrainLoss = 0.1601, ValLoss = 0.2640, Val Acc = 0.9008, Val F1 = 0.8988
# Epoch 11: TrainLoss = 0.1522, ValLoss = 0.2615, Val Acc = 0.9061, Val F1 = 0.9060
# Early stopping at epoch 11
#
# Config 41/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3502, ValLoss = 0.2746, Val Acc = 0.8862, Val F1 = 0.8914
# Epoch 2: TrainLoss = 0.2746, ValLoss = 0.2478, Val Acc = 0.8981, Val F1 = 0.8980
# Epoch 3: TrainLoss = 0.2457, ValLoss = 0.2367, Val Acc = 0.9034, Val F1 = 0.9015
# Epoch 4: TrainLoss = 0.2331, ValLoss = 0.2383, Val Acc = 0.9061, Val F1 = 0.9072
# Epoch 5: TrainLoss = 0.2245, ValLoss = 0.2227, Val Acc = 0.9153, Val F1 = 0.9140
# Epoch 6: TrainLoss = 0.2103, ValLoss = 0.2341, Val Acc = 0.8995, Val F1 = 0.8967
# Epoch 7: TrainLoss = 0.1997, ValLoss = 0.2395, Val Acc = 0.9074, Val F1 = 0.9089
# Epoch 8: TrainLoss = 0.1907, ValLoss = 0.2834, Val Acc = 0.8915, Val F1 = 0.8975
# Epoch 9: TrainLoss = 0.1786, ValLoss = 0.2480, Val Acc = 0.8995, Val F1 = 0.8967
# Epoch 10: TrainLoss = 0.1694, ValLoss = 0.2431, Val Acc = 0.8995, Val F1 = 0.8989
# Early stopping at epoch 10
#
# Config 42/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3709, ValLoss = 0.2758, Val Acc = 0.8862, Val F1 = 0.8897
# Epoch 2: TrainLoss = 0.2703, ValLoss = 0.2839, Val Acc = 0.8730, Val F1 = 0.8663
# Epoch 3: TrainLoss = 0.2463, ValLoss = 0.2416, Val Acc = 0.8968, Val F1 = 0.8982
# Epoch 4: TrainLoss = 0.2334, ValLoss = 0.2671, Val Acc = 0.8849, Val F1 = 0.8889
# Epoch 5: TrainLoss = 0.2408, ValLoss = 0.2293, Val Acc = 0.9048, Val F1 = 0.9024
# Epoch 6: TrainLoss = 0.2198, ValLoss = 0.2250, Val Acc = 0.9114, Val F1 = 0.9091
# Epoch 7: TrainLoss = 0.2056, ValLoss = 0.2230, Val Acc = 0.9114, Val F1 = 0.9098
# Epoch 8: TrainLoss = 0.2026, ValLoss = 0.2426, Val Acc = 0.8981, Val F1 = 0.9001
# Epoch 9: TrainLoss = 0.1896, ValLoss = 0.2554, Val Acc = 0.8836, Val F1 = 0.8869
# Epoch 10: TrainLoss = 0.1845, ValLoss = 0.2522, Val Acc = 0.8968, Val F1 = 0.9013
# Epoch 11: TrainLoss = 0.1730, ValLoss = 0.2377, Val Acc = 0.9048, Val F1 = 0.9045
# Epoch 12: TrainLoss = 0.1661, ValLoss = 0.2360, Val Acc = 0.8995, Val F1 = 0.8978
# Early stopping at epoch 12
#
# Config 43/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3357, ValLoss = 0.2513, Val Acc = 0.8955, Val F1 = 0.8925
# Epoch 2: TrainLoss = 0.2750, ValLoss = 0.2509, Val Acc = 0.8981, Val F1 = 0.8920
# Epoch 3: TrainLoss = 0.2552, ValLoss = 0.2692, Val Acc = 0.8889, Val F1 = 0.8953
# Epoch 4: TrainLoss = 0.2404, ValLoss = 0.2327, Val Acc = 0.9034, Val F1 = 0.9048
# Epoch 5: TrainLoss = 0.2302, ValLoss = 0.2342, Val Acc = 0.9008, Val F1 = 0.8988
# Epoch 6: TrainLoss = 0.2221, ValLoss = 0.3110, Val Acc = 0.8743, Val F1 = 0.8843
# Epoch 7: TrainLoss = 0.2081, ValLoss = 0.2465, Val Acc = 0.9061, Val F1 = 0.9077
# Epoch 8: TrainLoss = 0.1939, ValLoss = 0.2462, Val Acc = 0.8995, Val F1 = 0.8978
# Epoch 9: TrainLoss = 0.1880, ValLoss = 0.2555, Val Acc = 0.9021, Val F1 = 0.9013
# Epoch 10: TrainLoss = 0.1747, ValLoss = 0.2607, Val Acc = 0.9048, Val F1 = 0.9019
# Epoch 11: TrainLoss = 0.1641, ValLoss = 0.2517, Val Acc = 0.9021, Val F1 = 0.9005
# Epoch 12: TrainLoss = 0.1496, ValLoss = 0.2871, Val Acc = 0.8955, Val F1 = 0.8996
# Early stopping at epoch 12
#
# Config 44/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3456, ValLoss = 0.2595, Val Acc = 0.8876, Val F1 = 0.8862
# Epoch 2: TrainLoss = 0.2689, ValLoss = 0.2480, Val Acc = 0.8968, Val F1 = 0.8990
# Epoch 3: TrainLoss = 0.2516, ValLoss = 0.2307, Val Acc = 0.9034, Val F1 = 0.9023
# Epoch 4: TrainLoss = 0.2312, ValLoss = 0.2621, Val Acc = 0.8876, Val F1 = 0.8920
# Epoch 5: TrainLoss = 0.2190, ValLoss = 0.3593, Val Acc = 0.8558, Val F1 = 0.8698
# Epoch 6: TrainLoss = 0.2167, ValLoss = 0.2379, Val Acc = 0.9008, Val F1 = 0.9012
# Epoch 7: TrainLoss = 0.1969, ValLoss = 0.2357, Val Acc = 0.8995, Val F1 = 0.8978
# Epoch 8: TrainLoss = 0.1792, ValLoss = 0.2456, Val Acc = 0.8968, Val F1 = 0.8987
# Early stopping at epoch 8
#
# Config 45/81: {'hidden_dim': 256, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3427, ValLoss = 0.2641, Val Acc = 0.8849, Val F1 = 0.8875
# Epoch 2: TrainLoss = 0.2672, ValLoss = 0.2500, Val Acc = 0.8942, Val F1 = 0.8950
# Epoch 3: TrainLoss = 0.2432, ValLoss = 0.2611, Val Acc = 0.8915, Val F1 = 0.8835
# Epoch 4: TrainLoss = 0.2382, ValLoss = 0.2290, Val Acc = 0.9008, Val F1 = 0.9022
# Epoch 5: TrainLoss = 0.2161, ValLoss = 0.2311, Val Acc = 0.9021, Val F1 = 0.9005
# Epoch 6: TrainLoss = 0.2033, ValLoss = 0.2587, Val Acc = 0.8929, Val F1 = 0.8960
# Epoch 7: TrainLoss = 0.2047, ValLoss = 0.2320, Val Acc = 0.9101, Val F1 = 0.9105
# Epoch 8: TrainLoss = 0.1868, ValLoss = 0.3342, Val Acc = 0.8638, Val F1 = 0.8761
# Epoch 9: TrainLoss = 0.1716, ValLoss = 0.2521, Val Acc = 0.9034, Val F1 = 0.8982
# Epoch 10: TrainLoss = 0.1564, ValLoss = 0.2713, Val Acc = 0.8942, Val F1 = 0.8982
# Epoch 11: TrainLoss = 0.1515, ValLoss = 0.2581, Val Acc = 0.9008, Val F1 = 0.8971
# Epoch 12: TrainLoss = 0.1435, ValLoss = 0.2752, Val Acc = 0.9008, Val F1 = 0.9032
# Early stopping at epoch 12
#
# Config 46/81: {'hidden_dim': 256, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3614, ValLoss = 0.2817, Val Acc = 0.8717, Val F1 = 0.8632
# Epoch 2: TrainLoss = 0.2755, ValLoss = 0.2575, Val Acc = 0.8981, Val F1 = 0.8991
# Epoch 3: TrainLoss = 0.2609, ValLoss = 0.2439, Val Acc = 0.9021, Val F1 = 0.9031
# Epoch 4: TrainLoss = 0.2470, ValLoss = 0.2330, Val Acc = 0.8981, Val F1 = 0.8969
# Epoch 5: TrainLoss = 0.2362, ValLoss = 0.2474, Val Acc = 0.8915, Val F1 = 0.8941
# ...
# Epoch 11: TrainLoss = 0.1517, ValLoss = 0.2697, Val Acc = 0.8915, Val F1 = 0.8858
# Epoch 12: TrainLoss = 0.1452, ValLoss = 0.2743, Val Acc = 0.8995, Val F1 = 0.9016
# Early stopping at epoch 12
#
# Config 69/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3575, ValLoss = 0.2741, Val Acc = 0.8743, Val F1 = 0.8656
# Epoch 2: TrainLoss = 0.2711, ValLoss = 0.2604, Val Acc = 0.8889, Val F1 = 0.8827
# Epoch 3: TrainLoss = 0.2495, ValLoss = 0.2351, Val Acc = 0.9074, Val F1 = 0.9064
# Epoch 4: TrainLoss = 0.2322, ValLoss = 0.2319, Val Acc = 0.9048, Val F1 = 0.9048
# Epoch 5: TrainLoss = 0.2269, ValLoss = 0.2342, Val Acc = 0.9034, Val F1 = 0.9007
# Epoch 6: TrainLoss = 0.2166, ValLoss = 0.2315, Val Acc = 0.9061, Val F1 = 0.9057
# Epoch 7: TrainLoss = 0.2089, ValLoss = 0.2521, Val Acc = 0.8942, Val F1 = 0.8977
# Epoch 8: TrainLoss = 0.2006, ValLoss = 0.2348, Val Acc = 0.9048, Val F1 = 0.9055
# Early stopping at epoch 8
#
# Config 70/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3434, ValLoss = 0.2627, Val Acc = 0.8955, Val F1 = 0.8951
# Epoch 2: TrainLoss = 0.2784, ValLoss = 0.2510, Val Acc = 0.9008, Val F1 = 0.9014
# Epoch 3: TrainLoss = 0.2619, ValLoss = 0.2340, Val Acc = 0.8955, Val F1 = 0.8934
# Epoch 4: TrainLoss = 0.2403, ValLoss = 0.2421, Val Acc = 0.8915, Val F1 = 0.8904
# Epoch 5: TrainLoss = 0.2345, ValLoss = 0.2473, Val Acc = 0.8995, Val F1 = 0.9003
# Epoch 6: TrainLoss = 0.2251, ValLoss = 0.2398, Val Acc = 0.9087, Val F1 = 0.9081
# Epoch 7: TrainLoss = 0.2164, ValLoss = 0.2364, Val Acc = 0.9034, Val F1 = 0.9004
# Epoch 8: TrainLoss = 0.2019, ValLoss = 0.2923, Val Acc = 0.8836, Val F1 = 0.8892
# Epoch 9: TrainLoss = 0.1878, ValLoss = 0.2660, Val Acc = 0.8942, Val F1 = 0.8961
# Epoch 10: TrainLoss = 0.1755, ValLoss = 0.2576, Val Acc = 0.8915, Val F1 = 0.8858
# Epoch 11: TrainLoss = 0.1562, ValLoss = 0.2634, Val Acc = 0.9008, Val F1 = 0.8960
# Early stopping at epoch 11
#
# Config 71/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3486, ValLoss = 0.3386, Val Acc = 0.8439, Val F1 = 0.8185
# Epoch 2: TrainLoss = 0.2679, ValLoss = 0.2627, Val Acc = 0.8862, Val F1 = 0.8789
# Epoch 3: TrainLoss = 0.2516, ValLoss = 0.2504, Val Acc = 0.9008, Val F1 = 0.9030
# Epoch 4: TrainLoss = 0.2339, ValLoss = 0.2556, Val Acc = 0.8889, Val F1 = 0.8837
# Epoch 5: TrainLoss = 0.2264, ValLoss = 0.2431, Val Acc = 0.8968, Val F1 = 0.8946
# Epoch 6: TrainLoss = 0.2098, ValLoss = 0.2302, Val Acc = 0.9034, Val F1 = 0.8985
# Epoch 7: TrainLoss = 0.1985, ValLoss = 0.2557, Val Acc = 0.9034, Val F1 = 0.9053
# Epoch 8: TrainLoss = 0.1889, ValLoss = 0.2329, Val Acc = 0.9140, Val F1 = 0.9106
# Epoch 9: TrainLoss = 0.1766, ValLoss = 0.2408, Val Acc = 0.9101, Val F1 = 0.9088
# Epoch 10: TrainLoss = 0.1615, ValLoss = 0.2615, Val Acc = 0.9074, Val F1 = 0.9074
# Epoch 11: TrainLoss = 0.1517, ValLoss = 0.2462, Val Acc = 0.9021, Val F1 = 0.9016
# Epoch 12: TrainLoss = 0.1446, ValLoss = 0.2702, Val Acc = 0.9048, Val F1 = 0.9027
# Epoch 13: TrainLoss = 0.1293, ValLoss = 0.2652, Val Acc = 0.9008, Val F1 = 0.9001
# Early stopping at epoch 13
#
# Config 72/81: {'hidden_dim': 512, 'dropout': 0.3, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3421, ValLoss = 0.2634, Val Acc = 0.8849, Val F1 = 0.8832
# Epoch 2: TrainLoss = 0.2665, ValLoss = 0.2401, Val Acc = 0.8915, Val F1 = 0.8907
# Epoch 3: TrainLoss = 0.2529, ValLoss = 0.2645, Val Acc = 0.8889, Val F1 = 0.8945
# Epoch 4: TrainLoss = 0.2296, ValLoss = 0.2360, Val Acc = 0.8968, Val F1 = 0.8943
# Epoch 5: TrainLoss = 0.2169, ValLoss = 0.2894, Val Acc = 0.8796, Val F1 = 0.8850
# Epoch 6: TrainLoss = 0.2156, ValLoss = 0.3001, Val Acc = 0.8796, Val F1 = 0.8886
# Epoch 7: TrainLoss = 0.1944, ValLoss = 0.2486, Val Acc = 0.9021, Val F1 = 0.8981
# Epoch 8: TrainLoss = 0.1834, ValLoss = 0.2512, Val Acc = 0.9021, Val F1 = 0.9026
# Epoch 9: TrainLoss = 0.1737, ValLoss = 0.2472, Val Acc = 0.9034, Val F1 = 0.9028
# Epoch 10: TrainLoss = 0.1580, ValLoss = 0.2496, Val Acc = 0.8955, Val F1 = 0.8937
# Epoch 11: TrainLoss = 0.1525, ValLoss = 0.2549, Val Acc = 0.8995, Val F1 = 0.9013
# Epoch 12: TrainLoss = 0.1347, ValLoss = 0.2688, Val Acc = 0.9061, Val F1 = 0.9062
# Epoch 13: TrainLoss = 0.1360, ValLoss = 0.2945, Val Acc = 0.8968, Val F1 = 0.9000
# Epoch 14: TrainLoss = 0.1115, ValLoss = 0.3305, Val Acc = 0.8915, Val F1 = 0.8967
# Epoch 15: TrainLoss = 0.1136, ValLoss = 0.3597, Val Acc = 0.8823, Val F1 = 0.8905
# Epoch 16: TrainLoss = 0.0958, ValLoss = 0.3053, Val Acc = 0.9074, Val F1 = 0.9084
# Epoch 17: TrainLoss = 0.0883, ValLoss = 0.3555, Val Acc = 0.8942, Val F1 = 0.8990
# Epoch 18: TrainLoss = 0.0850, ValLoss = 0.3237, Val Acc = 0.8981, Val F1 = 0.9006
# Epoch 19: TrainLoss = 0.0732, ValLoss = 0.3737, Val Acc = 0.8955, Val F1 = 0.8919
# Epoch 20: TrainLoss = 0.0688, ValLoss = 0.3395, Val Acc = 0.8981, Val F1 = 0.8980
# Epoch 21: TrainLoss = 0.0681, ValLoss = 0.3507, Val Acc = 0.8995, Val F1 = 0.8970
# Early stopping at epoch 21
#
# Config 73/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3579, ValLoss = 0.2647, Val Acc = 0.8902, Val F1 = 0.8918
# Epoch 2: TrainLoss = 0.2755, ValLoss = 0.3176, Val Acc = 0.8730, Val F1 = 0.8832
# Epoch 3: TrainLoss = 0.2654, ValLoss = 0.2402, Val Acc = 0.8995, Val F1 = 0.8947
# Epoch 4: TrainLoss = 0.2495, ValLoss = 0.2474, Val Acc = 0.8942, Val F1 = 0.8892
# Epoch 5: TrainLoss = 0.2375, ValLoss = 0.2331, Val Acc = 0.9061, Val F1 = 0.9047
# Epoch 6: TrainLoss = 0.2299, ValLoss = 0.2326, Val Acc = 0.9034, Val F1 = 0.9017
# Epoch 7: TrainLoss = 0.2203, ValLoss = 0.2399, Val Acc = 0.8981, Val F1 = 0.8941
# Epoch 8: TrainLoss = 0.2125, ValLoss = 0.2487, Val Acc = 0.8995, Val F1 = 0.8933
# Epoch 9: TrainLoss = 0.2059, ValLoss = 0.2322, Val Acc = 0.9048, Val F1 = 0.9022
# Epoch 10: TrainLoss = 0.2017, ValLoss = 0.2977, Val Acc = 0.8770, Val F1 = 0.8853
# Early stopping at epoch 10
#
# Config 74/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3779, ValLoss = 0.2888, Val Acc = 0.8796, Val F1 = 0.8844
# Epoch 2: TrainLoss = 0.2785, ValLoss = 0.2552, Val Acc = 0.8929, Val F1 = 0.8895
# Epoch 3: TrainLoss = 0.2570, ValLoss = 0.2483, Val Acc = 0.8955, Val F1 = 0.8925
# Epoch 4: TrainLoss = 0.2455, ValLoss = 0.2472, Val Acc = 0.8968, Val F1 = 0.8926
# Epoch 5: TrainLoss = 0.2405, ValLoss = 0.2436, Val Acc = 0.8955, Val F1 = 0.8898
# Epoch 6: TrainLoss = 0.2337, ValLoss = 0.2493, Val Acc = 0.8942, Val F1 = 0.8904
# Epoch 7: TrainLoss = 0.2245, ValLoss = 0.2362, Val Acc = 0.9034, Val F1 = 0.9036
# Epoch 8: TrainLoss = 0.2201, ValLoss = 0.2324, Val Acc = 0.9034, Val F1 = 0.9017
# Epoch 9: TrainLoss = 0.2115, ValLoss = 0.2377, Val Acc = 0.9061, Val F1 = 0.9034
# Epoch 10: TrainLoss = 0.2063, ValLoss = 0.2362, Val Acc = 0.9061, Val F1 = 0.9023
# Epoch 11: TrainLoss = 0.2058, ValLoss = 0.2459, Val Acc = 0.9008, Val F1 = 0.8954
# Epoch 12: TrainLoss = 0.1942, ValLoss = 0.2523, Val Acc = 0.8876, Val F1 = 0.8909
# Early stopping at epoch 12
#
# Config 75/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.0005, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.4046, ValLoss = 0.2782, Val Acc = 0.8836, Val F1 = 0.8854
# Epoch 2: TrainLoss = 0.2821, ValLoss = 0.2536, Val Acc = 0.8915, Val F1 = 0.8924
# Epoch 3: TrainLoss = 0.2622, ValLoss = 0.2488, Val Acc = 0.8902, Val F1 = 0.8889
# Epoch 4: TrainLoss = 0.2479, ValLoss = 0.2383, Val Acc = 0.8995, Val F1 = 0.8970
# Epoch 5: TrainLoss = 0.2405, ValLoss = 0.2359, Val Acc = 0.9048, Val F1 = 0.9043
# Epoch 6: TrainLoss = 0.2345, ValLoss = 0.2371, Val Acc = 0.8995, Val F1 = 0.8970
# Epoch 7: TrainLoss = 0.2269, ValLoss = 0.2283, Val Acc = 0.9048, Val F1 = 0.9043
# Epoch 8: TrainLoss = 0.2231, ValLoss = 0.2288, Val Acc = 0.9034, Val F1 = 0.9031
# Epoch 9: TrainLoss = 0.2228, ValLoss = 0.2300, Val Acc = 0.9061, Val F1 = 0.9047
# Epoch 10: TrainLoss = 0.2077, ValLoss = 0.2288, Val Acc = 0.9074, Val F1 = 0.9064
# Epoch 11: TrainLoss = 0.2172, ValLoss = 0.2273, Val Acc = 0.9048, Val F1 = 0.9037
# Epoch 12: TrainLoss = 0.2023, ValLoss = 0.2319, Val Acc = 0.9074, Val F1 = 0.9072
# Epoch 13: TrainLoss = 0.1988, ValLoss = 0.2292, Val Acc = 0.9101, Val F1 = 0.9084
# Epoch 14: TrainLoss = 0.1982, ValLoss = 0.2603, Val Acc = 0.8836, Val F1 = 0.8739
# Epoch 15: TrainLoss = 0.1891, ValLoss = 0.2405, Val Acc = 0.8995, Val F1 = 0.9013
# Epoch 16: TrainLoss = 0.1868, ValLoss = 0.2567, Val Acc = 0.8955, Val F1 = 0.8988
# Epoch 17: TrainLoss = 0.1864, ValLoss = 0.2379, Val Acc = 0.9008, Val F1 = 0.9022
# Epoch 18: TrainLoss = 0.1764, ValLoss = 0.2388, Val Acc = 0.9101, Val F1 = 0.9086
# Epoch 19: TrainLoss = 0.1729, ValLoss = 0.2577, Val Acc = 0.8889, Val F1 = 0.8810
# Epoch 20: TrainLoss = 0.1707, ValLoss = 0.2431, Val Acc = 0.9034, Val F1 = 0.9036
# Epoch 21: TrainLoss = 0.1647, ValLoss = 0.2705, Val Acc = 0.8929, Val F1 = 0.8864
# Epoch 22: TrainLoss = 0.1569, ValLoss = 0.2515, Val Acc = 0.9061, Val F1 = 0.9052
# Epoch 23: TrainLoss = 0.1566, ValLoss = 0.2418, Val Acc = 0.9074, Val F1 = 0.9074
# Early stopping at epoch 23
#
# Config 76/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3439, ValLoss = 0.2554, Val Acc = 0.8889, Val F1 = 0.8906
# Epoch 2: TrainLoss = 0.2854, ValLoss = 0.2376, Val Acc = 0.9021, Val F1 = 0.9005
# Epoch 3: TrainLoss = 0.2729, ValLoss = 0.2389, Val Acc = 0.8995, Val F1 = 0.8992
# Epoch 4: TrainLoss = 0.2552, ValLoss = 0.2523, Val Acc = 0.8849, Val F1 = 0.8787
# Epoch 5: TrainLoss = 0.2440, ValLoss = 0.2630, Val Acc = 0.8955, Val F1 = 0.8994
# Epoch 6: TrainLoss = 0.2300, ValLoss = 0.2404, Val Acc = 0.8995, Val F1 = 0.8962
# Epoch 7: TrainLoss = 0.2279, ValLoss = 0.2449, Val Acc = 0.8955, Val F1 = 0.8978
# Early stopping at epoch 7
#
# Config 77/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3562, ValLoss = 0.2625, Val Acc = 0.8876, Val F1 = 0.8874
# Epoch 2: TrainLoss = 0.2762, ValLoss = 0.2419, Val Acc = 0.9061, Val F1 = 0.9052
# Epoch 3: TrainLoss = 0.2574, ValLoss = 0.2413, Val Acc = 0.9008, Val F1 = 0.8971
# Epoch 4: TrainLoss = 0.2432, ValLoss = 0.2434, Val Acc = 0.9008, Val F1 = 0.8954
# Epoch 5: TrainLoss = 0.2422, ValLoss = 0.2344, Val Acc = 0.9008, Val F1 = 0.9001
# Epoch 6: TrainLoss = 0.2309, ValLoss = 0.2365, Val Acc = 0.9008, Val F1 = 0.8980
# Epoch 7: TrainLoss = 0.2209, ValLoss = 0.2491, Val Acc = 0.9008, Val F1 = 0.8945
# Early stopping at epoch 7
#
# Config 78/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.001, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3782, ValLoss = 0.2651, Val Acc = 0.8889, Val F1 = 0.8883
# Epoch 2: TrainLoss = 0.2736, ValLoss = 0.2497, Val Acc = 0.9021, Val F1 = 0.9031
# Epoch 3: TrainLoss = 0.2606, ValLoss = 0.2418, Val Acc = 0.9074, Val F1 = 0.9074
# Epoch 4: TrainLoss = 0.2494, ValLoss = 0.2444, Val Acc = 0.9021, Val F1 = 0.9034
# Epoch 5: TrainLoss = 0.2389, ValLoss = 0.2429, Val Acc = 0.8995, Val F1 = 0.9018
# Epoch 6: TrainLoss = 0.2261, ValLoss = 0.2333, Val Acc = 0.9021, Val F1 = 0.9034
# Epoch 7: TrainLoss = 0.2194, ValLoss = 0.2285, Val Acc = 0.9048, Val F1 = 0.9048
# Epoch 8: TrainLoss = 0.2140, ValLoss = 0.2297, Val Acc = 0.9074, Val F1 = 0.9067
# Early stopping at epoch 8
#
# Config 79/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 16}
# Epoch 1: TrainLoss = 0.3590, ValLoss = 0.2632, Val Acc = 0.8836, Val F1 = 0.8833
# Epoch 2: TrainLoss = 0.3014, ValLoss = 0.2504, Val Acc = 0.8915, Val F1 = 0.8924
# Epoch 3: TrainLoss = 0.2830, ValLoss = 0.2522, Val Acc = 0.9087, Val F1 = 0.9046
# Epoch 4: TrainLoss = 0.2769, ValLoss = 0.2624, Val Acc = 0.8902, Val F1 = 0.8829
# Epoch 5: TrainLoss = 0.2652, ValLoss = 0.2633, Val Acc = 0.8915, Val F1 = 0.8943
# Epoch 6: TrainLoss = 0.2527, ValLoss = 0.2576, Val Acc = 0.8929, Val F1 = 0.8958
# Epoch 7: TrainLoss = 0.2401, ValLoss = 0.3053, Val Acc = 0.8651, Val F1 = 0.8762
# Epoch 8: TrainLoss = 0.2327, ValLoss = 0.2337, Val Acc = 0.9087, Val F1 = 0.9069
# Epoch 9: TrainLoss = 0.2308, ValLoss = 0.2469, Val Acc = 0.9034, Val F1 = 0.9048
# Epoch 10: TrainLoss = 0.2168, ValLoss = 0.2295, Val Acc = 0.9048, Val F1 = 0.9060
# Epoch 11: TrainLoss = 0.2075, ValLoss = 0.2497, Val Acc = 0.9061, Val F1 = 0.9089
# Epoch 12: TrainLoss = 0.2045, ValLoss = 0.2577, Val Acc = 0.9008, Val F1 = 0.9037
# Epoch 13: TrainLoss = 0.1942, ValLoss = 0.2877, Val Acc = 0.8862, Val F1 = 0.8925
# Epoch 14: TrainLoss = 0.1862, ValLoss = 0.2252, Val Acc = 0.9021, Val F1 = 0.8978
# Epoch 15: TrainLoss = 0.1703, ValLoss = 0.2435, Val Acc = 0.9167, Val F1 = 0.9172
# Epoch 16: TrainLoss = 0.1774, ValLoss = 0.2961, Val Acc = 0.8836, Val F1 = 0.8897
# Epoch 17: TrainLoss = 0.1705, ValLoss = 0.2668, Val Acc = 0.9008, Val F1 = 0.8957
# Epoch 18: TrainLoss = 0.1553, ValLoss = 0.2293, Val Acc = 0.9153, Val F1 = 0.9140
# Epoch 19: TrainLoss = 0.1506, ValLoss = 0.2562, Val Acc = 0.9048, Val F1 = 0.9070
# Epoch 20: TrainLoss = 0.1426, ValLoss = 0.2353, Val Acc = 0.9127, Val F1 = 0.9106
# Early stopping at epoch 20
#
# Config 80/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 32}
# Epoch 1: TrainLoss = 0.3571, ValLoss = 0.2761, Val Acc = 0.8849, Val F1 = 0.8872
# Epoch 2: TrainLoss = 0.2902, ValLoss = 0.2550, Val Acc = 0.8929, Val F1 = 0.8963
# Epoch 3: TrainLoss = 0.2686, ValLoss = 0.2360, Val Acc = 0.9008, Val F1 = 0.8980
# Epoch 4: TrainLoss = 0.2566, ValLoss = 0.2468, Val Acc = 0.8981, Val F1 = 0.8938
# Epoch 5: TrainLoss = 0.2544, ValLoss = 0.2331, Val Acc = 0.8995, Val F1 = 0.8973
# Epoch 6: TrainLoss = 0.2356, ValLoss = 0.2313, Val Acc = 0.9061, Val F1 = 0.9029
# Epoch 7: TrainLoss = 0.2259, ValLoss = 0.2326, Val Acc = 0.9061, Val F1 = 0.9052
# Epoch 8: TrainLoss = 0.2264, ValLoss = 0.2254, Val Acc = 0.9101, Val F1 = 0.9071
# Epoch 9: TrainLoss = 0.2132, ValLoss = 0.2438, Val Acc = 0.8995, Val F1 = 0.8987
# Epoch 10: TrainLoss = 0.2139, ValLoss = 0.2544, Val Acc = 0.8942, Val F1 = 0.8942
# Epoch 11: TrainLoss = 0.1966, ValLoss = 0.2231, Val Acc = 0.9074, Val F1 = 0.9072
# Epoch 12: TrainLoss = 0.1933, ValLoss = 0.2368, Val Acc = 0.9061, Val F1 = 0.9091
# Epoch 13: TrainLoss = 0.1749, ValLoss = 0.2461, Val Acc = 0.9061, Val F1 = 0.9047
# Epoch 14: TrainLoss = 0.1728, ValLoss = 0.2408, Val Acc = 0.9061, Val F1 = 0.9060
# Epoch 15: TrainLoss = 0.1581, ValLoss = 0.2436, Val Acc = 0.9048, Val F1 = 0.9040
# Epoch 16: TrainLoss = 0.1538, ValLoss = 0.2608, Val Acc = 0.8995, Val F1 = 0.9005
# Epoch 17: TrainLoss = 0.1484, ValLoss = 0.2418, Val Acc = 0.9048, Val F1 = 0.9067
# Early stopping at epoch 17
#
# Config 81/81: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 64}
# Epoch 1: TrainLoss = 0.3640, ValLoss = 0.3161, Val Acc = 0.8558, Val F1 = 0.8666
# Epoch 2: TrainLoss = 0.2823, ValLoss = 0.2433, Val Acc = 0.8968, Val F1 = 0.8954
# Epoch 3: TrainLoss = 0.2551, ValLoss = 0.2341, Val Acc = 0.9021, Val F1 = 0.9011
# Epoch 4: TrainLoss = 0.2471, ValLoss = 0.2461, Val Acc = 0.8915, Val F1 = 0.8932
# Epoch 5: TrainLoss = 0.2452, ValLoss = 0.2457, Val Acc = 0.8981, Val F1 = 0.8917
# Epoch 6: TrainLoss = 0.2245, ValLoss = 0.2359, Val Acc = 0.8995, Val F1 = 0.8984
# Epoch 7: TrainLoss = 0.2168, ValLoss = 0.2440, Val Acc = 0.8981, Val F1 = 0.8961
# Epoch 8: TrainLoss = 0.2166, ValLoss = 0.2438, Val Acc = 0.8968, Val F1 = 0.8990
# Early stopping at epoch 8
#
# Best uni Config: {'hidden_dim': 512, 'dropout': 0.5, 'lr': 0.002, 'batch_size': 16, 'best_val_f1': 0.9172141918528253, 'train_losses': [0.3590212791316624, 0.3014210343250249, 0.28297732003800896, 0.2769313379020216, 0.2652021409895204, 0.25268135925163165, 0.24006731790153368, 0.2326630107815291, 0.2307503250686074, 0.216825957862778, 0.20754963732356985, 0.20452531958548717, 0.19421662601518566, 0.18615271244687595, 0.17025069942678075, 0.17736032233416285, 0.1704754808004875, 0.15528339791991516, 0.15059442385209684, 0.1425832345082335], 'val_losses': [0.2632099850467904, 0.25035637412121686, 0.2521968528076454, 0.26238652094016, 0.2633490154036769, 0.25759192110684814, 0.3052908644159004, 0.23367725052530802, 0.24688485280546563, 0.2295297780837962, 0.24972776335383218, 0.25765434546130045, 0.2877292519523984, 0.22519707376206363, 0.24346590229364298, 0.2960946547882582, 0.2668289897381944, 0.22929535106455207, 0.2562424702343171, 0.2352729062870066]}

# %% [markdown]
# ##Train Models (PDB)
# Retrain model with best Hyperparameter combined Train + Val set

# %%
# Combine train and validation data
train_losses = []
val_losses = []
X_pdb_full = np.concatenate([x_pdb_train, x_pdb_val], axis=0)
y_pdb_full = np.concatenate([y_pdb_train, y_pdb_val], axis=0)

X_train_diag, X_val_diag, y_train_diag, y_val_diag = train_test_split(
    X_pdb_full, y_pdb_full, test_size=0.1, stratify=y_pdb_full, random_state=42
)

train_diag_dataset = TensorDataset(
    torch.tensor(X_train_diag, dtype=torch.float32),
    torch.tensor(y_train_diag, dtype=torch.long)
)
val_diag_dataset = TensorDataset(
    torch.tensor(X_val_diag, dtype=torch.float32),
    torch.tensor(y_val_diag, dtype=torch.long)
)
train_diag_loader = DataLoader(
    train_diag_dataset, batch_size=best_pdb_config['batch_size'], shuffle=True
)
val_diag_loader = DataLoader(
    val_diag_dataset, batch_size=best_pdb_config['batch_size'], shuffle=False
)

# Model for final PDB
model_pdb = BiLSTMModel(
    input_dim=1280,
    hidden_dim=best_pdb_config['hidden_dim'],
    dropout=best_pdb_config['dropout'],
    output_dim=2
).to(device)
optimizer_pdb = torch.optim.Adam(model_pdb.parameters(), lr=best_pdb_config['lr'])
criterion = torch.nn.CrossEntropyLoss()

train_losses = []
val_losses = []

for epoch in range(1, 31):
    # --- Train ---
    model_pdb.train()
    train_loss_epoch = 0.0
    for xb, yb in train_diag_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer_pdb.zero_grad()
        out = model_pdb(xb)
        loss = criterion(out, yb)
        loss.backward()
        optimizer_pdb.step()
        train_loss_epoch += loss.item() * xb.size(0)
    train_loss_epoch = train_loss_epoch / len(train_diag_loader.dataset)
    train_losses.append(train_loss_epoch)

    # --- Val ---
    model_pdb.eval()
    val_loss_epoch = 0.0
    all_preds, all_targets = [], []
    with torch.no_grad():
        for xb, yb in val_diag_loader:
            xb, yb = xb.to(device), yb.to(device)
            out = model_pdb(xb)
            loss = criterion(out, yb)
            val_loss_epoch += loss.item() * xb.size(0)
            preds = torch.argmax(out, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_targets.extend(yb.cpu().numpy())
    val_loss_epoch = val_loss_epoch / len(val_diag_loader.dataset)
    val_losses.append(val_loss_epoch)

    val_f1 = f1_score(all_targets, all_preds, average='binary')
    print(f"Epoch {epoch}: TrainLoss={train_loss_epoch:.4f}, ValLoss={val_loss_epoch:.4f}, ValF1={val_f1:.4f}")
# Out:
# Epoch 1: TrainLoss=0.5773, ValLoss=0.5384, ValF1=0.6667
# Epoch 2: TrainLoss=0.3616, ValLoss=0.5115, ValF1=0.6842
# Epoch 3: TrainLoss=0.3108, ValLoss=0.5682, ValF1=0.7692
# Epoch 4: TrainLoss=0.2941, ValLoss=0.5028, ValF1=0.7629
# Epoch 5: TrainLoss=0.2375, ValLoss=0.4668, ValF1=0.8041
# Epoch 6: TrainLoss=0.2166, ValLoss=0.4767, ValF1=0.7742
# Epoch 7: TrainLoss=0.2317, ValLoss=0.4533, ValF1=0.8125
# Epoch 8: TrainLoss=0.1662, ValLoss=0.5398, ValF1=0.7826
# Epoch 9: TrainLoss=0.1515, ValLoss=0.6447, ValF1=0.8000
# Epoch 10: TrainLoss=0.1428, ValLoss=0.5977, ValF1=0.8235
# Epoch 11: TrainLoss=0.1310, ValLoss=0.6344, ValF1=0.7921
# Epoch 12: TrainLoss=0.1056, ValLoss=0.6129, ValF1=0.7835
# Epoch 13: TrainLoss=0.0837, ValLoss=0.7438, ValF1=0.8077
# Epoch 14: TrainLoss=0.1028, ValLoss=0.7666, ValF1=0.8269
# Epoch 15: TrainLoss=0.0944, ValLoss=0.5967, ValF1=0.7778
# Epoch 16: TrainLoss=0.0727, ValLoss=0.6346, ValF1=0.7586
# Epoch 17: TrainLoss=0.0684, ValLoss=0.7282, ValF1=0.8081
# Epoch 18: TrainLoss=0.0607, ValLoss=0.8001, ValF1=0.8000
# Epoch 19: TrainLoss=0.0661, ValLoss=0.8771, ValF1=0.7126
# Epoch 20: TrainLoss=0.0647, ValLoss=0.7666, ValF1=0.8041
# Epoch 21: TrainLoss=0.0924, ValLoss=0.7846, ValF1=0.8000
# Epoch 22: TrainLoss=0.0463, ValLoss=0.7785, ValF1=0.7556
# Epoch 23: TrainLoss=0.0395, ValLoss=0.8825, ValF1=0.8200
# Epoch 24: TrainLoss=0.0294, ValLoss=0.9001, ValF1=0.7527
# Epoch 25: TrainLoss=0.0231, ValLoss=0.8350, ValF1=0.7609
# Epoch 26: TrainLoss=0.0224, ValLoss=1.0332, ValF1=0.8269
# Epoch 27: TrainLoss=0.0222, ValLoss=0.9126, ValF1=0.7835
# Epoch 28: TrainLoss=0.0309, ValLoss=0.9051, ValF1=0.7879
# Epoch 29: TrainLoss=0.0187, ValLoss=0.9559, ValF1=0.8041
# Epoch 30: TrainLoss=0.0281, ValLoss=0.9591, ValF1=0.7872

# %%
# Combine train and validation data
train_losses = []
val_losses = []
X_uni_full = np.concatenate([x_uni_train, x_uni_val], axis=0)
y_uni_full = np.concatenate([y_uni_train, y_uni_val], axis=0)

X_train_diag, X_val_diag, y_train_diag, y_val_diag = train_test_split(
    X_uni_full, y_uni_full, test_size=0.1, stratify=y_uni_full, random_state=42
)

train_diag_dataset = TensorDataset(
    torch.tensor(X_train_diag, dtype=torch.float32),
    torch.tensor(y_train_diag, dtype=torch.long)
)
val_diag_dataset = TensorDataset(
    torch.tensor(X_val_diag, dtype=torch.float32),
    torch.tensor(y_val_diag, dtype=torch.long)
)
train_diag_loader = DataLoader(
    train_diag_dataset, batch_size=best_uni_config['batch_size'], shuffle=True
)
val_diag_loader = DataLoader(
    val_diag_dataset, batch_size=best_uni_config['batch_size'], shuffle=False
)

# Model for final uni
model_uni = BiLSTMModel(
    input_dim=1280,
    hidden_dim=best_uni_config['hidden_dim'],
    dropout=best_uni_config['dropout'],
    output_dim=2
).to(device)
optimizer_uni = torch.optim.Adam(model_uni.parameters(), lr=best_uni_config['lr'])
criterion = torch.nn.CrossEntropyLoss()

train_losses = []
val_losses = []

for epoch in range(1, 31):
    # --- Train ---
    model_uni.train()
    train_loss_epoch = 0.0
    for xb, yb in train_diag_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer_uni.zero_grad()
        out = model_uni(xb)
        loss = criterion(out, yb)
        loss.backward()
        optimizer_uni.step()
        train_loss_epoch += loss.item() * xb.size(0)
    train_loss_epoch = train_loss_epoch / len(train_diag_loader.dataset)
    train_losses.append(train_loss_epoch)

    # --- Val ---
    model_uni.eval()
    val_loss_epoch = 0.0
    all_preds, all_targets = [], []
    with torch.no_grad():
        for xb, yb in val_diag_loader:
            xb, yb = xb.to(device), yb.to(device)
            out = model_uni(xb)
            loss = criterion(out, yb)
            val_loss_epoch += loss.item() * xb.size(0)
            preds = torch.argmax(out, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_targets.extend(yb.cpu().numpy())
    val_loss_epoch = val_loss_epoch / len(val_diag_loader.dataset)
    val_losses.append(val_loss_epoch)

    val_f1 = f1_score(all_targets, all_preds, average='binary')
    print(f"Epoch {epoch}: TrainLoss={train_loss_epoch:.4f}, ValLoss={val_loss_epoch:.4f}, ValF1={val_f1:.4f}")
# Out:
# Epoch 1: TrainLoss=0.3601, ValLoss=0.3019, ValF1=0.8689
# Epoch 2: TrainLoss=0.3026, ValLoss=0.2789, ValF1=0.8904
# Epoch 3: TrainLoss=0.2895, ValLoss=0.3052, ValF1=0.8512
# Epoch 4: TrainLoss=0.2662, ValLoss=0.2909, ValF1=0.8668
# Epoch 5: TrainLoss=0.2679, ValLoss=0.3118, ValF1=0.8688
# Epoch 6: TrainLoss=0.2519, ValLoss=0.3237, ValF1=0.8582
# Epoch 7: TrainLoss=0.2362, ValLoss=0.2914, ValF1=0.8709
# Epoch 8: TrainLoss=0.2370, ValLoss=0.2540, ValF1=0.8948
# Epoch 9: TrainLoss=0.2210, ValLoss=0.2586, ValF1=0.8831
# Epoch 10: TrainLoss=0.2257, ValLoss=0.2783, ValF1=0.8819
# Epoch 11: TrainLoss=0.2057, ValLoss=0.3009, ValF1=0.8712
# Epoch 12: TrainLoss=0.1975, ValLoss=0.2572, ValF1=0.8987
# Epoch 13: TrainLoss=0.1999, ValLoss=0.2523, ValF1=0.9012
# Epoch 14: TrainLoss=0.1822, ValLoss=0.2693, ValF1=0.8944
# Epoch 15: TrainLoss=0.1790, ValLoss=0.2557, ValF1=0.8978
# Epoch 16: TrainLoss=0.1662, ValLoss=0.2619, ValF1=0.8956
# Epoch 17: TrainLoss=0.1602, ValLoss=0.2744, ValF1=0.9013
# Epoch 18: TrainLoss=0.1555, ValLoss=0.2732, ValF1=0.9027
# Epoch 19: TrainLoss=0.1518, ValLoss=0.2839, ValF1=0.8967
# Epoch 20: TrainLoss=0.1480, ValLoss=0.2863, ValF1=0.8952
# Epoch 21: TrainLoss=0.1434, ValLoss=0.2725, ValF1=0.9005
# Epoch 22: TrainLoss=0.1317, ValLoss=0.3322, ValF1=0.8790
# Epoch 23: TrainLoss=0.1281, ValLoss=0.3028, ValF1=0.8881
# Epoch 24: TrainLoss=0.1219, ValLoss=0.3106, ValF1=0.8943
# Epoch 25: TrainLoss=0.1256, ValLoss=0.3066, ValF1=0.8860
# Epoch 26: TrainLoss=0.1173, ValLoss=0.3100, ValF1=0.9006
# Epoch 27: TrainLoss=0.1120, ValLoss=0.3251, ValF1=0.8967
# Epoch 28: TrainLoss=0.1061, ValLoss=0.3251, ValF1=0.8950
# Epoch 29: TrainLoss=0.1006, ValLoss=0.3260, ValF1=0.8884
# Epoch 30: TrainLoss=0.1069, ValLoss=0.3420, ValF1=0.8970

# %%
def evaluate_and_report(model, loader, name, return_probs=False):
    model.eval()
    all_preds, all_targets = [], []
    all_probs = []
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            outputs = model(xb)
            probs = torch.softmax(outputs, dim=1)[:,1].cpu().numpy()  # For binary
            preds = np.round(probs)
            all_probs.extend(probs)
            all_preds.extend(preds)
            all_targets.extend(yb.cpu().numpy())

    acc = accuracy_score(all_targets, all_preds)
    prec = precision_score(all_targets, all_preds)
    rec = recall_score(all_targets, all_preds)
    f1 = f1_score(all_targets, all_preds)
    mcc = matthews_corrcoef(all_targets, all_preds)
    cm = confusion_matrix(all_targets, all_preds)

    # Sensitivity == Recall; Specificity == True Negative Rate
    tn, fp, fn, tp = cm.ravel()
    sensitivity = rec
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

    # ROC/AUC
    roc_auc = roc_auc_score(all_targets, all_probs)
    fpr, tpr, thresholds = roc_curve(all_targets, all_probs)

    print(f"\n{name} Metrics:")
    print(f"  Accuracy     : {acc:.4f}")
    print(f"  Precision    : {prec:.4f}")
    print(f"  Recall/Sens. : {sensitivity:.4f}")
    print(f"  Specificity  : {specificity:.4f}")
    print(f"  F1-score     : {f1:.4f}")
    print(f"  MCC          : {mcc:.4f}")
    print(f"  ROC_AUC      : {roc_auc:.4f}")
    print(f"  Confusion Matrix:\n{cm}\n")
    print(f"{name} Classification Report:")
    print(classification_report(all_targets, all_preds, digits=4))

    # Plot Confusion Matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues')
    plt.title(f"{name} Confusion Matrix")
    plt.show()

    # Plot ROC Curve
    plt.figure()
    plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate (Recall)')
    plt.title(f'{name} ROC Curve')
    plt.legend()
    plt.show()

    # Plot val loss
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Train & Val Loss Curves (Best Model Retrain)')
    plt.legend()
    plt.show()

    # Optionally return probabilities for further analysis
    if return_probs:
        return all_preds, all_targets, all_probs

    # For report table (like image): print markdown or as pandas.DataFrame
    metrics = {
        "Accuracy": acc,
        "Precision_macro": prec,
        "Recall_macro": rec,
        "F1_macro": f1,
        "MCC": mcc,
        "Specificity": specificity,
        "ROC_AUC": roc_auc
    }
# Run evaluation ONLY on test set for final results
pdb_test_dataset = TensorDataset(torch.tensor(x_pdb_test_emb, dtype=torch.float32), torch.tensor(y_pdb_test, dtype=torch.long))
pdb_test_loader = DataLoader(pdb_test_dataset, batch_size=best_pdb_config['batch_size'], shuffle=False)

evaluate_and_report(model_pdb, pdb_test_loader, "PDB Test")

uni_test_dataset = TensorDataset(torch.tensor(x_uni_test_emb, dtype=torch.float32), torch.tensor(y_uni_test, dtype=torch.long))
uni_test_loader = DataLoader(uni_test_dataset, batch_size=best_uni_config['batch_size'], shuffle=False)

evaluate_and_report(model_uni, uni_test_loader, "UniSwiss Test")
# Out:
# PDB Test Metrics:
#   Accuracy     : 0.8011
#   Precision    : 0.8111
#   Recall/Sens. : 0.7849
#   Specificity  : 0.8172
#   F1-score     : 0.7978
#   MCC          : 0.6025
#   ROC_AUC      : 0.8777
#   Confusion Matrix:
# [[76 17]
#  [20 73]]
#
# PDB Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7917    0.8172    0.8042        93
#            1     0.8111    0.7849    0.7978        93
#
#     accuracy                         0.8011       186
#    macro avg     0.8014    0.8011    0.8010       186
# weighted avg     0.8014    0.8011    0.8010       186
# UniSwiss Test Metrics:
#   Accuracy     : 0.9051
#   Precision    : 0.9298
#   Recall/Sens. : 0.8757
#   Specificity  : 0.9344
#   F1-score     : 0.9019
#   MCC          : 0.8116
#   ROC_AUC      : 0.9568
#   Confusion Matrix:
# [[356  25]
#  [ 47 331]]
#
# UniSwiss Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8834    0.9344    0.9082       381
#            1     0.9298    0.8757    0.9019       378
#
#     accuracy                         0.9051       759
#    macro avg     0.9066    0.9050    0.9050       759
# weighted avg     0.9065    0.9051    0.9050       759
